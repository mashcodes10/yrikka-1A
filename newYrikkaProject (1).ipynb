# %%
# !git clone https://github.com/YRIKKA/yrikka-btt-aistudio-2025.git
# Out:
# Cloning into 'yrikka-btt-aistudio-2025'...
# remote: Enumerating objects: 1011, done.
# remote: Total 1011 (delta 0), reused 0 (delta 0), pack-reused 1011 (from 3)
# Receiving objects: 100% (1011/1011), 244.53 MiB | 42.49 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import os
import json
import csv
import shutil
from tqdm import tqdm
from PIL import Image

def clean_dataset(images_dir, coco_json_path, out_dir):

    # Create output directory & images folder
    os.makedirs(os.path.join(out_dir, "images"), exist_ok=True)

    # -------------------------------------------
    # Step 1: Define canonical classes + mappings
    # -------------------------------------------
    canonical_classes = ["potted plant", "chair", "cup", "vase", "book"]
    class_mapping = {
        "##ted": "potted plant",
        "pot plant": "potted plant",
        "cup vase": "vase",
        "pot": "potted plant",
        "vase potted plant": "potted plant",
        "potted": "potted plant"
    }

    # -------------------------------------------
    # Step 2: Load COCO annotations
    # -------------------------------------------
    with open(coco_json_path) as f:
        coco = json.load(f)

    # Map canonical class names → new IDs (1 to N)
    name_to_new_id = {cls: i + 1 for i, cls in enumerate(canonical_classes)}

    # Original COCO category_id → category_name mapping
    category_id_to_name = {cat["id"]: cat["name"] for cat in coco.get("categories", [])}

    # -------------------------------------------
    # Step 3: Collect valid images + dimensions
    # -------------------------------------------
    image_id_to_info = {}
    for img in coco["images"]:
        file_path = os.path.join(images_dir, img["file_name"])
        if not os.path.exists(file_path):
            continue
        try:
            with Image.open(file_path) as im:
                width, height = im.size
        except:
            continue

        image_id_to_info[img["id"]] = {
            "file_name": img["file_name"],
            "path": file_path,
            "width": width,
            "height": height
        }

    # -------------------------------------------
    # Step 4: Validate and clean annotations
    # -------------------------------------------
    valid_annotations = []
    valid_image_ids = set()
    dropped_rows = []
    used_original_classes = []  # Track only class names actually present

    for ann in tqdm(coco["annotations"], desc="Validating annotations"):
        image_id = ann["image_id"]

        # Skip annotation if image is missing/unloadable
        if image_id not in image_id_to_info:
            dropped_rows.append(["Missing image", image_id, ann["id"], ann.get("bbox", "")])
            continue

        # Validate bbox
        info = image_id_to_info[image_id]
        img_w, img_h = info["width"], info["height"]
        x, y, w, h = ann["bbox"]

        if w <= 0 or h <= 0:
            dropped_rows.append(["Invalid bbox size", image_id, ann["id"], ann["bbox"]])
            continue

        # Clip box to image boundaries
        x = max(0, min(x, img_w))
        y = max(0, min(y, img_h))
        w = max(1, min(w, img_w - x))
        h = max(1, min(h, img_h - y))

        if w <= 0 or h <= 0:
            dropped_rows.append(["Box outside image", image_id, ann["id"], [x, y, w, h]])
            continue

        # Apply class mapping for noisy labels
        original_class = category_id_to_name.get(ann["category_id"], "Unknown")
        if original_class not in used_original_classes:
          used_original_classes.append(original_class)  # Only track used classes
        mapped_class = class_mapping.get(original_class, original_class)

        # Keep only mapped or canonical classes
        if mapped_class not in canonical_classes:
            dropped_rows.append(["Unmapped class", image_id, ann["id"], original_class])
            continue

        # Final annotation cleanup
        ann["category_id"] = name_to_new_id[mapped_class]
        ann["bbox"] = [x, y, w, h]
        valid_annotations.append(ann)
        valid_image_ids.add(image_id)

    # -------------------------------------------
    # Step 5: Keep only valid images
    # -------------------------------------------
    valid_images = [img for img in coco["images"] if img["id"] in valid_image_ids]

    # -------------------------------------------
    # Step 6: Save cleaned COCO JSON
    # -------------------------------------------
    cleaned_coco = {
        "images": valid_images,
        "annotations": valid_annotations,
        "categories": [{"id": i + 1, "name": cls} for i, cls in enumerate(canonical_classes)]
    }
    with open(os.path.join(out_dir, "cleaned_coco.json"), "w") as f:
        json.dump(cleaned_coco, f, indent=2)

    # Copy only validated images to the new folder
    for img in valid_images:
        src = os.path.join(images_dir, img["file_name"])
        dst = os.path.join(out_dir, "images", img["file_name"])
        if os.path.exists(src):
            shutil.copy2(src, dst)

    # -------------------------------------------
    # Step 7: Save dropped annotation report
    # -------------------------------------------
    with open(os.path.join(out_dir, "dropped_report.csv"), "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Reason", "ImageID", "AnnotationID", "Details"])
        for r in dropped_rows:
            writer.writerow(r)

    # -------------------------------------------
    # Step 8: Save real class mapping used
    # -------------------------------------------
    with open(os.path.join(out_dir, "class_mapping.csv"), "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["Original Class (found)", "Mapped Class"])
        for orig in used_original_classes:
            mapped = class_mapping.get(orig, orig)
            if orig != mapped:
                writer.writerow([orig, mapped])

    print(f"✅ Cleaned dataset saved ({out_dir}): {len(valid_images)} images, {len(valid_annotations)} annotations")

# ---------------------------
# Run on both datasets
# ---------------------------
clean_dataset(
    images_dir="yrikka-btt-aistudio-2025/BTT_Data/852a64c6-4bd3-495f-8ff7-f5cc85e34316/images",
    coco_json_path="yrikka-btt-aistudio-2025/BTT_Data/852a64c6-4bd3-495f-8ff7-f5cc85e34316/coco.json",
    out_dir="cleaned_dataset1"
)

clean_dataset(
    images_dir="yrikka-btt-aistudio-2025/BTT_Data/8e0a5d2d-3ae0-4ff0-b6ee-2d85f7da4fee/images",
    coco_json_path="yrikka-btt-aistudio-2025/BTT_Data/8e0a5d2d-3ae0-4ff0-b6ee-2d85f7da4fee/coco.json",
    out_dir="cleaned_dataset2"
)
# Out:
# Validating annotations: 100%|██████████| 1668/1668 [00:00<00:00, 452499.78it/s]
# ✅ Cleaned dataset saved (cleaned_dataset1): 497 images, 1668 annotations
# Validating annotations: 100%|██████████| 1708/1708 [00:00<00:00, 270620.70it/s]
# ✅ Cleaned dataset saved (cleaned_dataset2): 496 images, 1708 annotations

# %%
import os
import json
import shutil
from tqdm import tqdm

def merge_coco_datasets(cleaned_dir1, cleaned_dir2, output_dir):
    """
    Merges two cleaned COCO datasets (same categories) into one unified dataset.
    """

    os.makedirs(os.path.join(output_dir, "images"), exist_ok=True)

    # Load both COCO annotations
    with open(os.path.join(cleaned_dir1, "cleaned_coco.json")) as f:
        coco1 = json.load(f)
    with open(os.path.join(cleaned_dir2, "cleaned_coco.json")) as f:
        coco2 = json.load(f)

    # Categories should be the same (because we already cleaned them)
    categories = coco1["categories"]

    # To avoid ID conflicts, find maximum existing IDs in dataset1
    max_image_id = max([img["id"] for img in coco1["images"]], default=0)
    max_ann_id = max([ann["id"] for ann in coco1["annotations"]], default=0)

    merged_images = []
    merged_annotations = []

    # Step 1: Copy all images + annotations from dataset1
    for img in coco1["images"]:
        src = os.path.join(cleaned_dir1, "images", img["file_name"])
        dst = os.path.join(output_dir, "images", img["file_name"])
        if os.path.exists(src):
            shutil.copy2(src, dst)
        merged_images.append(img)

    for ann in coco1["annotations"]:
        merged_annotations.append(ann)

    # Step 2: Append all from dataset2 but shift IDs
    for img in coco2["images"]:
        new_img = img.copy()
        new_img["id"] = img["id"] + max_image_id  # shift image ID
        src = os.path.join(cleaned_dir2, "images", img["file_name"])
        dst = os.path.join(output_dir, "images", img["file_name"])
        if os.path.exists(src):
            shutil.copy2(src, dst)
        merged_images.append(new_img)

    for ann in coco2["annotations"]:
        new_ann = ann.copy()
        new_ann["id"] = ann["id"] + max_ann_id  # shift annotation ID
        new_ann["image_id"] = ann["image_id"] + max_image_id  # link to shifted image ID
        merged_annotations.append(new_ann)

    # Step 3: Save merged COCO JSON
    merged_coco = {
        "images": merged_images,
        "annotations": merged_annotations,
        "categories": categories
    }

    with open(os.path.join(output_dir, "merged_coco.json"), "w") as f:
        json.dump(merged_coco, f, indent=2)

    print(f"✅ Merged dataset saved to {output_dir}:")
    print(f"   → Total Images: {len(merged_images)}")
    print(f"   → Total Annotations: {len(merged_annotations)}")


# ----------------------------
# Run After Your Cleaning Step
# ----------------------------
merge_coco_datasets(
    cleaned_dir1="cleaned_dataset1",
    cleaned_dir2="cleaned_dataset2",
    output_dir="merged_cleaned_dataset"
)
# Out:
# ✅ Merged dataset saved to merged_cleaned_dataset:
#    → Total Images: 993
#    → Total Annotations: 3376

# %%
# from google.colab import files

# # Create a zip of the misclassified images folder
# shutil.make_archive("merged_cleaned_dataset/images", "zip", "merged_cleaned_dataset/images")


# # Download the zip

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.230-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.230-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 46.2 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.230 ultralytics-thop-2.0.18

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import os
import shutil
import csv
import json
from collections import defaultdict
from ultralytics import YOLO

# -----------------------------
# Step 1. Run YOLO Predictions
# -----------------------------
model = YOLO("yolo11n.pt")

results = model.predict(
    source="merged_cleaned_dataset/images",
    save=True,
    save_txt=True,
    conf=0.5,
    classes=[58, 56, 41, 75, 73]  # COCO IDs for potted plant, chair, cup, vase, book
)

# -----------------------------
# Step 2. Class Mapping
# -----------------------------
coco_to_canonical = {58: 1, 56: 2, 41: 3, 75: 4, 73: 5}
canonical_names = {
    1: "potted plant", 2: "chair", 3: "cup", 4: "vase", 5: "book"
}

# -----------------------------
# Step 3. Load Ground Truth
# -----------------------------
with open("merged_cleaned_dataset/merged_coco.json") as f:
    gt = json.load(f)

image_id_to_ann = defaultdict(list)
for ann in gt["annotations"]:
    image_id_to_ann[ann["image_id"]].append(ann)

image_id_to_name = {img["id"]: img["file_name"] for img in gt["images"]}

# -----------------------------
# Step 4. IOU Function
# -----------------------------
def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
    yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])
    inter = max(0, xB - xA) * max(0, yB - yA)
    union = boxA[2]*boxA[3] + boxB[2]*boxB[3] - inter
    return inter / union if union > 0 else 0

# -----------------------------
# Step 5. Compare Predictions vs GT
# -----------------------------
misclassified_images = set()
report_rows = []
iou_threshold = 0.4

for result in results:
    file_name = os.path.basename(result.path)

    # Match GT image id
    image_id = next((img["id"] for img in gt["images"] if img["file_name"] == file_name), None)
    if image_id is None:
        continue

    gt_boxes = [(ann["bbox"], ann["category_id"]) for ann in image_id_to_ann[image_id]]

    preds = []
    for box in result.boxes:
        coco_id = int(box.cls.cpu().numpy()[0])
        if coco_id in coco_to_canonical:
            pred_class = coco_to_canonical[coco_id]
            xyxy = box.xyxy.cpu().numpy()[0]
            w, h = xyxy[2] - xyxy[0], xyxy[3] - xyxy[1]
            preds.append(([float(xyxy[0]), float(xyxy[1]), float(w), float(h)], pred_class))

    matched_preds = set()

    # GT vs Preds
    for gt_box, gt_cls in gt_boxes:
        for i, (pred_box, pred_cls) in enumerate(preds):
            if i not in matched_preds and iou(gt_box, pred_box) >= iou_threshold:
                matched_preds.add(i)
                if pred_cls != gt_cls:
                    misclassified_images.add(file_name)
                    report_rows.append([file_name, "Wrong Class",
                                        canonical_names[gt_cls],
                                        canonical_names[pred_cls],
                                        round(iou(gt_box, pred_box), 3)])

    # Extra Predictions = Missing GT annotations
    for i, (pred_box, pred_cls) in enumerate(preds):
        if i not in matched_preds:
            misclassified_images.add(file_name)
            report_rows.append([file_name, "Missing Annotation", "None",
                                canonical_names[pred_cls], 0.0])

# -----------------------------
# Step 6. Save Everything in One Folder
# -----------------------------
output_folder = "misclassified_dataset"
images_folder = os.path.join(output_folder, "images")
os.makedirs(images_folder, exist_ok=True)

# Create COCO JSON with only misclassified images
misclassified_gt = {
    "images": [img for img in gt["images"] if img["file_name"] in misclassified_images],
    "annotations": [ann for ann in gt["annotations"]
                    if image_id_to_name[ann["image_id"]] in misclassified_images],
    "categories": gt["categories"]
}

with open(os.path.join(output_folder, "misclassified_coco.json"), "w") as f:
    json.dump(misclassified_gt, f, indent=2)

# Copy misclassified images
for img in misclassified_gt["images"]:
    src = os.path.join("merged_cleaned_dataset/images", img["file_name"])
    dst = os.path.join(images_folder, img["file_name"])
    if os.path.exists(src):
        shutil.copy2(src, dst)

# Save CSV Report
with open(os.path.join(output_folder, "misclassified_report.csv"), "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Image", "Reason", "GroundTruth", "Prediction", "IOU"])
    writer.writerows(report_rows)

print(f"✅ {len(misclassified_gt['images'])} misclassified images found.")
print(f"📁 All outputs saved inside '{output_folder}/'")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 166.1MB/s 0.0s
#
# image 1/993 /content/merged_cleaned_dataset/images/0067dc2e-4bb7-48a2-b9c5-9da631f86595_flux_1756081928.png: 640x640 1 potted plant, 1 vase, 8.3ms
# image 2/993 /content/merged_cleaned_dataset/images/007abd03-fa5e-43d8-af0a-fbed58e17821_flux_1756081085.png: 640x640 (no detections), 8.3ms
# image 3/993 /content/merged_cleaned_dataset/images/00f8644a-c4af-4097-a0bc-e8af706554ce_flux_1756082211.png: 640x640 1 vase, 8.2ms
# image 4/993 /content/merged_cleaned_dataset/images/0142ef49-931a-46b3-a841-452224567d33_flux_1756079514.png: 640x640 1 chair, 8.2ms
# image 5/993 /content/merged_cleaned_dataset/images/01a1e58d-cdf5-4de9-8c35-bf4a9e741350_flux_1756079529.png: 640x640 1 chair, 1 vase, 8.2ms
# image 6/993 /content/merged_cleaned_dataset/images/02534685-590c-4899-a048-c9371666f4b6_flux_1756080506.png: 640x640 1 cup, 1 book, 8.2ms
# image 7/993 /content/merged_cleaned_dataset/images/02de1ef0-1130-473d-9d2a-425b231ebdd2_flux_1756080597.png: 640x640 1 chair, 2 potted plants, 14.0ms
# image 8/993 /content/merged_cleaned_dataset/images/02e220f1-583c-4f22-9ded-d01b8ffdc466_flux_1756078698.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 9/993 /content/merged_cleaned_dataset/images/0305fc14-9c1f-4b9e-b08b-33d199bc022f_flux_1756081386.png: 640x640 1 chair, 8.2ms
# image 10/993 /content/merged_cleaned_dataset/images/0313d4d2-c1b6-411a-9d0d-e29714a0d27e_flux_1756081964.png: 640x640 2 chairs, 2 potted plants, 1 book, 8.2ms
# image 11/993 /content/merged_cleaned_dataset/images/031b2fd0-366f-4a7f-b317-8d9eb7c3e8c3_flux_1756079420.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 12/993 /content/merged_cleaned_dataset/images/036c2df1-bd35-4212-b519-470036c3b938_flux_1756079758.png: 640x640 (no detections), 8.2ms
# image 13/993 /content/merged_cleaned_dataset/images/03a1ad66-b5fa-42cb-b86a-91bc0f3ac0fe_flux_1756079951.png: 640x640 1 cup, 8.2ms
# image 14/993 /content/merged_cleaned_dataset/images/03af0e86-1d0e-4470-ae4a-dc34f3129c16_flux_1756082373.png: 640x640 (no detections), 8.2ms
# image 15/993 /content/merged_cleaned_dataset/images/04207281-836e-437d-a637-028329a89ae5_flux_1756081815.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 16/993 /content/merged_cleaned_dataset/images/045ad3e2-b4ee-42ee-aec8-aaee1ee006eb_flux_1756081190.png: 640x640 (no detections), 8.3ms
# image 17/993 /content/merged_cleaned_dataset/images/048ae3ab-e6a0-4416-b875-9348e9dd580a_flux_1756081893.png: 640x640 1 potted plant, 8.2ms
# image 18/993 /content/merged_cleaned_dataset/images/04cafbb4-51b2-4bab-93e8-03db568c6655_flux_1756079688.png: 640x640 1 cup, 2 chairs, 8.2ms
# image 19/993 /content/merged_cleaned_dataset/images/04d6d431-2ff9-4e83-83e0-479b89937996_flux_1756081548.png: 640x640 1 chair, 8.2ms
# image 20/993 /content/merged_cleaned_dataset/images/0501aa30-2c53-4c0b-990d-584d1a070ee3_flux_1756079487.png: 640x640 1 book, 8.2ms
# image 21/993 /content/merged_cleaned_dataset/images/05bc3295-5c9a-4af6-8c24-5e288f296dc3_flux_1756079666.png: 640x640 2 chairs, 8.2ms
# image 22/993 /content/merged_cleaned_dataset/images/05ed35e5-bb41-47be-9659-d7707bc9d7a5_flux_1756079015.png: 640x640 1 vase, 8.6ms
# image 23/993 /content/merged_cleaned_dataset/images/0602c753-62b6-4edc-baa2-8f69d742559c_flux_1756081707.png: 640x640 1 chair, 8.2ms
# image 24/993 /content/merged_cleaned_dataset/images/0657bc9a-0ef1-40f0-bed8-f79fe2930e43_flux_1756082234.png: 640x640 (no detections), 8.2ms
# image 25/993 /content/merged_cleaned_dataset/images/065f1468-77e8-45a9-aa4a-6654433155c6_flux_1756079854.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 26/993 /content/merged_cleaned_dataset/images/076ecd94-ec78-4ebb-9b5f-7dc08e2632bf_flux_1756079924.png: 640x640 1 chair, 8.2ms
# image 27/993 /content/merged_cleaned_dataset/images/07fbd8c0-bc84-4f1f-865d-2f1def35de3c_flux_1756081279.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 28/993 /content/merged_cleaned_dataset/images/080eb723-6968-4486-b278-4fcbda0585ad_flux_1756079732.png: 640x640 2 chairs, 1 potted plant, 8.9ms
# image 29/993 /content/merged_cleaned_dataset/images/0855c460-0a0e-4ddf-9415-8ed89c7edfe1_flux_1756081260.png: 640x640 1 cup, 8.2ms
# image 30/993 /content/merged_cleaned_dataset/images/0887c71c-83e7-496f-92a5-4dd49c9a3529_flux_1756082304.png: 640x640 (no detections), 8.2ms
# image 31/993 /content/merged_cleaned_dataset/images/089b2eda-c8f1-451a-95aa-cf4c01d781bd_flux_1756081186.png: 640x640 1 chair, 8.2ms
# image 32/993 /content/merged_cleaned_dataset/images/08d7da45-3766-4cca-822c-f3cbbe0094a1_flux_1756081152.png: 640x640 (no detections), 8.2ms
# image 33/993 /content/merged_cleaned_dataset/images/09139aed-2e54-48cc-9927-dfa6e6b67d32_flux_1756079743.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 34/993 /content/merged_cleaned_dataset/images/09316c29-0615-4cca-8b43-6cf62da1e93d_flux_1756082027.png: 640x640 (no detections), 8.2ms
# image 35/993 /content/merged_cleaned_dataset/images/093da434-adb5-4b17-86fb-b220e71bee4e_flux_1756079390.png: 640x640 1 cup, 1 chair, 8.2ms
# image 36/993 /content/merged_cleaned_dataset/images/096733a4-ba23-4f6f-a64b-0c51c5e63117_flux_1756080692.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 37/993 /content/merged_cleaned_dataset/images/09996aab-4e48-4869-b0a7-6e985b6f242c_flux_1756080763.png: 640x640 1 cup, 1 book, 8.2ms
# image 38/993 /content/merged_cleaned_dataset/images/09bb2498-1d0a-4573-9e94-838f8e3ca14f_flux_1756079562.png: 640x640 1 cup, 8.2ms
# image 39/993 /content/merged_cleaned_dataset/images/09ff73e4-46a9-472c-a2ab-b6effb256d93_flux_1756081607.png: 640x640 1 cup, 8.2ms
# image 40/993 /content/merged_cleaned_dataset/images/0a1352cf-09ef-45a7-a0c4-4cf92d5795e9_flux_1756078925.png: 640x640 1 cup, 1 potted plant, 2 vases, 8.2ms
# image 41/993 /content/merged_cleaned_dataset/images/0a7a287a-d25a-472c-8c40-3876a3a60cbe_flux_1756080063.png: 640x640 2 vases, 8.2ms
# image 42/993 /content/merged_cleaned_dataset/images/0b05dc0d-d4ce-454d-a30e-5eb7368c5ab3_flux_1756081016.png: 640x640 1 cup, 8.2ms
# image 43/993 /content/merged_cleaned_dataset/images/0b1ee1d5-6e0f-4a18-a3ca-ba3dcc8b5f73_flux_1756080003.png: 640x640 1 chair, 8.2ms
# image 44/993 /content/merged_cleaned_dataset/images/0b86344b-45de-4e1d-a4de-7a7a3e45ba14_flux_1756079356.png: 640x640 1 chair, 8.2ms
# image 45/993 /content/merged_cleaned_dataset/images/0bc6ae52-b8d9-472b-816b-4c23db2afa37_flux_1756080257.png: 640x640 (no detections), 12.1ms
# image 46/993 /content/merged_cleaned_dataset/images/0bde8b01-4f2f-403f-ad35-468fe14a2601_flux_1756082370.png: 640x640 1 vase, 8.2ms
# image 47/993 /content/merged_cleaned_dataset/images/0c0d297e-075b-4e3a-ab04-610291993f94_flux_1756081796.png: 640x640 1 cup, 8.2ms
# image 48/993 /content/merged_cleaned_dataset/images/0d98007a-a323-46f2-9681-58e3b46a7e6c_flux_1756079696.png: 640x640 (no detections), 8.2ms
# image 49/993 /content/merged_cleaned_dataset/images/0da0d28f-f140-4ee3-be21-052e16c5d768_flux_1756080455.png: 640x640 1 chair, 8.2ms
# image 50/993 /content/merged_cleaned_dataset/images/0df5d159-76ae-4908-8f60-a3a03d0c1e8b_flux_1756080317.png: 640x640 1 potted plant, 1 vase, 8.6ms
# image 51/993 /content/merged_cleaned_dataset/images/0e5d32ff-82ac-401a-9792-9858476bf79c_flux_1756081651.png: 640x640 (no detections), 8.2ms
# image 52/993 /content/merged_cleaned_dataset/images/0eff620f-f1a8-4e6e-8d6d-3dbc57f730d1_flux_1756081983.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 53/993 /content/merged_cleaned_dataset/images/0f7a21d4-2a63-4e3d-bf0c-f5c662ca1a7b_flux_1756080473.png: 640x640 1 cup, 9.1ms
# image 54/993 /content/merged_cleaned_dataset/images/0f7c504e-7c0c-4f06-aef8-116db375ba23_flux_1756080429.png: 640x640 1 cup, 2 chairs, 8.2ms
# image 55/993 /content/merged_cleaned_dataset/images/0fde6ff6-3b80-4f72-8e87-439434726818_flux_1756081703.png: 640x640 (no detections), 8.2ms
# image 56/993 /content/merged_cleaned_dataset/images/0ff1599f-aa2f-4b80-9ba7-64c80282ae07_flux_1756081950.png: 640x640 1 cup, 8.2ms
# image 57/993 /content/merged_cleaned_dataset/images/104b6c25-7e6a-433f-8c45-de9ffeca331a_flux_1756080386.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 58/993 /content/merged_cleaned_dataset/images/1075c685-3561-45cc-919a-107248cae56d_flux_1756081785.png: 640x640 2 chairs, 8.2ms
# image 59/993 /content/merged_cleaned_dataset/images/112c004e-9f51-4735-8682-54fcf7a720f4_flux_1756081770.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 60/993 /content/merged_cleaned_dataset/images/11aa118c-4af9-4df8-9c90-4a8b602ae5d1_flux_1756079566.png: 640x640 1 chair, 8.2ms
# image 61/993 /content/merged_cleaned_dataset/images/11ae083d-ed88-4510-b37f-7cff3f2c3f26_flux_1756079703.png: 640x640 (no detections), 8.2ms
# image 62/993 /content/merged_cleaned_dataset/images/11b7f387-309f-49a7-91ca-1c7c6bcfce2a_flux_1756081658.png: 640x640 (no detections), 8.2ms
# image 63/993 /content/merged_cleaned_dataset/images/12439e46-758b-4d6e-8d05-55b020c6adc9_flux_1756080361.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 64/993 /content/merged_cleaned_dataset/images/124feba8-dfff-47ad-9d4e-a5226cde2ccc_flux_1756081219.png: 640x640 1 chair, 1 potted plant, 8.3ms
# image 65/993 /content/merged_cleaned_dataset/images/1278f02f-b6c0-446f-8518-7395a0769669_flux_1756081596.png: 640x640 1 cup, 8.4ms
# image 66/993 /content/merged_cleaned_dataset/images/1283017b-a569-4b43-a92d-d9cf58e8b405_flux_1756079259.png: 640x640 1 cup, 8.5ms
# image 67/993 /content/merged_cleaned_dataset/images/12bce271-294a-4584-b9ca-4a8e7be53bd6_flux_1756078812.png: 640x640 1 cup, 8.2ms
# image 68/993 /content/merged_cleaned_dataset/images/12d3c3d3-9369-468b-a1d2-ec6a382f58b4_flux_1756081636.png: 640x640 1 potted plant, 1 vase, 8.4ms
# image 69/993 /content/merged_cleaned_dataset/images/130fed4d-480d-4d6c-9e9d-b8b2af0dfeb7_flux_1756081935.png: 640x640 1 book, 8.2ms
# image 70/993 /content/merged_cleaned_dataset/images/13234045-cccc-4d01-8f00-5e7eeb92fdf2_flux_1756081492.png: 640x640 1 book, 8.2ms
# image 71/993 /content/merged_cleaned_dataset/images/1399e237-dc3b-4c83-8102-83579b9ff1ba_flux_1756081309.png: 640x640 (no detections), 8.2ms
# image 72/993 /content/merged_cleaned_dataset/images/139c2a53-fc0a-4f66-96c9-68fe63bd055c_flux_1756081748.png: 640x640 2 vases, 8.2ms
# image 73/993 /content/merged_cleaned_dataset/images/13ab4421-d2c8-45b5-afbb-b83dd16fbe00_flux_1756079648.png: 640x640 1 potted plant, 8.2ms
# image 74/993 /content/merged_cleaned_dataset/images/14075113-1329-4dab-b88a-6370862a2f6b_flux_1756082249.png: 640x640 (no detections), 8.2ms
# image 75/993 /content/merged_cleaned_dataset/images/1430d9bb-e7ad-4caf-974f-bc0403f416b8_flux_1756081916.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 76/993 /content/merged_cleaned_dataset/images/14595165-b881-411b-80de-6b9f12dcf3f1_flux_1756078880.png: 640x640 1 chair, 8.2ms
# image 77/993 /content/merged_cleaned_dataset/images/146b79cf-9499-4db0-8a94-b67c2d7c1689_flux_1756082318.png: 640x640 1 cup, 1 chair, 1 vase, 8.2ms
# image 78/993 /content/merged_cleaned_dataset/images/14a8a6d3-11f3-47c6-a26d-40ab390f14bd_flux_1756079277.png: 640x640 1 cup, 8.2ms
# image 79/993 /content/merged_cleaned_dataset/images/153e32cc-1e55-41d4-89ea-0c4f7b33f396_flux_1756079787.png: 640x640 1 chair, 8.2ms
# image 80/993 /content/merged_cleaned_dataset/images/15700d53-0eb0-4d98-a0f3-be1336a64b8b_flux_1756081514.png: 640x640 (no detections), 8.2ms
# image 81/993 /content/merged_cleaned_dataset/images/15a86e84-2c87-429f-afbc-961dcc87dc2f_flux_1756079699.png: 640x640 1 book, 8.2ms
# image 82/993 /content/merged_cleaned_dataset/images/15c66ce6-df8b-4919-b019-81b329451e42_flux_1756081729.png: 640x640 1 chair, 8.2ms
# image 83/993 /content/merged_cleaned_dataset/images/1604d64b-dedf-4e0c-9e70-31834a51c87c_flux_1756082425.png: 640x640 1 vase, 9.5ms
# image 84/993 /content/merged_cleaned_dataset/images/16258fb6-7886-416b-9527-d05f39222afc_flux_1756079397.png: 640x640 1 cup, 10.3ms
# image 85/993 /content/merged_cleaned_dataset/images/1650e522-c712-4543-adcb-948ffc7c06d8_flux_1756079153.png: 640x640 (no detections), 8.3ms
# image 86/993 /content/merged_cleaned_dataset/images/166e2fc5-5e2f-4520-bde0-01d6bff6665b_flux_1756082289.png: 640x640 1 vase, 9.2ms
# image 87/993 /content/merged_cleaned_dataset/images/16828bab-2ebe-43d9-8a57-2b7ffb4726c2_flux_1756082016.png: 640x640 1 potted plant, 1 book, 1 vase, 9.5ms
# image 88/993 /content/merged_cleaned_dataset/images/16ac950a-6374-4467-b663-2e6e4d80a648_flux_1756079375.png: 640x640 1 cup, 8.2ms
# image 89/993 /content/merged_cleaned_dataset/images/17153dbd-930e-4aed-bf1c-b6de81250f6a_flux_1756079030.png: 640x640 (no detections), 8.2ms
# image 90/993 /content/merged_cleaned_dataset/images/1719426f-a7f4-46ed-b3bb-6706a023fa73_flux_1756081129.png: 640x640 1 book, 8.2ms
# image 91/993 /content/merged_cleaned_dataset/images/1719c1df-346c-4df3-a0a6-82dda3a62458_flux_1756078838.png: 640x640 1 potted plant, 1 book, 8.2ms
# image 92/993 /content/merged_cleaned_dataset/images/172efd0b-be31-4d0b-8945-a8a55351fe14_flux_1756078808.png: 640x640 (no detections), 8.2ms
# image 93/993 /content/merged_cleaned_dataset/images/17734e78-cb33-4ddf-ba77-cc52dab5634b_flux_1756079821.png: 640x640 2 chairs, 1 potted plant, 8.2ms
# image 94/993 /content/merged_cleaned_dataset/images/19164952-106d-48f3-98f8-fbccd4d7a092_flux_1756080822.png: 640x640 1 cup, 8.2ms
# image 95/993 /content/merged_cleaned_dataset/images/191b590b-bf59-497b-b1d0-06c3c59730a8_flux_1756081049.png: 640x640 (no detections), 8.2ms
# image 96/993 /content/merged_cleaned_dataset/images/19739bc9-57f4-4f5a-9bb1-d53a219338af_flux_1756080513.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 97/993 /content/merged_cleaned_dataset/images/19a1243b-f2e9-4800-aae4-21f4319a2a2c_flux_1756081294.png: 640x640 1 book, 8.2ms
# image 98/993 /content/merged_cleaned_dataset/images/19ac98bd-9206-4ab6-998a-33583fe32abb_flux_1756079326.png: 640x640 1 cup, 2 books, 8.2ms
# image 99/993 /content/merged_cleaned_dataset/images/19b18126-17c8-400f-8364-41a72b941cfc_flux_1756081317.png: 640x640 1 vase, 8.2ms
# image 100/993 /content/merged_cleaned_dataset/images/19b8c491-c209-4497-af70-8a5c585e59db_flux_1756079386.png: 640x640 1 cup, 8.9ms
# image 101/993 /content/merged_cleaned_dataset/images/19f04d49-8ec6-4809-afb2-35bee8629828_flux_1756082127.png: 640x640 2 books, 1 vase, 8.2ms
# image 102/993 /content/merged_cleaned_dataset/images/1a241c1c-7ba8-40ba-b79b-c8d3105c5c00_flux_1756080612.png: 640x640 (no detections), 8.4ms
# image 103/993 /content/merged_cleaned_dataset/images/1ae697af-90f4-4ff3-b1a9-a150b13f33a5_flux_1756080803.png: 640x640 1 cup, 8.2ms
# image 104/993 /content/merged_cleaned_dataset/images/1b25b375-700d-4a33-a7c4-9e9b29eb4395_flux_1756079596.png: 640x640 (no detections), 8.2ms
# image 105/993 /content/merged_cleaned_dataset/images/1bb8185c-e7a1-4998-a5c8-4ba00a62be58_flux_1756079663.png: 640x640 1 cup, 8.2ms
# image 106/993 /content/merged_cleaned_dataset/images/1bbd6032-1d7b-408b-9347-f6aa90dcd836_flux_1756080134.png: 640x640 (no detections), 8.2ms
# image 107/993 /content/merged_cleaned_dataset/images/1c37f4a7-c67d-4c40-82ea-8efcad037daa_flux_1756078974.png: 640x640 1 cup, 1 chair, 8.2ms
# image 108/993 /content/merged_cleaned_dataset/images/1d2233a6-80c5-472e-979a-68124bcb2915_flux_1756082271.png: 640x640 1 cup, 8.2ms
# image 109/993 /content/merged_cleaned_dataset/images/1da9824f-d5cf-46cc-a951-51f33f8b758e_flux_1756079067.png: 640x640 1 book, 8.2ms
# image 110/993 /content/merged_cleaned_dataset/images/1dc3be62-3100-4a70-aac6-4b28b273c450_flux_1756079547.png: 640x640 1 vase, 8.2ms
# image 111/993 /content/merged_cleaned_dataset/images/1e265db6-4462-495e-9740-25ba1b4bad2f_flux_1756081804.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 112/993 /content/merged_cleaned_dataset/images/1ef6741e-0384-4404-b584-864f2548e621_flux_1756080313.png: 640x640 (no detections), 8.2ms
# image 113/993 /content/merged_cleaned_dataset/images/1f0d222d-a03f-4e5f-9c4f-bf4a5d7c676e_flux_1756078669.png: 640x640 1 potted plant, 2 vases, 8.2ms
# image 114/993 /content/merged_cleaned_dataset/images/1f6b7dca-adac-48f7-80b6-60e690af2569_flux_1756081834.png: 640x640 1 vase, 8.2ms
# image 115/993 /content/merged_cleaned_dataset/images/1fb85fe1-b254-43d7-8fbc-09b1b43dc1b3_flux_1756080375.png: 640x640 2 chairs, 1 vase, 8.2ms
# image 116/993 /content/merged_cleaned_dataset/images/20190ce9-3a4f-4529-921b-158cb40b9750_flux_1756079094.png: 640x640 1 cup, 8.2ms
# image 117/993 /content/merged_cleaned_dataset/images/202a6dde-076f-4e9e-a519-88cf52284e6d_flux_1756081752.png: 640x640 (no detections), 8.2ms
# image 118/993 /content/merged_cleaned_dataset/images/2097d4ab-56bc-481d-958a-5b98be83f93a_flux_1756080382.png: 640x640 2 chairs, 1 vase, 8.2ms
# image 119/993 /content/merged_cleaned_dataset/images/21436951-1371-49d9-99fe-34ebadb894e5_flux_1756078760.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 120/993 /content/merged_cleaned_dataset/images/21f2c75c-1dda-41cb-8add-1e3452c28947_flux_1756079131.png: 640x640 1 potted plant, 8.2ms
# image 121/993 /content/merged_cleaned_dataset/images/21ff0455-4ed1-4291-9a58-5e10888a8289_flux_1756078712.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 122/993 /content/merged_cleaned_dataset/images/2256260a-2e61-4e9f-8d1d-61d8db84dc86_flux_1756079204.png: 640x640 1 chair, 14.0ms
# image 123/993 /content/merged_cleaned_dataset/images/2308c5f2-bca1-4f3c-bc8a-58698f1911b9_flux_1756080954.png: 640x640 (no detections), 8.2ms
# image 124/993 /content/merged_cleaned_dataset/images/230e07c0-202f-4a34-9e6d-4ce55dd4e7c9_flux_1756081208.png: 640x640 (no detections), 8.8ms
# image 125/993 /content/merged_cleaned_dataset/images/233adda4-8346-4e07-8da3-c56f0abdff47_flux_1756081118.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 126/993 /content/merged_cleaned_dataset/images/234e1939-66b0-463a-b189-efa053437bf1_flux_1756079995.png: 640x640 1 potted plant, 8.2ms
# image 127/993 /content/merged_cleaned_dataset/images/236fa17e-d321-4f80-8373-2b0044ac6ead_flux_1756079909.png: 640x640 1 chair, 8.2ms
# image 128/993 /content/merged_cleaned_dataset/images/242c9e5f-fb61-4b49-aa72-b60d54d09599_flux_1756079891.png: 640x640 1 cup, 8.2ms
# image 129/993 /content/merged_cleaned_dataset/images/2460f51b-1269-4f7b-8da4-5340e4d69b1a_flux_1756080165.png: 640x640 1 chair, 1 vase, 8.2ms
# image 130/993 /content/merged_cleaned_dataset/images/249bc37a-2152-447b-a47b-e60107c328d4_flux_1756080718.png: 640x640 2 chairs, 8.2ms
# image 131/993 /content/merged_cleaned_dataset/images/251ed839-e1f6-4a9c-a21a-37a0d1a2b3d7_flux_1756079394.png: 640x640 1 vase, 8.2ms
# image 132/993 /content/merged_cleaned_dataset/images/258ffee1-6a49-443c-a52e-ff8d9d14f955_flux_1756080379.png: 640x640 1 chair, 8.2ms
# image 133/993 /content/merged_cleaned_dataset/images/2613ca20-e6fc-4eab-895c-5b8755457cc0_flux_1756080309.png: 640x640 1 chair, 1 potted plant, 1 vase, 8.2ms
# image 134/993 /content/merged_cleaned_dataset/images/26358efc-a5c2-416c-b501-7a4a8b51ff7e_flux_1756081912.png: 640x640 1 chair, 8.2ms
# image 135/993 /content/merged_cleaned_dataset/images/2671e0ad-8e38-44de-aebd-535f214d5309_flux_1756081890.png: 640x640 1 cup, 1 potted plant, 1 vase, 8.2ms
# image 136/993 /content/merged_cleaned_dataset/images/26a18337-668f-4bf1-a97d-005b62c12933_flux_1756079932.png: 640x640 1 cup, 8.2ms
# image 137/993 /content/merged_cleaned_dataset/images/26cf02f2-fce6-4894-8f34-6a9a4a460460_flux_1756078764.png: 640x640 (no detections), 8.2ms
# image 138/993 /content/merged_cleaned_dataset/images/2700348a-c791-40e1-afee-fa158141dd37_flux_1756081197.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 139/993 /content/merged_cleaned_dataset/images/278eb2d7-71c0-46a0-bb35-572961f57325_flux_1756079917.png: 640x640 1 potted plant, 9.3ms
# image 140/993 /content/merged_cleaned_dataset/images/27a30bcf-2365-4832-bb16-cc4ad69f9568_flux_1756080411.png: 640x640 1 potted plant, 8.2ms
# image 141/993 /content/merged_cleaned_dataset/images/28447fbd-e8f9-44fe-bf21-ad6bdca8ad53_flux_1756081924.png: 640x640 1 vase, 8.2ms
# image 142/993 /content/merged_cleaned_dataset/images/28503fa2-6f69-46c5-9ac9-413daad2b920_flux_1756080924.png: 640x640 1 cup, 8.2ms
# image 143/993 /content/merged_cleaned_dataset/images/2896fac1-b3b8-4050-9684-092ee406e293_flux_1756080689.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 144/993 /content/merged_cleaned_dataset/images/28d30207-2b45-43a3-be73-76d63963b5fa_flux_1756080659.png: 640x640 1 cup, 8.2ms
# image 145/993 /content/merged_cleaned_dataset/images/29171825-da0d-4aab-91a6-4a87f7de902a_flux_1756079484.png: 640x640 1 chair, 8.2ms
# image 146/993 /content/merged_cleaned_dataset/images/293ac3e2-f4ef-42d0-8ef9-40dfbc8c0caf_flux_1756079049.png: 640x640 1 chair, 1 book, 8.2ms
# image 147/993 /content/merged_cleaned_dataset/images/296445de-1bcd-426a-bd61-6f80bb7f0bd8_flux_1756079750.png: 640x640 1 vase, 8.2ms
# image 148/993 /content/merged_cleaned_dataset/images/29ee0f3d-4a96-485b-85fc-6fcf7fdaff15_flux_1756079765.png: 640x640 1 cup, 8.2ms
# image 149/993 /content/merged_cleaned_dataset/images/2a2f89ac-e90c-4124-b1fd-e4337e3fcd3f_flux_1756081455.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 150/993 /content/merged_cleaned_dataset/images/2a35a70d-c668-407c-85fe-fcb054a52c8b_flux_1756081767.png: 640x640 1 cup, 8.2ms
# image 151/993 /content/merged_cleaned_dataset/images/2ad68627-9e80-4f4a-81b9-99781e20ebf0_flux_1756081053.png: 640x640 3 books, 8.2ms
# image 152/993 /content/merged_cleaned_dataset/images/2b987a7f-e8d4-492e-8ce3-4b4054ec095a_flux_1756079544.png: 640x640 (no detections), 8.2ms
# image 153/993 /content/merged_cleaned_dataset/images/2bb0ac17-6a6d-4c50-ae9c-7c199f76b2d8_flux_1756079836.png: 640x640 (no detections), 8.2ms
# image 154/993 /content/merged_cleaned_dataset/images/2bdd2a51-e76c-4ec1-9109-ae5b45999dd9_flux_1756080074.png: 640x640 1 cup, 1 potted plant, 1 vase, 8.2ms
# image 155/993 /content/merged_cleaned_dataset/images/2bfaee73-39c3-4c9d-a4fd-0c3b4662080e_flux_1756081275.png: 640x640 1 vase, 8.2ms
# image 156/993 /content/merged_cleaned_dataset/images/2c3312eb-cc02-4882-a165-f3ed38d9fa79_flux_1756078801.png: 640x640 1 potted plant, 8.2ms
# image 157/993 /content/merged_cleaned_dataset/images/2c411644-6e05-4ba2-9346-64908d5a647f_flux_1756079817.png: 640x640 1 vase, 8.2ms
# image 158/993 /content/merged_cleaned_dataset/images/2c737ebd-04e9-4436-81e9-36fe55daeef6_flux_1756080696.png: 640x640 1 vase, 8.2ms
# image 159/993 /content/merged_cleaned_dataset/images/2c772c3d-6918-450b-aa72-241a1064c407_flux_1756081986.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 160/993 /content/merged_cleaned_dataset/images/2c84514c-8401-4bfd-88f4-33d58765ad85_flux_1756080756.png: 640x640 1 potted plant, 14.2ms
# image 161/993 /content/merged_cleaned_dataset/images/2cc7f669-0420-46b8-8859-2099a9097e8d_flux_1756080477.png: 640x640 1 chair, 1 potted plant, 12.1ms
# image 162/993 /content/merged_cleaned_dataset/images/2cdf16e0-185f-478b-a5f5-a4676b9a2eab_flux_1756080301.png: 640x640 (no detections), 14.1ms
# image 163/993 /content/merged_cleaned_dataset/images/2dbbcfc2-d2d5-49e0-83b4-f7be8cb4ac6f_flux_1756081163.png: 640x640 1 chair, 1 vase, 14.0ms
# image 164/993 /content/merged_cleaned_dataset/images/2e1484a4-d123-4e1e-a005-f4285912ea32_flux_1756079865.png: 640x640 1 vase, 9.9ms
# image 165/993 /content/merged_cleaned_dataset/images/2e2108f7-e924-4dc9-8b50-283afd3ddcbc_flux_1756081089.png: 640x640 1 cup, 2 chairs, 1 potted plant, 9.8ms
# image 166/993 /content/merged_cleaned_dataset/images/2e27722f-2b0d-4f49-a0ba-420a612f906d_flux_1756079211.png: 640x640 3 chairs, 12.1ms
# image 167/993 /content/merged_cleaned_dataset/images/2e3afed6-c7ad-4c69-875e-635a6ff5fb04_flux_1756078936.png: 640x640 1 potted plant, 1 vase, 10.6ms
# image 168/993 /content/merged_cleaned_dataset/images/2e8d11dc-39e9-4bfe-9d92-8015185af772_flux_1756078966.png: 640x640 1 potted plant, 10.6ms
# image 169/993 /content/merged_cleaned_dataset/images/2f290367-616e-4e03-966a-513412a3a74c_flux_1756080917.png: 640x640 1 potted plant, 1 vase, 11.0ms
# image 170/993 /content/merged_cleaned_dataset/images/2f5abb95-18dd-4e78-adba-94b866902be2_flux_1756082034.png: 640x640 (no detections), 9.1ms
# image 171/993 /content/merged_cleaned_dataset/images/2fba9b3d-ec7b-473b-a6dd-a60a1f05c512_flux_1756081878.png: 640x640 1 vase, 10.2ms
# image 172/993 /content/merged_cleaned_dataset/images/2fca5353-66f9-4f4a-bf6a-ae86976fb80b_flux_1756080404.png: 640x640 1 vase, 10.1ms
# image 173/993 /content/merged_cleaned_dataset/images/2fd45e53-ad2d-4240-bf47-b1cb0c194216_flux_1756080393.png: 640x640 1 vase, 10.6ms
# image 174/993 /content/merged_cleaned_dataset/images/3042b10c-a63a-4187-a08c-62012680a3e1_flux_1756081298.png: 640x640 1 cup, 1 potted plant, 9.5ms
# image 175/993 /content/merged_cleaned_dataset/images/3049fbf7-2718-4013-93ff-e5a2a7c35e6d_flux_1756079692.png: 640x640 (no detections), 9.7ms
# image 176/993 /content/merged_cleaned_dataset/images/30534e6e-1cac-41a9-8dbf-ffa7fbcf5b46_flux_1756082005.png: 640x640 1 vase, 9.4ms
# image 177/993 /content/merged_cleaned_dataset/images/305b9a22-cb61-4f25-b9ef-48ed85c8535d_flux_1756079292.png: 640x640 1 vase, 9.5ms
# image 178/993 /content/merged_cleaned_dataset/images/3095c1df-a8d1-49b0-8e60-a7daaf3659fd_flux_1756080093.png: 640x640 2 potted plants, 2 vases, 9.8ms
# image 179/993 /content/merged_cleaned_dataset/images/30ed20b1-bdd0-4f7a-8923-2fb5088e1e08_flux_1756078996.png: 640x640 1 chair, 9.7ms
# image 180/993 /content/merged_cleaned_dataset/images/312b9b6e-166a-45e8-983c-2d02138ac742_flux_1756078921.png: 640x640 1 chair, 9.6ms
# image 181/993 /content/merged_cleaned_dataset/images/31432a0d-4ba5-43c0-bef4-8461d0b1c480_flux_1756080286.png: 640x640 1 chair, 9.7ms
# image 182/993 /content/merged_cleaned_dataset/images/31574912-a6cc-4522-848f-70190fee5bb1_flux_1756079622.png: 640x640 1 chair, 9.6ms
# image 183/993 /content/merged_cleaned_dataset/images/31a85a4f-2937-424b-9547-e2eaac893a3d_flux_1756078959.png: 640x640 1 cup, 9.6ms
# image 184/993 /content/merged_cleaned_dataset/images/32a992d3-8dad-43a7-81f7-848b3f3c510d_flux_1756081574.png: 640x640 1 book, 9.6ms
# image 185/993 /content/merged_cleaned_dataset/images/33072fe5-4493-47d1-a05d-e57d2f4d7333_flux_1756082307.png: 640x640 1 cup, 11.9ms
# image 186/993 /content/merged_cleaned_dataset/images/3317f1ad-94e7-49c6-a2d3-671ccf7629b6_flux_1756082149.png: 640x640 1 cup, 9.1ms
# image 187/993 /content/merged_cleaned_dataset/images/3374ef3b-4339-465c-a03a-7bd7e7f133cf_flux_1756079281.png: 640x640 1 potted plant, 1 vase, 15.8ms
# image 188/993 /content/merged_cleaned_dataset/images/33940505-3438-445e-84f2-36e1cb5fd11f_flux_1756078981.png: 640x640 (no detections), 11.9ms
# image 189/993 /content/merged_cleaned_dataset/images/33ba388e-7be4-4fdc-b5ec-89787bec968c_flux_1756079880.png: 640x640 1 chair, 3 potted plants, 8.9ms
# image 190/993 /content/merged_cleaned_dataset/images/33bd7fcc-ed36-4249-b79f-c405add07425_flux_1756079630.png: 640x640 (no detections), 8.9ms
# image 191/993 /content/merged_cleaned_dataset/images/33cd43c7-55dd-44fe-8138-3af744011ae5_flux_1756079736.png: 640x640 (no detections), 9.3ms
# image 192/993 /content/merged_cleaned_dataset/images/33ce9fad-b0fa-49be-9c2d-d6d0c6702da6_flux_1756081849.png: 640x640 1 chair, 9.0ms
# image 193/993 /content/merged_cleaned_dataset/images/34757a5d-445e-4a85-a9d8-ba8fe450c407_flux_1756079495.png: 640x640 1 cup, 9.1ms
# image 194/993 /content/merged_cleaned_dataset/images/34802bbe-e820-4489-9f8d-015eb9118cb5_flux_1756081115.png: 640x640 1 vase, 9.1ms
# image 195/993 /content/merged_cleaned_dataset/images/355fe846-6ab7-4d14-aae0-4cf975c1f81e_flux_1756078948.png: 640x640 1 cup, 8.9ms
# image 196/993 /content/merged_cleaned_dataset/images/3567a632-b490-4785-8551-13b78ad085b6_flux_1756082395.png: 640x640 1 potted plant, 1 vase, 8.8ms
# image 197/993 /content/merged_cleaned_dataset/images/361c13da-095e-4bc7-b90f-c0c867942775_flux_1756080426.png: 640x640 1 vase, 9.4ms
# image 198/993 /content/merged_cleaned_dataset/images/3627fa88-b15d-45c9-a052-a0476fb592b8_flux_1756080700.png: 640x640 1 cup, 1 potted plant, 9.3ms
# image 199/993 /content/merged_cleaned_dataset/images/369cc86a-489f-436c-8be6-b48470777763_flux_1756080796.png: 640x640 1 chair, 1 book, 11.4ms
# image 200/993 /content/merged_cleaned_dataset/images/36abcc37-20e9-4324-a539-963db4b54759_flux_1756080652.png: 640x640 1 chair, 2 vases, 9.7ms
# image 201/993 /content/merged_cleaned_dataset/images/36b57255-aa25-47a7-8398-198442e917ce_flux_1756079999.png: 640x640 1 chair, 10.5ms
# image 202/993 /content/merged_cleaned_dataset/images/36bee849-e627-491e-aba6-d5ed64a7122c_flux_1756082340.png: 640x640 1 potted plant, 1 vase, 13.7ms
# image 203/993 /content/merged_cleaned_dataset/images/36cc7feb-01ee-47f2-8755-7f1e66a202a3_flux_1756079850.png: 640x640 2 potted plants, 9.9ms
# image 204/993 /content/merged_cleaned_dataset/images/37224030-b198-4a06-aae6-267f31dabe36_flux_1756080615.png: 640x640 1 cup, 13.0ms
# image 205/993 /content/merged_cleaned_dataset/images/373aa369-6b07-41c2-adc3-87dabb1fc7ca_flux_1756079769.png: 640x640 1 potted plant, 9.7ms
# image 206/993 /content/merged_cleaned_dataset/images/377a278a-2196-4f20-a12d-d91fe6e48c40_flux_1756079803.png: 640x640 1 cup, 13.5ms
# image 207/993 /content/merged_cleaned_dataset/images/378a84d2-a4e5-47e1-aea7-cc4b6be14a32_flux_1756080811.png: 640x640 1 potted plant, 1 book, 9.3ms
# image 208/993 /content/merged_cleaned_dataset/images/37ecea88-62f9-43b5-9e05-91db58a60aa9_flux_1756078963.png: 640x640 1 potted plant, 2 books, 1 vase, 11.6ms
# image 209/993 /content/merged_cleaned_dataset/images/37fd7ca5-8af3-4f4f-84aa-3b40ff9b897f_flux_1756079681.png: 640x640 1 cup, 12.4ms
# image 210/993 /content/merged_cleaned_dataset/images/385bf0ad-03d1-4a67-b41e-61493d4de0cc_flux_1756080459.png: 640x640 1 chair, 12.9ms
# image 211/993 /content/merged_cleaned_dataset/images/3908788b-f948-410d-8f34-e92d10544d8a_flux_1756080800.png: 640x640 1 vase, 9.8ms
# image 212/993 /content/merged_cleaned_dataset/images/3945b6c8-3321-45b9-a500-4933601bdcb1_flux_1756079008.png: 640x640 1 potted plant, 1 vase, 11.2ms
# image 213/993 /content/merged_cleaned_dataset/images/39546bc8-7148-414d-8689-ede20573a238_flux_1756081477.png: 640x640 1 potted plant, 1 vase, 13.1ms
# image 214/993 /content/merged_cleaned_dataset/images/39ce4cdd-2d5b-4e9a-b4f5-de193027cb14_flux_1756080958.png: 640x640 1 potted plant, 12.7ms
# image 215/993 /content/merged_cleaned_dataset/images/39fca080-1f65-4a42-bbea-2786eb8e815c_flux_1756081448.png: 640x640 1 chair, 1 vase, 13.9ms
# image 216/993 /content/merged_cleaned_dataset/images/3a1d3b11-fff7-4f77-89ae-217a407a048f_flux_1756079134.png: 640x640 1 potted plant, 1 vase, 14.9ms
# image 217/993 /content/merged_cleaned_dataset/images/3a7290b1-67df-4ccc-af79-ebca8fee4140_flux_1756081496.png: 640x640 1 cup, 12.5ms
# image 218/993 /content/merged_cleaned_dataset/images/3a903948-3bc9-46df-9313-cf99a3d3de04_flux_1756080498.png: 640x640 (no detections), 12.9ms
# image 219/993 /content/merged_cleaned_dataset/images/3b76ac02-5435-4ecd-a6c3-83cef72c0efb_flux_1756082414.png: 640x640 1 book, 12.3ms
# image 220/993 /content/merged_cleaned_dataset/images/3bb9fd96-92ec-49d7-a64d-3b8753b3f0ec_flux_1756079832.png: 640x640 1 vase, 8.2ms
# image 221/993 /content/merged_cleaned_dataset/images/3bcc59fb-1282-40ba-bc4a-2663eeca2969_flux_1756080681.png: 640x640 1 chair, 8.2ms
# image 222/993 /content/merged_cleaned_dataset/images/3becf56b-cda0-4ff8-bf2d-1bb0fb04bca5_flux_1756079193.png: 640x640 1 chair, 1 potted plant, 1 vase, 8.2ms
# image 223/993 /content/merged_cleaned_dataset/images/3c489e90-9354-4768-b986-190aefb5a69b_flux_1756082116.png: 640x640 1 vase, 8.2ms
# image 224/993 /content/merged_cleaned_dataset/images/3c84639a-ae76-4209-a78d-5eab7955dfeb_flux_1756080906.png: 640x640 1 vase, 8.2ms
# image 225/993 /content/merged_cleaned_dataset/images/3ca78fbd-3149-495a-a611-1439c725ff1d_flux_1756080781.png: 640x640 2 chairs, 4 potted plants, 10.0ms
# image 226/993 /content/merged_cleaned_dataset/images/3cab4296-865b-4338-8b5b-17d500b18d27_flux_1756079423.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 227/993 /content/merged_cleaned_dataset/images/3cb2edf6-7aa8-43e4-8c2d-f52577fd4412_flux_1756079603.png: 640x640 1 chair, 8.2ms
# image 228/993 /content/merged_cleaned_dataset/images/3d4674c9-1eed-4654-a6af-0cab158f1f73_flux_1756080408.png: 640x640 (no detections), 8.2ms
# image 229/993 /content/merged_cleaned_dataset/images/3d474abf-85ed-4172-8e9b-d009c5e611ee_flux_1756082226.png: 640x640 1 vase, 8.2ms
# image 230/993 /content/merged_cleaned_dataset/images/3d4be69d-7878-4ea1-9a71-46be291d0836_flux_1756081644.png: 640x640 (no detections), 8.2ms
# image 231/993 /content/merged_cleaned_dataset/images/3d5bb8a4-ec0d-4c0d-a1b7-008e868c84fe_flux_1756081437.png: 640x640 (no detections), 8.2ms
# image 232/993 /content/merged_cleaned_dataset/images/3d81eb51-cd23-4d32-8c5d-e99fa64fd132_flux_1756079973.png: 640x640 1 potted plant, 8.2ms
# image 233/993 /content/merged_cleaned_dataset/images/3d82a23c-730e-43fa-979f-70f9b814c2de_flux_1756082083.png: 640x640 1 vase, 8.2ms
# image 234/993 /content/merged_cleaned_dataset/images/3d9ae6bb-4a7f-444d-93ce-189212e536bb_flux_1756080390.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 235/993 /content/merged_cleaned_dataset/images/3de99476-0a18-447c-b7fb-e5e3d975b2ec_flux_1756080884.png: 640x640 (no detections), 8.2ms
# image 236/993 /content/merged_cleaned_dataset/images/3e6fd7e2-2dd6-471b-9089-b1f479f7dd6e_flux_1756081328.png: 640x640 1 cup, 8.2ms
# image 237/993 /content/merged_cleaned_dataset/images/3ec1d650-46f5-4bec-90d8-693a0634bab2_flux_1756080264.png: 640x640 (no detections), 8.2ms
# image 238/993 /content/merged_cleaned_dataset/images/3f27c42d-a586-410b-ab2b-25410749f56f_flux_1756082263.png: 640x640 1 vase, 8.2ms
# image 239/993 /content/merged_cleaned_dataset/images/3f49f8c9-89cb-44a6-b9ce-4c1a41afe9b6_flux_1756080194.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 240/993 /content/merged_cleaned_dataset/images/3f6a51e1-0f12-426f-a432-a8d76830e5c2_flux_1756079185.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 241/993 /content/merged_cleaned_dataset/images/3f92d9fd-6c39-44c8-8bdd-b06bdfb9c852_flux_1756080172.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 242/993 /content/merged_cleaned_dataset/images/3fbcaccf-a98c-4947-bed8-bb1566b1ac0f_flux_1756079273.png: 640x640 1 cup, 8.2ms
# image 243/993 /content/merged_cleaned_dataset/images/405b0d57-7949-4a8c-adb4-b91a71a5aaa6_flux_1756079776.png: 640x640 1 potted plant, 8.2ms
# image 244/993 /content/merged_cleaned_dataset/images/40619609-7397-4ca1-894c-da380f7a81bb_flux_1756081100.png: 640x640 1 vase, 8.2ms
# image 245/993 /content/merged_cleaned_dataset/images/406d416b-3eb2-4196-ae41-5aba5838e22b_flux_1756081264.png: 640x640 (no detections), 8.2ms
# image 246/993 /content/merged_cleaned_dataset/images/409f191e-c1ac-4c07-b7f8-adf2a0bbe50a_flux_1756080586.png: 640x640 1 cup, 8.2ms
# image 247/993 /content/merged_cleaned_dataset/images/40ede778-93ef-4f51-9442-d02b3c20474a_flux_1756080108.png: 640x640 1 chair, 16.5ms
# image 248/993 /content/merged_cleaned_dataset/images/4157cab7-9819-4d82-a858-817f86d0f00c_flux_1756082407.png: 640x640 1 cup, 8.2ms
# image 249/993 /content/merged_cleaned_dataset/images/419a064b-2540-401b-a531-07494bf72f97_flux_1756079592.png: 640x640 1 cup, 8.2ms
# image 250/993 /content/merged_cleaned_dataset/images/41f96e07-8cb0-4ab4-a687-0962fca56132_flux_1756080707.png: 640x640 1 vase, 8.2ms
# image 251/993 /content/merged_cleaned_dataset/images/41faf946-66e7-4aa9-8bd4-c909c30ba02e_flux_1756080807.png: 640x640 1 cup, 9.8ms
# image 252/993 /content/merged_cleaned_dataset/images/42343668-b19f-467d-b331-6c4acddc1855_flux_1756079178.png: 640x640 1 potted plant, 13.1ms
# image 253/993 /content/merged_cleaned_dataset/images/4235b8e5-9ca4-45be-a9bf-be6f63faf199_flux_1756082322.png: 640x640 (no detections), 8.2ms
# image 254/993 /content/merged_cleaned_dataset/images/423c806f-670c-4f92-ba8f-7cac8cb974a7_flux_1756080932.png: 640x640 2 potted plants, 1 book, 1 vase, 8.2ms
# image 255/993 /content/merged_cleaned_dataset/images/4263b505-ed2a-4d4e-a622-8758d8110b07_flux_1756080183.png: 640x640 2 chairs, 1 potted plant, 8.2ms
# image 256/993 /content/merged_cleaned_dataset/images/428039c4-76f5-4f2e-8763-9da299b35222_flux_1756080224.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 257/993 /content/merged_cleaned_dataset/images/429a8acf-8f0e-4ca2-a2bf-04a1b4eabec1_flux_1756081655.png: 640x640 1 book, 8.2ms
# image 258/993 /content/merged_cleaned_dataset/images/42c5f6fa-ec56-419f-94d2-1d7fb24a2233_flux_1756081481.png: 640x640 1 chair, 8.2ms
# image 259/993 /content/merged_cleaned_dataset/images/42df4fbd-d053-4e95-a614-7921871bef62_flux_1756080331.png: 640x640 (no detections), 8.2ms
# image 260/993 /content/merged_cleaned_dataset/images/4323c5f6-8f29-4f89-a8e6-ac7f9018dcd5_flux_1756078727.png: 640x640 1 chair, 8.2ms
# image 261/993 /content/merged_cleaned_dataset/images/43a4dd78-1bf2-41ee-bfe1-47772ad2fd28_flux_1756082218.png: 640x640 1 chair, 9.3ms
# image 262/993 /content/merged_cleaned_dataset/images/43c66cee-cbce-4b1c-a754-d48bae6eb78b_flux_1756079034.png: 640x640 1 potted plant, 8.2ms
# image 263/993 /content/merged_cleaned_dataset/images/43e6dc87-3486-477a-8e66-ffa77358abb3_flux_1756079584.png: 640x640 1 cup, 8.2ms
# image 264/993 /content/merged_cleaned_dataset/images/43e8a3df-38bf-4b29-93b0-693e22795057_flux_1756079011.png: 640x640 1 chair, 5 potted plants, 8.2ms
# image 265/993 /content/merged_cleaned_dataset/images/44f8399c-6dcf-476c-a066-46a10ff9da8e_flux_1756081625.png: 640x640 (no detections), 8.2ms
# image 266/993 /content/merged_cleaned_dataset/images/457852ee-9781-458b-9af8-d103059229e0_flux_1756081463.png: 640x640 1 cup, 8.2ms
# image 267/993 /content/merged_cleaned_dataset/images/45a9a7cf-1d09-4845-be75-a679df9a3011_flux_1756081669.png: 640x640 2 chairs, 8.2ms
# image 268/993 /content/merged_cleaned_dataset/images/45ba895d-fcbe-49b1-9f1b-428e2d117111_flux_1756081622.png: 640x640 1 cup, 8.2ms
# image 269/993 /content/merged_cleaned_dataset/images/469dbfa2-295f-4e8a-8069-238983cfe3e9_flux_1756078790.png: 640x640 2 books, 8.2ms
# image 270/993 /content/merged_cleaned_dataset/images/46d344d9-4453-4b8c-9cc3-a0dc1b228777_flux_1756080623.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 271/993 /content/merged_cleaned_dataset/images/4749de5a-c0f6-4fb3-bc55-dd9a9283da3f_flux_1756079717.png: 640x640 1 cup, 8.2ms
# image 272/993 /content/merged_cleaned_dataset/images/479bf09d-4946-45a6-a5d8-c783da1d7822_flux_1756080466.png: 640x640 1 chair, 8.2ms
# image 273/993 /content/merged_cleaned_dataset/images/47a3aa28-3501-4aca-9f41-86b21027badb_flux_1756081441.png: 640x640 1 chair, 8.2ms
# image 274/993 /content/merged_cleaned_dataset/images/483827aa-d1d9-4acd-8992-963741dcc4d6_flux_1756081042.png: 640x640 2 cups, 1 chair, 1 potted plant, 8.2ms
# image 275/993 /content/merged_cleaned_dataset/images/487d66e4-6d88-44b8-9140-5e088d2d1f63_flux_1756081774.png: 640x640 1 chair, 8.6ms
# image 276/993 /content/merged_cleaned_dataset/images/488e9f4c-b7a2-42c9-8269-5fcfe1f56c1d_flux_1756080397.png: 640x640 2 cups, 1 potted plant, 8.2ms
# image 277/993 /content/merged_cleaned_dataset/images/491b3e4a-2f61-429b-a3ae-68928022b71c_flux_1756081193.png: 640x640 1 chair, 8.2ms
# image 278/993 /content/merged_cleaned_dataset/images/495c34dc-ecfd-4252-8ad4-f6b68e88824e_flux_1756079079.png: 640x640 1 cup, 8.2ms
# image 279/993 /content/merged_cleaned_dataset/images/4982f0ee-4e34-4432-8d60-81d015261190_flux_1756080419.png: 640x640 (no detections), 8.2ms
# image 280/993 /content/merged_cleaned_dataset/images/4a4a893e-7532-4684-9a5a-1970898d482d_flux_1756081122.png: 640x640 1 chair, 8.2ms
# image 281/993 /content/merged_cleaned_dataset/images/4aa4e312-19be-4e85-9874-7e1e2f5fb98f_flux_1756081034.png: 640x640 (no detections), 8.2ms
# image 282/993 /content/merged_cleaned_dataset/images/4aadfb91-b53e-4537-9458-a0e10e352929_flux_1756079086.png: 640x640 1 vase, 8.2ms
# image 283/993 /content/merged_cleaned_dataset/images/4ac45228-8b02-4b9c-b01f-43cd4b77c8b6_flux_1756079105.png: 640x640 1 chair, 8.2ms
# image 284/993 /content/merged_cleaned_dataset/images/4b403896-2b67-40f3-b22f-23af1e04b7fb_flux_1756081522.png: 640x640 (no detections), 8.2ms
# image 285/993 /content/merged_cleaned_dataset/images/4b53d319-4036-4163-9ef9-8cfcd8957646_flux_1756081256.png: 640x640 1 book, 1 vase, 8.2ms
# image 286/993 /content/merged_cleaned_dataset/images/4b66f6a4-82f9-4225-a226-c4d2f8a109b9_flux_1756080105.png: 640x640 1 potted plant, 8.2ms
# image 287/993 /content/merged_cleaned_dataset/images/4bfd6922-c9be-4750-8aa6-fea7d7e05191_flux_1756078757.png: 640x640 (no detections), 9.0ms
# image 288/993 /content/merged_cleaned_dataset/images/4c477d16-9468-4cc6-ba4f-388c465e2230_flux_1756080168.png: 640x640 2 potted plants, 8.6ms
# image 289/993 /content/merged_cleaned_dataset/images/4c844d1f-403f-4370-8e05-60bee0cf307e_flux_1756078720.png: 640x640 1 book, 8.2ms
# image 290/993 /content/merged_cleaned_dataset/images/4cbc357d-ef42-4047-b3cd-64dd8684d8e2_flux_1756080279.png: 640x640 (no detections), 13.0ms
# image 291/993 /content/merged_cleaned_dataset/images/4cca4683-b4ea-4ddb-85b8-2f20eb7d86c0_flux_1756081793.png: 640x640 4 vases, 8.2ms
# image 292/993 /content/merged_cleaned_dataset/images/4ced3813-4535-4e0a-8bec-fb812779b128_flux_1756079588.png: 640x640 1 potted plant, 2 vases, 8.2ms
# image 293/993 /content/merged_cleaned_dataset/images/4d016870-d932-45ce-8862-44bf4ebf0b41_flux_1756081867.png: 640x640 1 cup, 8.2ms
# image 294/993 /content/merged_cleaned_dataset/images/4d837d05-62cb-4401-a20a-78cbfb773991_flux_1756081556.png: 640x640 1 chair, 1 potted plant, 8.9ms
# image 295/993 /content/merged_cleaned_dataset/images/4ddb7436-9bb3-4927-8baa-11a223155c81_flux_1756081027.png: 640x640 1 chair, 8.2ms
# image 296/993 /content/merged_cleaned_dataset/images/4e0c69d2-bc0f-49b6-8a7d-a4d06c808678_flux_1756081778.png: 640x640 1 potted plant, 8.2ms
# image 297/993 /content/merged_cleaned_dataset/images/4e231b0b-5e7a-4b32-ae66-ae9bcceb9cb1_flux_1756081093.png: 640x640 1 potted plant, 9.2ms
# image 298/993 /content/merged_cleaned_dataset/images/4e2b3b1b-a859-48b6-a417-aab9a7b03ed3_flux_1756082060.png: 640x640 (no detections), 8.2ms
# image 299/993 /content/merged_cleaned_dataset/images/4e41a2cc-e00d-4424-9095-b713547fd2ee_flux_1756079233.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 300/993 /content/merged_cleaned_dataset/images/4e5fdbdf-71cd-4865-bb9f-26bf17e30184_flux_1756078940.png: 640x640 (no detections), 8.8ms
# image 301/993 /content/merged_cleaned_dataset/images/4e7bdfbf-05a5-4b7a-800a-4f2a98945bda_flux_1756079551.png: 640x640 1 chair, 8.2ms
# image 302/993 /content/merged_cleaned_dataset/images/4e9907a8-a3fb-4782-99ba-1d481d1a78e5_flux_1756079954.png: 640x640 3 chairs, 8.2ms
# image 303/993 /content/merged_cleaned_dataset/images/4f63c1b5-c63d-49fb-8b50-320d064ccc05_flux_1756081711.png: 640x640 1 chair, 8.2ms
# image 304/993 /content/merged_cleaned_dataset/images/4f79f90e-4836-4a7c-b8ae-08fce624d320_flux_1756079977.png: 640x640 (no detections), 8.7ms
# image 305/993 /content/merged_cleaned_dataset/images/4fdbe39d-8908-4394-ac66-7503258f662d_flux_1756082241.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 306/993 /content/merged_cleaned_dataset/images/50218e15-3da1-49a0-846f-c327e27150ee_flux_1756079626.png: 640x640 2 books, 8.2ms
# image 307/993 /content/merged_cleaned_dataset/images/503d5f37-e69b-4b55-af6c-e4f30a3d4b19_flux_1756080187.png: 640x640 1 cup, 8.2ms
# image 308/993 /content/merged_cleaned_dataset/images/505c0496-52a1-4e4f-a0b2-8a6d9869ad48_flux_1756079124.png: 640x640 1 chair, 8.2ms
# image 309/993 /content/merged_cleaned_dataset/images/50d90b19-ee0b-4ff0-a807-5a5f5b4850b0_flux_1756080836.png: 640x640 (no detections), 8.2ms
# image 310/993 /content/merged_cleaned_dataset/images/50f7ae87-b79b-442f-be02-1bc087fb5f94_flux_1756081946.png: 640x640 (no detections), 8.2ms
# image 311/993 /content/merged_cleaned_dataset/images/51953155-3557-4d6d-af5d-f6a6af055788_flux_1756079902.png: 640x640 2 cups, 1 chair, 1 vase, 8.2ms
# image 312/993 /content/merged_cleaned_dataset/images/51f245df-ef33-46fc-92bb-a244d9b5bfc2_flux_1756080011.png: 640x640 1 cup, 1 potted plant, 1 book, 8.2ms
# image 313/993 /content/merged_cleaned_dataset/images/52458976-5016-4040-805b-9f648ec5ace7_flux_1756082196.png: 640x640 1 book, 8.2ms
# image 314/993 /content/merged_cleaned_dataset/images/5268081d-281d-4615-89b5-71ada581cc1a_flux_1756079710.png: 640x640 1 chair, 8.2ms
# image 315/993 /content/merged_cleaned_dataset/images/52ad2768-36d4-4c08-9714-a162f55aa993_flux_1756080902.png: 640x640 1 vase, 8.2ms
# image 316/993 /content/merged_cleaned_dataset/images/52b07367-70e1-4b7b-9c66-763020535df4_flux_1756081382.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 317/993 /content/merged_cleaned_dataset/images/53250b70-5985-4f02-991c-10476571478d_flux_1756079341.png: 640x640 (no detections), 8.2ms
# image 318/993 /content/merged_cleaned_dataset/images/53706bde-8a15-46fa-972b-a14698e2540f_flux_1756080814.png: 640x640 1 cup, 8.2ms
# image 319/993 /content/merged_cleaned_dataset/images/53a48d08-2d69-4419-95b8-2c0e0d841dd6_flux_1756078694.png: 640x640 1 chair, 8.2ms
# image 320/993 /content/merged_cleaned_dataset/images/53c3a9a8-3a77-4f98-b262-f09acf39708a_flux_1756079052.png: 640x640 1 cup, 8.2ms
# image 321/993 /content/merged_cleaned_dataset/images/54515b8f-8e3e-452d-9679-67fce8bf669e_flux_1756081537.png: 640x640 (no detections), 8.2ms
# image 322/993 /content/merged_cleaned_dataset/images/54518000-9593-41b1-8e8d-c68ea90fb3e4_flux_1756079156.png: 640x640 2 vases, 8.2ms
# image 323/993 /content/merged_cleaned_dataset/images/54d104ed-4720-4d96-b2a3-e381d6f1c341_flux_1756081238.png: 640x640 (no detections), 8.2ms
# image 324/993 /content/merged_cleaned_dataset/images/555d424f-c67a-4e09-8699-ffcf17a1646d_flux_1756081503.png: 640x640 1 cup, 1 potted plant, 8.9ms
# image 325/993 /content/merged_cleaned_dataset/images/5609d736-dee2-4239-a8a1-6e64728d0fed_flux_1756080774.png: 640x640 1 cup, 1 vase, 8.2ms
# image 326/993 /content/merged_cleaned_dataset/images/5612e092-d355-4293-a46b-07bec526a633_flux_1756082171.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 327/993 /content/merged_cleaned_dataset/images/56274353-0dd3-47e2-b278-1785c77b5bdb_flux_1756079416.png: 640x640 1 vase, 8.3ms
# image 328/993 /content/merged_cleaned_dataset/images/562780d1-325f-496e-afed-2dfb019a7944_flux_1756081357.png: 640x640 (no detections), 16.2ms
# image 329/993 /content/merged_cleaned_dataset/images/563a0328-cbd4-4856-9332-bf410702b389_flux_1756082001.png: 640x640 1 cup, 1 vase, 8.2ms
# image 330/993 /content/merged_cleaned_dataset/images/56bae961-38d1-47a4-82f5-cc5f536572a2_flux_1756080509.png: 640x640 1 vase, 10.1ms
# image 331/993 /content/merged_cleaned_dataset/images/56e61f9a-2c88-4d52-af37-c4f0bafc6d49_flux_1756082094.png: 640x640 (no detections), 8.2ms
# image 332/993 /content/merged_cleaned_dataset/images/5749a0d6-7c36-4110-b35c-8ee5068c35e0_flux_1756078865.png: 640x640 1 chair, 8.2ms
# image 333/993 /content/merged_cleaned_dataset/images/57621e8f-028c-45d1-beb8-1b6462dd0744_flux_1756080157.png: 640x640 1 chair, 8.2ms
# image 334/993 /content/merged_cleaned_dataset/images/576358ca-8753-41c6-8c3d-7a935ceaaae1_flux_1756080752.png: 640x640 (no detections), 9.1ms
# image 335/993 /content/merged_cleaned_dataset/images/577193a1-f4bb-4f8b-ba7e-08c2c433e9ec_flux_1756080987.png: 640x640 1 chair, 8.2ms
# image 336/993 /content/merged_cleaned_dataset/images/578275c8-e26b-44d1-b883-ee1fccc4959c_flux_1756080480.png: 640x640 2 chairs, 8.2ms
# image 337/993 /content/merged_cleaned_dataset/images/57938a90-2a19-4027-81af-c5b61214c5c8_flux_1756080722.png: 640x640 1 chair, 2 potted plants, 1 vase, 8.1ms
# image 338/993 /content/merged_cleaned_dataset/images/57bfc584-8ff3-41e4-914e-bc1a4ac50e16_flux_1756080648.png: 640x640 1 vase, 8.2ms
# image 339/993 /content/merged_cleaned_dataset/images/57cfc2b7-1d74-40e9-8238-c74f15cc7c7a_flux_1756081823.png: 640x640 1 vase, 8.2ms
# image 340/993 /content/merged_cleaned_dataset/images/584d793f-0be6-49e3-a09a-797dd1986bac_flux_1756081897.png: 640x640 1 cup, 1 book, 8.2ms
# image 341/993 /content/merged_cleaned_dataset/images/5860452b-fec6-4414-8caf-a875a28588b7_flux_1756080873.png: 640x640 1 cup, 8.8ms
# image 342/993 /content/merged_cleaned_dataset/images/58bcc4d6-867e-4a8a-9f09-053b3b7970d0_flux_1756081688.png: 640x640 1 chair, 8.2ms
# image 343/993 /content/merged_cleaned_dataset/images/590274cb-4150-49cb-84ab-45ae5f62672e_flux_1756079659.png: 640x640 (no detections), 8.2ms
# ...
# image 881/993 /content/merged_cleaned_dataset/images/e42c314a-8f44-4a46-afa5-27d8f4b1f203_flux_1756079858.png: 640x640 1 vase, 8.3ms
# image 882/993 /content/merged_cleaned_dataset/images/e499094e-71a2-471f-a510-68b4c9c3018e_flux_1756081589.png: 640x640 1 cup, 8.2ms
# image 883/993 /content/merged_cleaned_dataset/images/e51eba6b-dd89-4962-b910-1089379fab77_flux_1756080994.png: 640x640 2 chairs, 1 potted plant, 1 vase, 8.2ms
# image 884/993 /content/merged_cleaned_dataset/images/e5435074-4c4a-4839-b951-5c28600453ba_flux_1756082105.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 885/993 /content/merged_cleaned_dataset/images/e5ad13e7-1142-4578-beae-43dbade34552_flux_1756082174.png: 640x640 1 potted plant, 8.2ms
# image 886/993 /content/merged_cleaned_dataset/images/e5f34029-6bd6-4791-9291-1cd6004ce760_flux_1756078742.png: 640x640 3 cups, 1 potted plant, 8.2ms
# image 887/993 /content/merged_cleaned_dataset/images/e60bea87-4964-4f63-84e0-c12636cbfc57_flux_1756082351.png: 640x640 1 vase, 8.2ms
# image 888/993 /content/merged_cleaned_dataset/images/e63c11ef-6b24-4929-9d7d-ed9623efba47_flux_1756081349.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 889/993 /content/merged_cleaned_dataset/images/e6c5de98-299d-4fe8-b2bd-8528fb068471_flux_1756080324.png: 640x640 1 cup, 8.2ms
# image 890/993 /content/merged_cleaned_dataset/images/e6fb6947-38c5-4eb3-9f1f-a2b3d6137423_flux_1756080488.png: 640x640 1 cup, 8.2ms
# image 891/993 /content/merged_cleaned_dataset/images/e7844c1d-573e-4828-b553-90864428f79b_flux_1756079518.png: 640x640 1 chair, 8.2ms
# image 892/993 /content/merged_cleaned_dataset/images/e7b9b64a-9226-4cb0-9f65-46f20f4990d9_flux_1756079026.png: 640x640 1 cup, 9.0ms
# image 893/993 /content/merged_cleaned_dataset/images/e7bbf9bb-3b35-439c-ba9b-54f95be50a1f_flux_1756081647.png: 640x640 1 chair, 1 vase, 8.2ms
# image 894/993 /content/merged_cleaned_dataset/images/e7da0808-f1a0-4671-af85-1169c3012d03_flux_1756078672.png: 640x640 (no detections), 8.2ms
# image 895/993 /content/merged_cleaned_dataset/images/e808c4de-0e5b-480e-a3d8-d4151bee01c7_flux_1756079023.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 896/993 /content/merged_cleaned_dataset/images/e82094a8-435c-4492-ae5a-cfec08d028d6_flux_1756080851.png: 640x640 1 book, 9.9ms
# image 897/993 /content/merged_cleaned_dataset/images/e88ed536-1168-46f5-b532-3b3a91514fb9_flux_1756081038.png: 640x640 1 cup, 8.2ms
# image 898/993 /content/merged_cleaned_dataset/images/e898a2d1-01f5-4175-9683-7c0638167238_flux_1756081379.png: 640x640 1 potted plant, 8.2ms
# image 899/993 /content/merged_cleaned_dataset/images/e8b94026-bcfb-4c33-9fc0-b16c4059bdd6_flux_1756082381.png: 640x640 (no detections), 13.6ms
# image 900/993 /content/merged_cleaned_dataset/images/e9173250-89c8-4fa2-b3f9-4fd7a1ef200c_flux_1756079754.png: 640x640 1 cup, 8.2ms
# image 901/993 /content/merged_cleaned_dataset/images/e948bddd-ea39-4a40-8afa-d6df1a8245d7_flux_1756079109.png: 640x640 1 cup, 8.2ms
# image 902/993 /content/merged_cleaned_dataset/images/e9600052-ad8c-4da7-8fa9-0115e068f961_flux_1756078944.png: 640x640 (no detections), 8.2ms
# image 903/993 /content/merged_cleaned_dataset/images/e9745bd1-d212-43ea-9f85-6712ec4525fa_flux_1756079536.png: 640x640 (no detections), 8.2ms
# image 904/993 /content/merged_cleaned_dataset/images/e9793b64-a7d8-44e4-a7b3-7779cfbead49_flux_1756078842.png: 640x640 1 chair, 1 vase, 8.2ms
# image 905/993 /content/merged_cleaned_dataset/images/e9c3444e-018b-4cd8-977b-0e6dec2e0b28_flux_1756080086.png: 640x640 1 cup, 1 chair, 9.8ms
# image 906/993 /content/merged_cleaned_dataset/images/e9e325e1-4c0b-4586-ac50-efe28f6ec834_flux_1756082167.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 907/993 /content/merged_cleaned_dataset/images/e9e6759e-1e8e-49fb-a236-07e8f6ddc0e7_flux_1756080161.png: 640x640 1 cup, 8.2ms
# image 908/993 /content/merged_cleaned_dataset/images/ea8dd713-6415-421a-96b7-21e5bac94a92_flux_1756081518.png: 640x640 1 vase, 8.2ms
# image 909/993 /content/merged_cleaned_dataset/images/eaea85ea-876d-4c79-bd0f-99acb0d208e1_flux_1756078887.png: 640x640 1 vase, 8.2ms
# image 910/993 /content/merged_cleaned_dataset/images/eb027c42-1511-49d9-8881-7c2554f62675_flux_1756081167.png: 640x640 1 cup, 8.2ms
# image 911/993 /content/merged_cleaned_dataset/images/eba1beb6-a77d-4241-8020-c422d9a868d5_flux_1756080213.png: 640x640 (no detections), 9.6ms
# image 912/993 /content/merged_cleaned_dataset/images/ebae7f1b-88fa-43ae-84be-ef3ff81b3730_flux_1756079780.png: 640x640 (no detections), 8.2ms
# image 913/993 /content/merged_cleaned_dataset/images/ebea687f-482c-4e8e-a5df-425cee5ccdfa_flux_1756080604.png: 640x640 1 chair, 8.2ms
# image 914/993 /content/merged_cleaned_dataset/images/ebf88bdd-c12a-4d6e-a1b8-1b421d1dc0af_flux_1756078661.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 915/993 /content/merged_cleaned_dataset/images/ecaf0cc2-74f5-42d1-a423-f06b56171ee8_flux_1756080231.png: 640x640 1 cup, 8.2ms
# image 916/993 /content/merged_cleaned_dataset/images/ecf263d6-d3b7-45f7-b846-f1f2576b53bd_flux_1756081673.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 917/993 /content/merged_cleaned_dataset/images/ed53d07f-d5fa-4d54-9ad9-4c27d86d9296_flux_1756079947.png: 640x640 1 cup, 1 vase, 8.4ms
# image 918/993 /content/merged_cleaned_dataset/images/edb73a6c-12d8-4e33-b171-3887184aa59c_flux_1756080770.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 919/993 /content/merged_cleaned_dataset/images/edbacb8b-7921-4c76-92ce-5a9db892d5a3_flux_1756079300.png: 640x640 (no detections), 8.2ms
# image 920/993 /content/merged_cleaned_dataset/images/ee1917cb-30ad-48b1-8dd2-c60ff37f81b9_flux_1756079270.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 921/993 /content/merged_cleaned_dataset/images/ee4b7ebe-23ff-4026-955c-e39ecb9cdff6_flux_1756079791.png: 640x640 1 chair, 1 vase, 8.2ms
# image 922/993 /content/merged_cleaned_dataset/images/ee5f309e-124c-4642-8fe3-ee653cc8e8ad_flux_1756080936.png: 640x640 1 vase, 8.2ms
# image 923/993 /content/merged_cleaned_dataset/images/ee837846-b1dc-40cd-874f-3379d9670240_flux_1756081488.png: 640x640 (no detections), 8.2ms
# image 924/993 /content/merged_cleaned_dataset/images/eeb0b36d-a161-4755-8c31-7cda551cbc2e_flux_1756081961.png: 640x640 2 cups, 8.2ms
# image 925/993 /content/merged_cleaned_dataset/images/ef68a476-2189-4214-a798-96a076cf695f_flux_1756081393.png: 640x640 (no detections), 8.5ms
# image 926/993 /content/merged_cleaned_dataset/images/efac38e6-16a3-4777-89f2-f8142a87c041_flux_1756081699.png: 640x640 1 cup, 8.2ms
# image 927/993 /content/merged_cleaned_dataset/images/efeb8d86-fbc2-4c64-bf68-ecb1a8e48da4_flux_1756082207.png: 640x640 1 potted plant, 8.2ms
# image 928/993 /content/merged_cleaned_dataset/images/f00275c6-fd61-4eb3-8a4d-c1d0ef31e555_flux_1756081920.png: 640x640 1 cup, 8.2ms
# image 929/993 /content/merged_cleaned_dataset/images/f03e6324-3fba-4441-9a3b-ce568790d27c_flux_1756079670.png: 640x640 1 potted plant, 2 vases, 8.3ms
# image 930/993 /content/merged_cleaned_dataset/images/f09b3eaa-f07c-4485-8def-caf9590210e7_flux_1756080346.png: 640x640 1 chair, 2 potted plants, 1 vase, 8.2ms
# image 931/993 /content/merged_cleaned_dataset/images/f0b81379-cade-4591-add9-8c9f7767305d_flux_1756079251.png: 640x640 (no detections), 8.2ms
# image 932/993 /content/merged_cleaned_dataset/images/f0c28297-70d3-4a8f-985b-5379b73598eb_flux_1756082403.png: 640x640 1 cup, 8.7ms
# image 933/993 /content/merged_cleaned_dataset/images/f0fd77e9-100b-4b93-9019-91e8e7892ad5_flux_1756079969.png: 640x640 1 cup, 8.2ms
# image 934/993 /content/merged_cleaned_dataset/images/f114f357-0c6e-47e2-8660-4b1b16b974b4_flux_1756079674.png: 640x640 (no detections), 8.2ms
# image 935/993 /content/merged_cleaned_dataset/images/f1b9be00-79e1-46bb-98c1-224774cf71a4_flux_1756080368.png: 640x640 (no detections), 8.2ms
# image 936/993 /content/merged_cleaned_dataset/images/f1cb4d08-88b5-4606-8871-8c5d7aecf50f_flux_1756082275.png: 640x640 (no detections), 8.2ms
# image 937/993 /content/merged_cleaned_dataset/images/f1dfc87b-fbb8-4866-a669-9f99aedfaa7f_flux_1756081819.png: 640x640 1 chair, 13.1ms
# image 938/993 /content/merged_cleaned_dataset/images/f20c965d-b7ce-4784-985a-4b9e79634c22_flux_1756079360.png: 640x640 1 vase, 8.2ms
# image 939/993 /content/merged_cleaned_dataset/images/f2271b59-09bd-4717-9b03-f6572351c9eb_flux_1756082030.png: 640x640 1 chair, 8.2ms
# image 940/993 /content/merged_cleaned_dataset/images/f327ce2f-f476-49aa-8c1a-95f008868f69_flux_1756080082.png: 640x640 1 vase, 8.2ms
# image 941/993 /content/merged_cleaned_dataset/images/f39a2f29-eb75-4c4d-94f7-21e1832b3855_flux_1756080840.png: 640x640 2 chairs, 1 vase, 8.2ms
# image 942/993 /content/merged_cleaned_dataset/images/f3ac8a7a-e17b-4ba3-b091-0a745a5c8191_flux_1756081570.png: 640x640 1 book, 8.2ms
# image 943/993 /content/merged_cleaned_dataset/images/f3d17fd8-24fb-47a9-a423-59873205948e_flux_1756078869.png: 640x640 1 book, 8.2ms
# image 944/993 /content/merged_cleaned_dataset/images/f3da8801-0d6b-4862-b0e2-f0f3ca4b4db2_flux_1756080328.png: 640x640 1 cup, 1 vase, 8.2ms
# image 945/993 /content/merged_cleaned_dataset/images/f442f479-5bfc-47de-aaea-66e9954d7867_flux_1756079843.png: 640x640 4 books, 9.0ms
# image 946/993 /content/merged_cleaned_dataset/images/f491d54f-37eb-42fe-bb08-0317f9e29712_flux_1756081302.png: 640x640 1 chair, 8.2ms
# image 947/993 /content/merged_cleaned_dataset/images/f4d323ce-a9b9-4d81-8a04-3608ed737dd7_flux_1756081375.png: 640x640 1 book, 8.2ms
# image 948/993 /content/merged_cleaned_dataset/images/f4db1868-0236-4ceb-9acb-41780f6520bd_flux_1756081882.png: 640x640 (no detections), 8.8ms
# image 949/993 /content/merged_cleaned_dataset/images/f4ebe5c1-1c65-4084-88f8-168ebffbe301_flux_1756079098.png: 640x640 1 cup, 8.2ms
# image 950/993 /content/merged_cleaned_dataset/images/f500ba27-0b01-4924-82c5-1bfb4ea03ef8_flux_1756080674.png: 640x640 1 book, 8.2ms
# image 951/993 /content/merged_cleaned_dataset/images/f519141b-d3c9-4d76-a66c-0219ca39a324_flux_1756079090.png: 640x640 1 cup, 8.2ms
# image 952/993 /content/merged_cleaned_dataset/images/f5608264-afb3-4349-8c75-702c79e5f5a7_flux_1756081733.png: 640x640 1 chair, 8.2ms
# image 953/993 /content/merged_cleaned_dataset/images/f65468f1-7ce2-46e8-916c-11f9ba463cd8_flux_1756081763.png: 640x640 2 chairs, 8.5ms
# image 954/993 /content/merged_cleaned_dataset/images/f672ac39-87af-436e-9c37-319dc0ba0648_flux_1756081346.png: 640x640 2 books, 1 vase, 8.2ms
# image 955/993 /content/merged_cleaned_dataset/images/f67aefc6-6310-47c3-8b2b-1a94bfa2e219_flux_1756079795.png: 640x640 2 chairs, 8.2ms
# image 956/993 /content/merged_cleaned_dataset/images/f6bf2c0d-d2e5-4f98-bf60-00f91fac62be_flux_1756078884.png: 640x640 1 cup, 1 book, 8.2ms
# image 957/993 /content/merged_cleaned_dataset/images/f73bad3d-7d14-4cde-b994-436be64f7b05_flux_1756080590.png: 640x640 1 vase, 8.3ms
# image 958/993 /content/merged_cleaned_dataset/images/f8a8d32a-b395-4f57-9bbd-b9684d3e4622_flux_1756079229.png: 640x640 1 cup, 8.2ms
# image 959/993 /content/merged_cleaned_dataset/images/f8ad4cd9-51ed-49a5-9095-2fe769f5b1b6_flux_1756080869.png: 640x640 1 cup, 8.2ms
# image 960/993 /content/merged_cleaned_dataset/images/f8aeb2b6-0387-4dc2-bdb3-ef5174093f67_flux_1756079000.png: 640x640 1 vase, 8.2ms
# image 961/993 /content/merged_cleaned_dataset/images/f8c68903-3292-4ce6-9b52-1b805cce7b43_flux_1756079196.png: 640x640 1 chair, 9.1ms
# image 962/993 /content/merged_cleaned_dataset/images/f910e424-885a-46f2-a6ca-19b4b38e9a44_flux_1756082333.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 963/993 /content/merged_cleaned_dataset/images/f9297bd5-5b1f-4606-b3a4-25f3e990ca1d_flux_1756080101.png: 640x640 1 vase, 8.2ms
# image 964/993 /content/merged_cleaned_dataset/images/f95d5d60-31e4-4211-ba48-f5f2a3a5297f_flux_1756078929.png: 640x640 (no detections), 8.2ms
# image 965/993 /content/merged_cleaned_dataset/images/f97a400e-c863-4c29-a19f-a38fec5ba0aa_flux_1756081411.png: 640x640 1 cup, 8.2ms
# image 966/993 /content/merged_cleaned_dataset/images/f998c8d8-176c-41c3-8419-8b5ad5aadabc_flux_1756079761.png: 640x640 (no detections), 8.2ms
# image 967/993 /content/merged_cleaned_dataset/images/f9aa79f0-4365-4fce-a198-d8b28a0acde3_flux_1756079041.png: 640x640 1 cup, 8.2ms
# image 968/993 /content/merged_cleaned_dataset/images/f9e2ce33-c9bb-40b3-adc6-9f73e099f64b_flux_1756079502.png: 640x640 3 cups, 1 chair, 1 potted plant, 10.7ms
# image 969/993 /content/merged_cleaned_dataset/images/fa5eebae-c854-4383-baa7-8420ec1f554d_flux_1756080630.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 970/993 /content/merged_cleaned_dataset/images/fa8ea711-948d-4db0-8324-a2f56ce9f3ab_flux_1756082388.png: 640x640 1 chair, 8.2ms
# image 971/993 /content/merged_cleaned_dataset/images/faba1ee7-36b7-4b1f-9711-547884c049f4_flux_1756081353.png: 640x640 (no detections), 8.3ms
# image 972/993 /content/merged_cleaned_dataset/images/fbb01c0a-45c4-4f95-844f-3f2cbb09015a_flux_1756081864.png: 640x640 1 cup, 8.2ms
# image 973/993 /content/merged_cleaned_dataset/images/fbb708e1-055c-44d4-a143-df9c2ae996f6_flux_1756081567.png: 640x640 1 book, 8.2ms
# image 974/993 /content/merged_cleaned_dataset/images/fbd05460-7440-4880-aa40-347cec3015aa_flux_1756082049.png: 640x640 1 cup, 14.3ms
# image 975/993 /content/merged_cleaned_dataset/images/fbd8ecaf-acd6-459b-bfb1-47fd24a9b175_flux_1756079045.png: 640x640 1 potted plant, 2 vases, 8.2ms
# image 976/993 /content/merged_cleaned_dataset/images/fc7fe2bb-dd08-4180-b5ca-018c058315d3_flux_1756078831.png: 640x640 1 chair, 8.2ms
# image 977/993 /content/merged_cleaned_dataset/images/fc919877-b6b5-47aa-b3fb-24f38e86359c_flux_1756079207.png: 640x640 1 chair, 8.2ms
# image 978/993 /content/merged_cleaned_dataset/images/fd204698-f37b-4fab-9613-844ab28420d8_flux_1756079435.png: 640x640 1 potted plant, 8.2ms
# image 979/993 /content/merged_cleaned_dataset/images/fd4b958f-1ea1-4c5e-9411-df7a76e99f6f_flux_1756079618.png: 640x640 1 cup, 9.2ms
# image 980/993 /content/merged_cleaned_dataset/images/fd7faaf4-dbcf-4b8e-b1b5-55283f1faaf0_flux_1756080748.png: 640x640 1 vase, 8.2ms
# image 981/993 /content/merged_cleaned_dataset/images/fd83b426-677a-496a-a880-c666fc0afe4e_flux_1756080253.png: 640x640 1 chair, 8.5ms
# image 982/993 /content/merged_cleaned_dataset/images/fe081c1b-a186-406c-92b1-bbfb045737a8_flux_1756080451.png: 640x640 1 cup, 12.6ms
# image 983/993 /content/merged_cleaned_dataset/images/fe2ab369-25a5-4b2c-971c-cd31c3a6ec22_flux_1756078849.png: 640x640 1 potted plant, 8.2ms
# image 984/993 /content/merged_cleaned_dataset/images/fe497f86-221a-4f37-b62a-2a116dca1a67_flux_1756082108.png: 640x640 1 cup, 8.2ms
# image 985/993 /content/merged_cleaned_dataset/images/fe498f37-6989-4649-a4dd-5125a81682b1_flux_1756081426.png: 640x640 2 chairs, 3 potted plants, 8.2ms
# image 986/993 /content/merged_cleaned_dataset/images/fe71821f-2fb7-4d6b-9d7f-97dae8fb574f_flux_1756080991.png: 640x640 (no detections), 8.2ms
# image 987/993 /content/merged_cleaned_dataset/images/febc3f83-08b5-407e-b98f-58f723679dd5_flux_1756078989.png: 640x640 1 cup, 8.2ms
# image 988/993 /content/merged_cleaned_dataset/images/fed56918-760d-4043-8fb0-5d0e4be6414b_flux_1756080887.png: 640x640 1 book, 8.2ms
# image 989/993 /content/merged_cleaned_dataset/images/ff59b836-1cde-416b-85a0-2c30c3ded392_flux_1756078676.png: 640x640 (no detections), 8.2ms
# image 990/993 /content/merged_cleaned_dataset/images/ff9376c9-b821-4f82-a0d9-d26070ea7e86_flux_1756079454.png: 640x640 2 potted plants, 8.2ms
# image 991/993 /content/merged_cleaned_dataset/images/ff9a0c40-fd15-427e-ad36-8e89c2ac6c79_flux_1756079318.png: 640x640 (no detections), 8.2ms
# image 992/993 /content/merged_cleaned_dataset/images/ffc4d71d-0d83-4d25-9229-15942ff76003_flux_1756080895.png: 640x640 1 chair, 9.4ms
# image 993/993 /content/merged_cleaned_dataset/images/ffe8acd0-e74b-49af-b156-1fb72aebfa16_flux_1756079304.png: 640x640 1 cup, 2 chairs, 3 potted plants, 1 vase, 8.2ms
# Speed: 3.5ms preprocess, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict
# 792 labels saved to /content/runs/detect/predict/labels
# ✅ 243 misclassified images found.
# 📁 All outputs saved inside 'misclassified_dataset/'

# %%
import csv

wrong_class = 0
missing_annotation = 0

with open("misclassified_dataset/misclassified_report.csv", newline="") as f:
    reader = csv.reader(f)
    next(reader)  # skip header
    for row in reader:
        reason = row[1]
        if reason == "Wrong Class":
            wrong_class += 1
        elif reason == "Missing Annotation":
            missing_annotation += 1

total = wrong_class + missing_annotation

print("Wrong Class:", wrong_class)
print("Missing Annotation:", missing_annotation)
print("Total Flagged:", total)
# Out:
# Wrong Class: 27
# Missing Annotation: 277
# Total Flagged: 304

# %%
import json

with open("misclassified_dataset/misclassified_coco.json") as f:
    coco = json.load(f)

total_annotations = len(coco["annotations"])
print("Total annotations in misclassified COCO JSON:", total_annotations)
# Out:
# Total annotations in misclassified COCO JSON: 825

# %%
#-----------------------------
# Merging the cvat export with original merged dataset
# upload merged_cvat_all.json before running this cell.
#-----------------------------

import json, copy, hashlib
import math

# ------------------------------
# Helper: IoU for two COCO bboxes
# bbox = [x, y, w, h]
# ------------------------------
def iou(b1, b2):
    x1, y1, w1, h1 = b1
    x2, y2, w2, h2 = b2

    xa = max(x1, x2)
    ya = max(y1, y2)
    xb = min(x1 + w1, x2 + w2)
    yb = min(y1 + h1, y2 + h2)

    inter_w = xb - xa
    inter_h = yb - ya
    if inter_w <= 0 or inter_h <= 0:
        return 0.0

    inter_area = inter_w * inter_h
    area1 = w1 * h1
    area2 = w2 * h2
    union_area = area1 + area2 - inter_area

    return inter_area / union_area if union_area > 0 else 0.0


# ------------------------------
# Helper: Hash annotation to detect exact duplicates
# ------------------------------
def hash_ann(a):
    txt = json.dumps({
        "category_id": a.get("category_id"),
        "bbox": a.get("bbox"),
        "segmentation": a.get("segmentation"),
        "area": a.get("area"),
        "iscrowd": a.get("iscrowd")
    }, sort_keys=True)
    return hashlib.md5(txt.encode()).hexdigest()


# ------------------------------
# Helper: category name → object
# ------------------------------
def index_by_name(cats):
    return {c["name"]: c for c in cats}


# ------------------------------
# Main function
# ------------------------------
def fix_and_merge(all_path, corrected_path, out_path, verbose=True,
                  iou_duplicate_threshold=0.90):

    # load both files
    with open(all_path, "r") as f:
        all_coco = json.load(f)
    with open(corrected_path, "r") as f:
        corr_coco = json.load(f)

    # final merged structure
    final = {
        "images": [],
        "annotations": [],
        "categories": [],
        "info": all_coco.get("info", {}),
        "licenses": all_coco.get("licenses", [])
    }

    # --------------------------------------------------------------------
    # STEP 1 — Merge categories (by name)
    # --------------------------------------------------------------------
    cats1 = all_coco.get("categories", [])
    cats2 = corr_coco.get("categories", [])

    final["categories"] = copy.deepcopy(cats1)
    name_to_cat = index_by_name(cats1)
    next_cat_id = max([c["id"] for c in cats1], default=0) + 1

    cat_map = {}

    for c in cats2:
        name = c["name"]
        if name in name_to_cat:
            cat_map[c["id"]] = name_to_cat[name]["id"]
        else:
            new_c = copy.deepcopy(c)
            new_c["id"] = next_cat_id
            final["categories"].append(new_c)
            name_to_cat[name] = new_c
            cat_map[c["id"]] = next_cat_id
            next_cat_id += 1

    # --------------------------------------------------------------------
    # STEP 2 — Merge images by file_name
    # --------------------------------------------------------------------
    img1 = all_coco.get("images", [])
    img2 = corr_coco.get("images", [])

    final["images"] = copy.deepcopy(img1)
    fname_to_id = {img["file_name"]: img["id"] for img in img1}
    next_img_id = max([img["id"] for img in img1], default=0) + 1

    img_map = {}

    for img in img2:
        fn = img["file_name"]
        if fn in fname_to_id:
            img_map[img["id"]] = fname_to_id[fn]
        else:
            new_img = copy.deepcopy(img)
            new_img["id"] = next_img_id
            final["images"].append(new_img)
            fname_to_id[fn] = next_img_id
            img_map[img["id"]] = next_img_id
            next_img_id += 1

    # --------------------------------------------------------------------
    # STEP 3 — Remove wrong annotations
    # --------------------------------------------------------------------
    corrected_filenames = {img["file_name"] for img in img2}
    corrected_image_ids = {
        fname_to_id[f] for f in corrected_filenames if f in fname_to_id
    }

    all_ann = all_coco.get("annotations", [])
    cleaned_all_ann = [
        ann for ann in all_ann
        if ann["image_id"] not in corrected_image_ids
    ]

    # --------------------------------------------------------------------
    # STEP 4 — Add corrected annotations (with ID remap)
    # --------------------------------------------------------------------
    final["annotations"] = cleaned_all_ann
    next_ann_id = max([a["id"] for a in cleaned_all_ann], default=0) + 1

    # store annotations by (image, category) for IoU dup detection
    ann_index = {}
    for a in cleaned_all_ann:
        key = (a["image_id"], a["category_id"])
        ann_index.setdefault(key, []).append(a)

    ann_hashes = {hash_ann(a) for a in cleaned_all_ann}

    added = 0
    skipped_iou = 0

    for ann in corr_coco.get("annotations", []):
        new_ann = copy.deepcopy(ann)
        new_ann["id"] = next_ann_id
        new_ann["image_id"] = img_map[new_ann["image_id"]]
        new_ann["category_id"] = cat_map[new_ann["category_id"]]

        key = (new_ann["image_id"], new_ann["category_id"])

        # ---- Step A: Exact duplicate detection
        h = hash_ann(new_ann)
        if h in ann_hashes:
            continue

        # ---- Step B: Near-duplicate IoU filtering
        existing_list = ann_index.get(key, [])
        is_duplicate = False
        for ex in existing_list:
            if iou(ex["bbox"], new_ann["bbox"]) > iou_duplicate_threshold:
                is_duplicate = True
                skipped_iou += 1
                break

        if is_duplicate:
            continue

        # add annotation
        ann_hashes.add(h)
        final["annotations"].append(new_ann)
        ann_index.setdefault(key, []).append(new_ann)
        next_ann_id += 1
        added += 1

    print(f"Added corrected annotations: {added}")
    print(f"Skipped near-duplicate boxes (IoU): {skipped_iou}")

    # --------------------------------------------------------------------
    # Save
    # --------------------------------------------------------------------
    with open(out_path, "w") as f:
        json.dump(final, f, indent=2)

    print("✅ Merged JSON saved as", out_path)

all_json_path = "merged_cleaned_dataset/merged_coco.json"
corrected_json_path = "merged_cvat_all.json"
output_path = "cleaned_merged_coco.json"

fix_and_merge(all_json_path, corrected_json_path, output_path, verbose=True)

print("Done!")
# Out:
# Added corrected annotations: 2048
# Skipped near-duplicate boxes (IoU): 91
# ✅ Merged JSON saved as cleaned_merged_coco.json
# Done!

# %%
import json

# Load the COCO JSON file
with open("cleaned_merged_coco.json") as f:  # replace with your JSON file path
    coco = json.load(f)

# Count total annotations
total_annotations = len(coco["annotations"])
print("Total annotations in COCO JSON:", total_annotations)

# count total images too
total_images = len(coco["images"])
print("Total images in COCO JSON:", total_images)
# Out:
# Total annotations in COCO JSON: 4599
# Total images in COCO JSON: 993

# %%
import os
import shutil
import csv
import json
from collections import defaultdict
from ultralytics import YOLO

# -----------------------------
# Paths
# -----------------------------
images_input_folder = "merged_cleaned_dataset/images"
coco_json_path = "cleaned_merged_coco.json"
output_folder = "new_misclassified_dataset"  # single output folder
images_output_folder = os.path.join(output_folder, "images")
os.makedirs(images_output_folder, exist_ok=True)

# -----------------------------
# Step 1. Run YOLO Predictions
# -----------------------------
model = YOLO("yolo11n.pt")

results = model.predict(
    source=images_input_folder,
    save=True,
    conf=0.5,
    classes=[58, 56, 41, 75, 73]  # COCO IDs for potted plant, chair, cup, vase, book
)

# -----------------------------
# Step 2. Class Mapping
# -----------------------------
coco_to_canonical = {58: 1, 56: 2, 41: 3, 75: 4, 73: 5}
canonical_names = {
    1: "potted plant", 2: "chair", 3: "cup", 4: "vase", 5: "book"
}

# -----------------------------
# Step 3. Load Ground Truth
# -----------------------------
with open(coco_json_path) as f:
    gt = json.load(f)

image_id_to_ann = defaultdict(list)
for ann in gt["annotations"]:
    image_id_to_ann[ann["image_id"]].append(ann)

image_id_to_name = {img["id"]: img["file_name"] for img in gt["images"]}

# -----------------------------
# Step 4. IOU Function
# -----------------------------
def iou(boxA, boxB):
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[0] + boxA[2], boxB[0] + boxB[2])
    yB = min(boxA[1] + boxA[3], boxB[1] + boxB[3])
    inter = max(0, xB - xA) * max(0, yB - yA)
    union = boxA[2]*boxA[3] + boxB[2]*boxB[3] - inter
    return inter / union if union > 0 else 0

# -----------------------------
# Step 5. Compare Predictions vs GT
# -----------------------------
misclassified_images = set()
report_rows = []
iou_threshold = 0.4

for result in results:
    file_name = os.path.basename(result.path)

    # Match GT image id
    image_id = next((img["id"] for img in gt["images"] if img["file_name"] == file_name), None)
    if image_id is None:
        continue

    gt_boxes = [(ann["bbox"], ann["category_id"]) for ann in image_id_to_ann[image_id]]

    preds = []
    for box in result.boxes:
        coco_id = int(box.cls.cpu().numpy()[0])
        if coco_id in coco_to_canonical:
            pred_class = coco_to_canonical[coco_id]
            xyxy = box.xyxy.cpu().numpy()[0]
            w, h = xyxy[2] - xyxy[0], xyxy[3] - xyxy[1]
            preds.append(([float(xyxy[0]), float(xyxy[1]), float(w), float(h)], pred_class))

    matched_preds = set()

    # GT vs Preds
    for gt_box, gt_cls in gt_boxes:
        for i, (pred_box, pred_cls) in enumerate(preds):
            if i not in matched_preds and iou(gt_box, pred_box) >= iou_threshold:
                matched_preds.add(i)
                if pred_cls != gt_cls:
                    misclassified_images.add(file_name)
                    report_rows.append([file_name, "Wrong Class",
                                        canonical_names[gt_cls],
                                        canonical_names[pred_cls],
                                        round(iou(gt_box, pred_box), 3)])

    # Extra Predictions = Missing GT annotations
    for i, (pred_box, pred_cls) in enumerate(preds):
        if i not in matched_preds:
            misclassified_images.add(file_name)
            report_rows.append([file_name, "Missing Annotation", "None",
                                canonical_names[pred_cls], 0.0])

# -----------------------------
# Step 6. Create COCO JSON with misclassified images
# -----------------------------
misclassified_gt = {
    "images": [img for img in gt["images"] if img["file_name"] in misclassified_images],
    "annotations": [ann for ann in gt["annotations"]
                    if image_id_to_name[ann["image_id"]] in misclassified_images],
    "categories": gt["categories"]
}

with open(os.path.join(output_folder, "misclassified_coco.json"), "w") as f:
    json.dump(misclassified_gt, f, indent=2)

# -----------------------------
# Step 7. Copy misclassified images to new_dataset/images
# -----------------------------
for img in misclassified_gt["images"]:
    src = os.path.join(images_input_folder, img["file_name"])
    dst = os.path.join(images_output_folder, img["file_name"])
    if os.path.exists(src):
        shutil.copy2(src, dst)

# -----------------------------
# Step 8. Save CSV report
# -----------------------------
with open(os.path.join(output_folder, "misclassified_report.csv"), "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Image", "Reason", "GroundTruth", "Prediction", "IOU"])
    writer.writerows(report_rows)

print(f"✅ {len(misclassified_gt['images'])} misclassified images found.")
print(f"📁 All outputs saved inside '{output_folder}/'")
# Out:
# image 1/993 /content/merged_cleaned_dataset/images/0067dc2e-4bb7-48a2-b9c5-9da631f86595_flux_1756081928.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 2/993 /content/merged_cleaned_dataset/images/007abd03-fa5e-43d8-af0a-fbed58e17821_flux_1756081085.png: 640x640 (no detections), 8.4ms
# image 3/993 /content/merged_cleaned_dataset/images/00f8644a-c4af-4097-a0bc-e8af706554ce_flux_1756082211.png: 640x640 1 vase, 8.2ms
# image 4/993 /content/merged_cleaned_dataset/images/0142ef49-931a-46b3-a841-452224567d33_flux_1756079514.png: 640x640 1 chair, 8.2ms
# image 5/993 /content/merged_cleaned_dataset/images/01a1e58d-cdf5-4de9-8c35-bf4a9e741350_flux_1756079529.png: 640x640 1 chair, 1 vase, 8.2ms
# image 6/993 /content/merged_cleaned_dataset/images/02534685-590c-4899-a048-c9371666f4b6_flux_1756080506.png: 640x640 1 cup, 1 book, 8.2ms
# image 7/993 /content/merged_cleaned_dataset/images/02de1ef0-1130-473d-9d2a-425b231ebdd2_flux_1756080597.png: 640x640 1 chair, 2 potted plants, 8.8ms
# image 8/993 /content/merged_cleaned_dataset/images/02e220f1-583c-4f22-9ded-d01b8ffdc466_flux_1756078698.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 9/993 /content/merged_cleaned_dataset/images/0305fc14-9c1f-4b9e-b08b-33d199bc022f_flux_1756081386.png: 640x640 1 chair, 8.2ms
# image 10/993 /content/merged_cleaned_dataset/images/0313d4d2-c1b6-411a-9d0d-e29714a0d27e_flux_1756081964.png: 640x640 2 chairs, 2 potted plants, 1 book, 8.2ms
# image 11/993 /content/merged_cleaned_dataset/images/031b2fd0-366f-4a7f-b317-8d9eb7c3e8c3_flux_1756079420.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 12/993 /content/merged_cleaned_dataset/images/036c2df1-bd35-4212-b519-470036c3b938_flux_1756079758.png: 640x640 (no detections), 8.2ms
# image 13/993 /content/merged_cleaned_dataset/images/03a1ad66-b5fa-42cb-b86a-91bc0f3ac0fe_flux_1756079951.png: 640x640 1 cup, 8.2ms
# image 14/993 /content/merged_cleaned_dataset/images/03af0e86-1d0e-4470-ae4a-dc34f3129c16_flux_1756082373.png: 640x640 (no detections), 8.2ms
# image 15/993 /content/merged_cleaned_dataset/images/04207281-836e-437d-a637-028329a89ae5_flux_1756081815.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 16/993 /content/merged_cleaned_dataset/images/045ad3e2-b4ee-42ee-aec8-aaee1ee006eb_flux_1756081190.png: 640x640 (no detections), 8.2ms
# image 17/993 /content/merged_cleaned_dataset/images/048ae3ab-e6a0-4416-b875-9348e9dd580a_flux_1756081893.png: 640x640 1 potted plant, 8.2ms
# image 18/993 /content/merged_cleaned_dataset/images/04cafbb4-51b2-4bab-93e8-03db568c6655_flux_1756079688.png: 640x640 1 cup, 2 chairs, 8.2ms
# image 19/993 /content/merged_cleaned_dataset/images/04d6d431-2ff9-4e83-83e0-479b89937996_flux_1756081548.png: 640x640 1 chair, 8.2ms
# image 20/993 /content/merged_cleaned_dataset/images/0501aa30-2c53-4c0b-990d-584d1a070ee3_flux_1756079487.png: 640x640 1 book, 8.2ms
# image 21/993 /content/merged_cleaned_dataset/images/05bc3295-5c9a-4af6-8c24-5e288f296dc3_flux_1756079666.png: 640x640 2 chairs, 8.2ms
# image 22/993 /content/merged_cleaned_dataset/images/05ed35e5-bb41-47be-9659-d7707bc9d7a5_flux_1756079015.png: 640x640 1 vase, 8.2ms
# image 23/993 /content/merged_cleaned_dataset/images/0602c753-62b6-4edc-baa2-8f69d742559c_flux_1756081707.png: 640x640 1 chair, 8.2ms
# image 24/993 /content/merged_cleaned_dataset/images/0657bc9a-0ef1-40f0-bed8-f79fe2930e43_flux_1756082234.png: 640x640 (no detections), 8.2ms
# image 25/993 /content/merged_cleaned_dataset/images/065f1468-77e8-45a9-aa4a-6654433155c6_flux_1756079854.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 26/993 /content/merged_cleaned_dataset/images/076ecd94-ec78-4ebb-9b5f-7dc08e2632bf_flux_1756079924.png: 640x640 1 chair, 8.2ms
# image 27/993 /content/merged_cleaned_dataset/images/07fbd8c0-bc84-4f1f-865d-2f1def35de3c_flux_1756081279.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 28/993 /content/merged_cleaned_dataset/images/080eb723-6968-4486-b278-4fcbda0585ad_flux_1756079732.png: 640x640 2 chairs, 1 potted plant, 8.2ms
# image 29/993 /content/merged_cleaned_dataset/images/0855c460-0a0e-4ddf-9415-8ed89c7edfe1_flux_1756081260.png: 640x640 1 cup, 8.2ms
# image 30/993 /content/merged_cleaned_dataset/images/0887c71c-83e7-496f-92a5-4dd49c9a3529_flux_1756082304.png: 640x640 (no detections), 8.2ms
# image 31/993 /content/merged_cleaned_dataset/images/089b2eda-c8f1-451a-95aa-cf4c01d781bd_flux_1756081186.png: 640x640 1 chair, 8.2ms
# image 32/993 /content/merged_cleaned_dataset/images/08d7da45-3766-4cca-822c-f3cbbe0094a1_flux_1756081152.png: 640x640 (no detections), 8.2ms
# image 33/993 /content/merged_cleaned_dataset/images/09139aed-2e54-48cc-9927-dfa6e6b67d32_flux_1756079743.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 34/993 /content/merged_cleaned_dataset/images/09316c29-0615-4cca-8b43-6cf62da1e93d_flux_1756082027.png: 640x640 (no detections), 12.6ms
# image 35/993 /content/merged_cleaned_dataset/images/093da434-adb5-4b17-86fb-b220e71bee4e_flux_1756079390.png: 640x640 1 cup, 1 chair, 8.2ms
# image 36/993 /content/merged_cleaned_dataset/images/096733a4-ba23-4f6f-a64b-0c51c5e63117_flux_1756080692.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 37/993 /content/merged_cleaned_dataset/images/09996aab-4e48-4869-b0a7-6e985b6f242c_flux_1756080763.png: 640x640 1 cup, 1 book, 8.2ms
# image 38/993 /content/merged_cleaned_dataset/images/09bb2498-1d0a-4573-9e94-838f8e3ca14f_flux_1756079562.png: 640x640 1 cup, 8.2ms
# image 39/993 /content/merged_cleaned_dataset/images/09ff73e4-46a9-472c-a2ab-b6effb256d93_flux_1756081607.png: 640x640 1 cup, 10.5ms
# image 40/993 /content/merged_cleaned_dataset/images/0a1352cf-09ef-45a7-a0c4-4cf92d5795e9_flux_1756078925.png: 640x640 1 cup, 1 potted plant, 2 vases, 8.2ms
# image 41/993 /content/merged_cleaned_dataset/images/0a7a287a-d25a-472c-8c40-3876a3a60cbe_flux_1756080063.png: 640x640 2 vases, 10.5ms
# image 42/993 /content/merged_cleaned_dataset/images/0b05dc0d-d4ce-454d-a30e-5eb7368c5ab3_flux_1756081016.png: 640x640 1 cup, 8.2ms
# image 43/993 /content/merged_cleaned_dataset/images/0b1ee1d5-6e0f-4a18-a3ca-ba3dcc8b5f73_flux_1756080003.png: 640x640 1 chair, 8.2ms
# image 44/993 /content/merged_cleaned_dataset/images/0b86344b-45de-4e1d-a4de-7a7a3e45ba14_flux_1756079356.png: 640x640 1 chair, 8.2ms
# image 45/993 /content/merged_cleaned_dataset/images/0bc6ae52-b8d9-472b-816b-4c23db2afa37_flux_1756080257.png: 640x640 (no detections), 8.2ms
# image 46/993 /content/merged_cleaned_dataset/images/0bde8b01-4f2f-403f-ad35-468fe14a2601_flux_1756082370.png: 640x640 1 vase, 8.2ms
# image 47/993 /content/merged_cleaned_dataset/images/0c0d297e-075b-4e3a-ab04-610291993f94_flux_1756081796.png: 640x640 1 cup, 10.0ms
# image 48/993 /content/merged_cleaned_dataset/images/0d98007a-a323-46f2-9681-58e3b46a7e6c_flux_1756079696.png: 640x640 (no detections), 8.2ms
# image 49/993 /content/merged_cleaned_dataset/images/0da0d28f-f140-4ee3-be21-052e16c5d768_flux_1756080455.png: 640x640 1 chair, 8.2ms
# image 50/993 /content/merged_cleaned_dataset/images/0df5d159-76ae-4908-8f60-a3a03d0c1e8b_flux_1756080317.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 51/993 /content/merged_cleaned_dataset/images/0e5d32ff-82ac-401a-9792-9858476bf79c_flux_1756081651.png: 640x640 (no detections), 8.2ms
# image 52/993 /content/merged_cleaned_dataset/images/0eff620f-f1a8-4e6e-8d6d-3dbc57f730d1_flux_1756081983.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 53/993 /content/merged_cleaned_dataset/images/0f7a21d4-2a63-4e3d-bf0c-f5c662ca1a7b_flux_1756080473.png: 640x640 1 cup, 8.2ms
# image 54/993 /content/merged_cleaned_dataset/images/0f7c504e-7c0c-4f06-aef8-116db375ba23_flux_1756080429.png: 640x640 1 cup, 2 chairs, 8.2ms
# image 55/993 /content/merged_cleaned_dataset/images/0fde6ff6-3b80-4f72-8e87-439434726818_flux_1756081703.png: 640x640 (no detections), 8.2ms
# image 56/993 /content/merged_cleaned_dataset/images/0ff1599f-aa2f-4b80-9ba7-64c80282ae07_flux_1756081950.png: 640x640 1 cup, 8.2ms
# image 57/993 /content/merged_cleaned_dataset/images/104b6c25-7e6a-433f-8c45-de9ffeca331a_flux_1756080386.png: 640x640 1 potted plant, 1 vase, 8.4ms
# image 58/993 /content/merged_cleaned_dataset/images/1075c685-3561-45cc-919a-107248cae56d_flux_1756081785.png: 640x640 2 chairs, 8.2ms
# image 59/993 /content/merged_cleaned_dataset/images/112c004e-9f51-4735-8682-54fcf7a720f4_flux_1756081770.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 60/993 /content/merged_cleaned_dataset/images/11aa118c-4af9-4df8-9c90-4a8b602ae5d1_flux_1756079566.png: 640x640 1 chair, 8.2ms
# image 61/993 /content/merged_cleaned_dataset/images/11ae083d-ed88-4510-b37f-7cff3f2c3f26_flux_1756079703.png: 640x640 (no detections), 8.2ms
# image 62/993 /content/merged_cleaned_dataset/images/11b7f387-309f-49a7-91ca-1c7c6bcfce2a_flux_1756081658.png: 640x640 (no detections), 8.2ms
# image 63/993 /content/merged_cleaned_dataset/images/12439e46-758b-4d6e-8d05-55b020c6adc9_flux_1756080361.png: 640x640 1 potted plant, 1 vase, 8.5ms
# image 64/993 /content/merged_cleaned_dataset/images/124feba8-dfff-47ad-9d4e-a5226cde2ccc_flux_1756081219.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 65/993 /content/merged_cleaned_dataset/images/1278f02f-b6c0-446f-8518-7395a0769669_flux_1756081596.png: 640x640 1 cup, 8.2ms
# image 66/993 /content/merged_cleaned_dataset/images/1283017b-a569-4b43-a92d-d9cf58e8b405_flux_1756079259.png: 640x640 1 cup, 8.2ms
# image 67/993 /content/merged_cleaned_dataset/images/12bce271-294a-4584-b9ca-4a8e7be53bd6_flux_1756078812.png: 640x640 1 cup, 8.2ms
# image 68/993 /content/merged_cleaned_dataset/images/12d3c3d3-9369-468b-a1d2-ec6a382f58b4_flux_1756081636.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 69/993 /content/merged_cleaned_dataset/images/130fed4d-480d-4d6c-9e9d-b8b2af0dfeb7_flux_1756081935.png: 640x640 1 book, 8.2ms
# image 70/993 /content/merged_cleaned_dataset/images/13234045-cccc-4d01-8f00-5e7eeb92fdf2_flux_1756081492.png: 640x640 1 book, 8.3ms
# image 71/993 /content/merged_cleaned_dataset/images/1399e237-dc3b-4c83-8102-83579b9ff1ba_flux_1756081309.png: 640x640 (no detections), 8.2ms
# image 72/993 /content/merged_cleaned_dataset/images/139c2a53-fc0a-4f66-96c9-68fe63bd055c_flux_1756081748.png: 640x640 2 vases, 8.2ms
# image 73/993 /content/merged_cleaned_dataset/images/13ab4421-d2c8-45b5-afbb-b83dd16fbe00_flux_1756079648.png: 640x640 1 potted plant, 8.2ms
# image 74/993 /content/merged_cleaned_dataset/images/14075113-1329-4dab-b88a-6370862a2f6b_flux_1756082249.png: 640x640 (no detections), 13.5ms
# image 75/993 /content/merged_cleaned_dataset/images/1430d9bb-e7ad-4caf-974f-bc0403f416b8_flux_1756081916.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 76/993 /content/merged_cleaned_dataset/images/14595165-b881-411b-80de-6b9f12dcf3f1_flux_1756078880.png: 640x640 1 chair, 8.2ms
# image 77/993 /content/merged_cleaned_dataset/images/146b79cf-9499-4db0-8a94-b67c2d7c1689_flux_1756082318.png: 640x640 1 cup, 1 chair, 1 vase, 8.2ms
# image 78/993 /content/merged_cleaned_dataset/images/14a8a6d3-11f3-47c6-a26d-40ab390f14bd_flux_1756079277.png: 640x640 1 cup, 8.2ms
# image 79/993 /content/merged_cleaned_dataset/images/153e32cc-1e55-41d4-89ea-0c4f7b33f396_flux_1756079787.png: 640x640 1 chair, 8.2ms
# image 80/993 /content/merged_cleaned_dataset/images/15700d53-0eb0-4d98-a0f3-be1336a64b8b_flux_1756081514.png: 640x640 (no detections), 8.2ms
# image 81/993 /content/merged_cleaned_dataset/images/15a86e84-2c87-429f-afbc-961dcc87dc2f_flux_1756079699.png: 640x640 1 book, 8.2ms
# image 82/993 /content/merged_cleaned_dataset/images/15c66ce6-df8b-4919-b019-81b329451e42_flux_1756081729.png: 640x640 1 chair, 8.2ms
# image 83/993 /content/merged_cleaned_dataset/images/1604d64b-dedf-4e0c-9e70-31834a51c87c_flux_1756082425.png: 640x640 1 vase, 8.2ms
# image 84/993 /content/merged_cleaned_dataset/images/16258fb6-7886-416b-9527-d05f39222afc_flux_1756079397.png: 640x640 1 cup, 8.2ms
# image 85/993 /content/merged_cleaned_dataset/images/1650e522-c712-4543-adcb-948ffc7c06d8_flux_1756079153.png: 640x640 (no detections), 8.2ms
# image 86/993 /content/merged_cleaned_dataset/images/166e2fc5-5e2f-4520-bde0-01d6bff6665b_flux_1756082289.png: 640x640 1 vase, 9.9ms
# image 87/993 /content/merged_cleaned_dataset/images/16828bab-2ebe-43d9-8a57-2b7ffb4726c2_flux_1756082016.png: 640x640 1 potted plant, 1 book, 1 vase, 8.2ms
# image 88/993 /content/merged_cleaned_dataset/images/16ac950a-6374-4467-b663-2e6e4d80a648_flux_1756079375.png: 640x640 1 cup, 8.2ms
# image 89/993 /content/merged_cleaned_dataset/images/17153dbd-930e-4aed-bf1c-b6de81250f6a_flux_1756079030.png: 640x640 (no detections), 9.1ms
# image 90/993 /content/merged_cleaned_dataset/images/1719426f-a7f4-46ed-b3bb-6706a023fa73_flux_1756081129.png: 640x640 1 book, 8.2ms
# image 91/993 /content/merged_cleaned_dataset/images/1719c1df-346c-4df3-a0a6-82dda3a62458_flux_1756078838.png: 640x640 1 potted plant, 1 book, 12.8ms
# image 92/993 /content/merged_cleaned_dataset/images/172efd0b-be31-4d0b-8945-a8a55351fe14_flux_1756078808.png: 640x640 (no detections), 13.0ms
# image 93/993 /content/merged_cleaned_dataset/images/17734e78-cb33-4ddf-ba77-cc52dab5634b_flux_1756079821.png: 640x640 2 chairs, 1 potted plant, 14.1ms
# image 94/993 /content/merged_cleaned_dataset/images/19164952-106d-48f3-98f8-fbccd4d7a092_flux_1756080822.png: 640x640 1 cup, 9.8ms
# image 95/993 /content/merged_cleaned_dataset/images/191b590b-bf59-497b-b1d0-06c3c59730a8_flux_1756081049.png: 640x640 (no detections), 11.9ms
# image 96/993 /content/merged_cleaned_dataset/images/19739bc9-57f4-4f5a-9bb1-d53a219338af_flux_1756080513.png: 640x640 1 potted plant, 1 vase, 9.2ms
# image 97/993 /content/merged_cleaned_dataset/images/19a1243b-f2e9-4800-aae4-21f4319a2a2c_flux_1756081294.png: 640x640 1 book, 9.8ms
# image 98/993 /content/merged_cleaned_dataset/images/19ac98bd-9206-4ab6-998a-33583fe32abb_flux_1756079326.png: 640x640 1 cup, 2 books, 11.0ms
# image 99/993 /content/merged_cleaned_dataset/images/19b18126-17c8-400f-8364-41a72b941cfc_flux_1756081317.png: 640x640 1 vase, 10.4ms
# image 100/993 /content/merged_cleaned_dataset/images/19b8c491-c209-4497-af70-8a5c585e59db_flux_1756079386.png: 640x640 1 cup, 9.1ms
# image 101/993 /content/merged_cleaned_dataset/images/19f04d49-8ec6-4809-afb2-35bee8629828_flux_1756082127.png: 640x640 2 books, 1 vase, 9.1ms
# image 102/993 /content/merged_cleaned_dataset/images/1a241c1c-7ba8-40ba-b79b-c8d3105c5c00_flux_1756080612.png: 640x640 (no detections), 9.9ms
# image 103/993 /content/merged_cleaned_dataset/images/1ae697af-90f4-4ff3-b1a9-a150b13f33a5_flux_1756080803.png: 640x640 1 cup, 9.6ms
# image 104/993 /content/merged_cleaned_dataset/images/1b25b375-700d-4a33-a7c4-9e9b29eb4395_flux_1756079596.png: 640x640 (no detections), 9.9ms
# image 105/993 /content/merged_cleaned_dataset/images/1bb8185c-e7a1-4998-a5c8-4ba00a62be58_flux_1756079663.png: 640x640 1 cup, 9.4ms
# image 106/993 /content/merged_cleaned_dataset/images/1bbd6032-1d7b-408b-9347-f6aa90dcd836_flux_1756080134.png: 640x640 (no detections), 9.6ms
# image 107/993 /content/merged_cleaned_dataset/images/1c37f4a7-c67d-4c40-82ea-8efcad037daa_flux_1756078974.png: 640x640 1 cup, 1 chair, 9.4ms
# image 108/993 /content/merged_cleaned_dataset/images/1d2233a6-80c5-472e-979a-68124bcb2915_flux_1756082271.png: 640x640 1 cup, 11.2ms
# image 109/993 /content/merged_cleaned_dataset/images/1da9824f-d5cf-46cc-a951-51f33f8b758e_flux_1756079067.png: 640x640 1 book, 11.0ms
# image 110/993 /content/merged_cleaned_dataset/images/1dc3be62-3100-4a70-aac6-4b28b273c450_flux_1756079547.png: 640x640 1 vase, 9.5ms
# image 111/993 /content/merged_cleaned_dataset/images/1e265db6-4462-495e-9740-25ba1b4bad2f_flux_1756081804.png: 640x640 1 potted plant, 1 vase, 10.0ms
# image 112/993 /content/merged_cleaned_dataset/images/1ef6741e-0384-4404-b584-864f2548e621_flux_1756080313.png: 640x640 (no detections), 9.7ms
# image 113/993 /content/merged_cleaned_dataset/images/1f0d222d-a03f-4e5f-9c4f-bf4a5d7c676e_flux_1756078669.png: 640x640 1 potted plant, 2 vases, 9.5ms
# image 114/993 /content/merged_cleaned_dataset/images/1f6b7dca-adac-48f7-80b6-60e690af2569_flux_1756081834.png: 640x640 1 vase, 9.9ms
# image 115/993 /content/merged_cleaned_dataset/images/1fb85fe1-b254-43d7-8fbc-09b1b43dc1b3_flux_1756080375.png: 640x640 2 chairs, 1 vase, 9.7ms
# image 116/993 /content/merged_cleaned_dataset/images/20190ce9-3a4f-4529-921b-158cb40b9750_flux_1756079094.png: 640x640 1 cup, 9.9ms
# image 117/993 /content/merged_cleaned_dataset/images/202a6dde-076f-4e9e-a519-88cf52284e6d_flux_1756081752.png: 640x640 (no detections), 9.8ms
# image 118/993 /content/merged_cleaned_dataset/images/2097d4ab-56bc-481d-958a-5b98be83f93a_flux_1756080382.png: 640x640 2 chairs, 1 vase, 10.8ms
# image 119/993 /content/merged_cleaned_dataset/images/21436951-1371-49d9-99fe-34ebadb894e5_flux_1756078760.png: 640x640 1 potted plant, 1 vase, 9.7ms
# image 120/993 /content/merged_cleaned_dataset/images/21f2c75c-1dda-41cb-8add-1e3452c28947_flux_1756079131.png: 640x640 1 potted plant, 9.8ms
# image 121/993 /content/merged_cleaned_dataset/images/21ff0455-4ed1-4291-9a58-5e10888a8289_flux_1756078712.png: 640x640 1 chair, 1 potted plant, 9.2ms
# image 122/993 /content/merged_cleaned_dataset/images/2256260a-2e61-4e9f-8d1d-61d8db84dc86_flux_1756079204.png: 640x640 1 chair, 9.2ms
# image 123/993 /content/merged_cleaned_dataset/images/2308c5f2-bca1-4f3c-bc8a-58698f1911b9_flux_1756080954.png: 640x640 (no detections), 8.9ms
# image 124/993 /content/merged_cleaned_dataset/images/230e07c0-202f-4a34-9e6d-4ce55dd4e7c9_flux_1756081208.png: 640x640 (no detections), 9.1ms
# image 125/993 /content/merged_cleaned_dataset/images/233adda4-8346-4e07-8da3-c56f0abdff47_flux_1756081118.png: 640x640 2 potted plants, 1 vase, 8.8ms
# image 126/993 /content/merged_cleaned_dataset/images/234e1939-66b0-463a-b189-efa053437bf1_flux_1756079995.png: 640x640 1 potted plant, 9.0ms
# image 127/993 /content/merged_cleaned_dataset/images/236fa17e-d321-4f80-8373-2b0044ac6ead_flux_1756079909.png: 640x640 1 chair, 9.4ms
# image 128/993 /content/merged_cleaned_dataset/images/242c9e5f-fb61-4b49-aa72-b60d54d09599_flux_1756079891.png: 640x640 1 cup, 8.9ms
# image 129/993 /content/merged_cleaned_dataset/images/2460f51b-1269-4f7b-8da4-5340e4d69b1a_flux_1756080165.png: 640x640 1 chair, 1 vase, 9.2ms
# image 130/993 /content/merged_cleaned_dataset/images/249bc37a-2152-447b-a47b-e60107c328d4_flux_1756080718.png: 640x640 2 chairs, 8.9ms
# image 131/993 /content/merged_cleaned_dataset/images/251ed839-e1f6-4a9c-a21a-37a0d1a2b3d7_flux_1756079394.png: 640x640 1 vase, 8.8ms
# image 132/993 /content/merged_cleaned_dataset/images/258ffee1-6a49-443c-a52e-ff8d9d14f955_flux_1756080379.png: 640x640 1 chair, 9.1ms
# image 133/993 /content/merged_cleaned_dataset/images/2613ca20-e6fc-4eab-895c-5b8755457cc0_flux_1756080309.png: 640x640 1 chair, 1 potted plant, 1 vase, 12.2ms
# image 134/993 /content/merged_cleaned_dataset/images/26358efc-a5c2-416c-b501-7a4a8b51ff7e_flux_1756081912.png: 640x640 1 chair, 14.7ms
# image 135/993 /content/merged_cleaned_dataset/images/2671e0ad-8e38-44de-aebd-535f214d5309_flux_1756081890.png: 640x640 1 cup, 1 potted plant, 1 vase, 13.9ms
# image 136/993 /content/merged_cleaned_dataset/images/26a18337-668f-4bf1-a97d-005b62c12933_flux_1756079932.png: 640x640 1 cup, 15.4ms
# image 137/993 /content/merged_cleaned_dataset/images/26cf02f2-fce6-4894-8f34-6a9a4a460460_flux_1756078764.png: 640x640 (no detections), 9.8ms
# image 138/993 /content/merged_cleaned_dataset/images/2700348a-c791-40e1-afee-fa158141dd37_flux_1756081197.png: 640x640 1 potted plant, 1 vase, 9.5ms
# image 139/993 /content/merged_cleaned_dataset/images/278eb2d7-71c0-46a0-bb35-572961f57325_flux_1756079917.png: 640x640 1 potted plant, 14.2ms
# image 140/993 /content/merged_cleaned_dataset/images/27a30bcf-2365-4832-bb16-cc4ad69f9568_flux_1756080411.png: 640x640 1 potted plant, 10.3ms
# image 141/993 /content/merged_cleaned_dataset/images/28447fbd-e8f9-44fe-bf21-ad6bdca8ad53_flux_1756081924.png: 640x640 1 vase, 10.4ms
# image 142/993 /content/merged_cleaned_dataset/images/28503fa2-6f69-46c5-9ac9-413daad2b920_flux_1756080924.png: 640x640 1 cup, 10.6ms
# image 143/993 /content/merged_cleaned_dataset/images/2896fac1-b3b8-4050-9684-092ee406e293_flux_1756080689.png: 640x640 1 potted plant, 1 vase, 16.0ms
# image 144/993 /content/merged_cleaned_dataset/images/28d30207-2b45-43a3-be73-76d63963b5fa_flux_1756080659.png: 640x640 1 cup, 15.1ms
# image 145/993 /content/merged_cleaned_dataset/images/29171825-da0d-4aab-91a6-4a87f7de902a_flux_1756079484.png: 640x640 1 chair, 13.4ms
# image 146/993 /content/merged_cleaned_dataset/images/293ac3e2-f4ef-42d0-8ef9-40dfbc8c0caf_flux_1756079049.png: 640x640 1 chair, 1 book, 9.5ms
# image 147/993 /content/merged_cleaned_dataset/images/296445de-1bcd-426a-bd61-6f80bb7f0bd8_flux_1756079750.png: 640x640 1 vase, 15.2ms
# image 148/993 /content/merged_cleaned_dataset/images/29ee0f3d-4a96-485b-85fc-6fcf7fdaff15_flux_1756079765.png: 640x640 1 cup, 12.9ms
# image 149/993 /content/merged_cleaned_dataset/images/2a2f89ac-e90c-4124-b1fd-e4337e3fcd3f_flux_1756081455.png: 640x640 2 potted plants, 1 vase, 13.2ms
# image 150/993 /content/merged_cleaned_dataset/images/2a35a70d-c668-407c-85fe-fcb054a52c8b_flux_1756081767.png: 640x640 1 cup, 12.9ms
# image 151/993 /content/merged_cleaned_dataset/images/2ad68627-9e80-4f4a-81b9-99781e20ebf0_flux_1756081053.png: 640x640 3 books, 12.1ms
# image 152/993 /content/merged_cleaned_dataset/images/2b987a7f-e8d4-492e-8ce3-4b4054ec095a_flux_1756079544.png: 640x640 (no detections), 14.4ms
# image 153/993 /content/merged_cleaned_dataset/images/2bb0ac17-6a6d-4c50-ae9c-7c199f76b2d8_flux_1756079836.png: 640x640 (no detections), 9.5ms
# image 154/993 /content/merged_cleaned_dataset/images/2bdd2a51-e76c-4ec1-9109-ae5b45999dd9_flux_1756080074.png: 640x640 1 cup, 1 potted plant, 1 vase, 8.2ms
# image 155/993 /content/merged_cleaned_dataset/images/2bfaee73-39c3-4c9d-a4fd-0c3b4662080e_flux_1756081275.png: 640x640 1 vase, 8.7ms
# image 156/993 /content/merged_cleaned_dataset/images/2c3312eb-cc02-4882-a165-f3ed38d9fa79_flux_1756078801.png: 640x640 1 potted plant, 8.2ms
# image 157/993 /content/merged_cleaned_dataset/images/2c411644-6e05-4ba2-9346-64908d5a647f_flux_1756079817.png: 640x640 1 vase, 8.2ms
# image 158/993 /content/merged_cleaned_dataset/images/2c737ebd-04e9-4436-81e9-36fe55daeef6_flux_1756080696.png: 640x640 1 vase, 8.2ms
# image 159/993 /content/merged_cleaned_dataset/images/2c772c3d-6918-450b-aa72-241a1064c407_flux_1756081986.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 160/993 /content/merged_cleaned_dataset/images/2c84514c-8401-4bfd-88f4-33d58765ad85_flux_1756080756.png: 640x640 1 potted plant, 8.2ms
# image 161/993 /content/merged_cleaned_dataset/images/2cc7f669-0420-46b8-8859-2099a9097e8d_flux_1756080477.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 162/993 /content/merged_cleaned_dataset/images/2cdf16e0-185f-478b-a5f5-a4676b9a2eab_flux_1756080301.png: 640x640 (no detections), 8.4ms
# image 163/993 /content/merged_cleaned_dataset/images/2dbbcfc2-d2d5-49e0-83b4-f7be8cb4ac6f_flux_1756081163.png: 640x640 1 chair, 1 vase, 8.2ms
# image 164/993 /content/merged_cleaned_dataset/images/2e1484a4-d123-4e1e-a005-f4285912ea32_flux_1756079865.png: 640x640 1 vase, 8.2ms
# image 165/993 /content/merged_cleaned_dataset/images/2e2108f7-e924-4dc9-8b50-283afd3ddcbc_flux_1756081089.png: 640x640 1 cup, 2 chairs, 1 potted plant, 8.2ms
# image 166/993 /content/merged_cleaned_dataset/images/2e27722f-2b0d-4f49-a0ba-420a612f906d_flux_1756079211.png: 640x640 3 chairs, 8.2ms
# image 167/993 /content/merged_cleaned_dataset/images/2e3afed6-c7ad-4c69-875e-635a6ff5fb04_flux_1756078936.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 168/993 /content/merged_cleaned_dataset/images/2e8d11dc-39e9-4bfe-9d92-8015185af772_flux_1756078966.png: 640x640 1 potted plant, 8.2ms
# image 169/993 /content/merged_cleaned_dataset/images/2f290367-616e-4e03-966a-513412a3a74c_flux_1756080917.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 170/993 /content/merged_cleaned_dataset/images/2f5abb95-18dd-4e78-adba-94b866902be2_flux_1756082034.png: 640x640 (no detections), 8.2ms
# image 171/993 /content/merged_cleaned_dataset/images/2fba9b3d-ec7b-473b-a6dd-a60a1f05c512_flux_1756081878.png: 640x640 1 vase, 10.7ms
# image 172/993 /content/merged_cleaned_dataset/images/2fca5353-66f9-4f4a-bf6a-ae86976fb80b_flux_1756080404.png: 640x640 1 vase, 8.2ms
# image 173/993 /content/merged_cleaned_dataset/images/2fd45e53-ad2d-4240-bf47-b1cb0c194216_flux_1756080393.png: 640x640 1 vase, 8.2ms
# image 174/993 /content/merged_cleaned_dataset/images/3042b10c-a63a-4187-a08c-62012680a3e1_flux_1756081298.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 175/993 /content/merged_cleaned_dataset/images/3049fbf7-2718-4013-93ff-e5a2a7c35e6d_flux_1756079692.png: 640x640 (no detections), 8.4ms
# image 176/993 /content/merged_cleaned_dataset/images/30534e6e-1cac-41a9-8dbf-ffa7fbcf5b46_flux_1756082005.png: 640x640 1 vase, 8.2ms
# image 177/993 /content/merged_cleaned_dataset/images/305b9a22-cb61-4f25-b9ef-48ed85c8535d_flux_1756079292.png: 640x640 1 vase, 9.6ms
# image 178/993 /content/merged_cleaned_dataset/images/3095c1df-a8d1-49b0-8e60-a7daaf3659fd_flux_1756080093.png: 640x640 2 potted plants, 2 vases, 8.2ms
# image 179/993 /content/merged_cleaned_dataset/images/30ed20b1-bdd0-4f7a-8923-2fb5088e1e08_flux_1756078996.png: 640x640 1 chair, 8.2ms
# image 180/993 /content/merged_cleaned_dataset/images/312b9b6e-166a-45e8-983c-2d02138ac742_flux_1756078921.png: 640x640 1 chair, 8.2ms
# image 181/993 /content/merged_cleaned_dataset/images/31432a0d-4ba5-43c0-bef4-8461d0b1c480_flux_1756080286.png: 640x640 1 chair, 8.2ms
# image 182/993 /content/merged_cleaned_dataset/images/31574912-a6cc-4522-848f-70190fee5bb1_flux_1756079622.png: 640x640 1 chair, 8.7ms
# image 183/993 /content/merged_cleaned_dataset/images/31a85a4f-2937-424b-9547-e2eaac893a3d_flux_1756078959.png: 640x640 1 cup, 8.2ms
# image 184/993 /content/merged_cleaned_dataset/images/32a992d3-8dad-43a7-81f7-848b3f3c510d_flux_1756081574.png: 640x640 1 book, 8.2ms
# image 185/993 /content/merged_cleaned_dataset/images/33072fe5-4493-47d1-a05d-e57d2f4d7333_flux_1756082307.png: 640x640 1 cup, 8.2ms
# image 186/993 /content/merged_cleaned_dataset/images/3317f1ad-94e7-49c6-a2d3-671ccf7629b6_flux_1756082149.png: 640x640 1 cup, 8.2ms
# image 187/993 /content/merged_cleaned_dataset/images/3374ef3b-4339-465c-a03a-7bd7e7f133cf_flux_1756079281.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 188/993 /content/merged_cleaned_dataset/images/33940505-3438-445e-84f2-36e1cb5fd11f_flux_1756078981.png: 640x640 (no detections), 8.4ms
# image 189/993 /content/merged_cleaned_dataset/images/33ba388e-7be4-4fdc-b5ec-89787bec968c_flux_1756079880.png: 640x640 1 chair, 3 potted plants, 8.2ms
# image 190/993 /content/merged_cleaned_dataset/images/33bd7fcc-ed36-4249-b79f-c405add07425_flux_1756079630.png: 640x640 (no detections), 8.2ms
# image 191/993 /content/merged_cleaned_dataset/images/33cd43c7-55dd-44fe-8138-3af744011ae5_flux_1756079736.png: 640x640 (no detections), 8.2ms
# image 192/993 /content/merged_cleaned_dataset/images/33ce9fad-b0fa-49be-9c2d-d6d0c6702da6_flux_1756081849.png: 640x640 1 chair, 8.2ms
# image 193/993 /content/merged_cleaned_dataset/images/34757a5d-445e-4a85-a9d8-ba8fe450c407_flux_1756079495.png: 640x640 1 cup, 8.2ms
# image 194/993 /content/merged_cleaned_dataset/images/34802bbe-e820-4489-9f8d-015eb9118cb5_flux_1756081115.png: 640x640 1 vase, 8.3ms
# image 195/993 /content/merged_cleaned_dataset/images/355fe846-6ab7-4d14-aae0-4cf975c1f81e_flux_1756078948.png: 640x640 1 cup, 8.2ms
# image 196/993 /content/merged_cleaned_dataset/images/3567a632-b490-4785-8551-13b78ad085b6_flux_1756082395.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 197/993 /content/merged_cleaned_dataset/images/361c13da-095e-4bc7-b90f-c0c867942775_flux_1756080426.png: 640x640 1 vase, 8.3ms
# image 198/993 /content/merged_cleaned_dataset/images/3627fa88-b15d-45c9-a052-a0476fb592b8_flux_1756080700.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 199/993 /content/merged_cleaned_dataset/images/369cc86a-489f-436c-8be6-b48470777763_flux_1756080796.png: 640x640 1 chair, 1 book, 8.2ms
# image 200/993 /content/merged_cleaned_dataset/images/36abcc37-20e9-4324-a539-963db4b54759_flux_1756080652.png: 640x640 1 chair, 2 vases, 8.4ms
# image 201/993 /content/merged_cleaned_dataset/images/36b57255-aa25-47a7-8398-198442e917ce_flux_1756079999.png: 640x640 1 chair, 8.2ms
# image 202/993 /content/merged_cleaned_dataset/images/36bee849-e627-491e-aba6-d5ed64a7122c_flux_1756082340.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 203/993 /content/merged_cleaned_dataset/images/36cc7feb-01ee-47f2-8755-7f1e66a202a3_flux_1756079850.png: 640x640 2 potted plants, 8.2ms
# image 204/993 /content/merged_cleaned_dataset/images/37224030-b198-4a06-aae6-267f31dabe36_flux_1756080615.png: 640x640 1 cup, 8.2ms
# image 205/993 /content/merged_cleaned_dataset/images/373aa369-6b07-41c2-adc3-87dabb1fc7ca_flux_1756079769.png: 640x640 1 potted plant, 8.2ms
# image 206/993 /content/merged_cleaned_dataset/images/377a278a-2196-4f20-a12d-d91fe6e48c40_flux_1756079803.png: 640x640 1 cup, 8.2ms
# image 207/993 /content/merged_cleaned_dataset/images/378a84d2-a4e5-47e1-aea7-cc4b6be14a32_flux_1756080811.png: 640x640 1 potted plant, 1 book, 8.2ms
# image 208/993 /content/merged_cleaned_dataset/images/37ecea88-62f9-43b5-9e05-91db58a60aa9_flux_1756078963.png: 640x640 1 potted plant, 2 books, 1 vase, 8.2ms
# image 209/993 /content/merged_cleaned_dataset/images/37fd7ca5-8af3-4f4f-84aa-3b40ff9b897f_flux_1756079681.png: 640x640 1 cup, 8.2ms
# image 210/993 /content/merged_cleaned_dataset/images/385bf0ad-03d1-4a67-b41e-61493d4de0cc_flux_1756080459.png: 640x640 1 chair, 9.4ms
# image 211/993 /content/merged_cleaned_dataset/images/3908788b-f948-410d-8f34-e92d10544d8a_flux_1756080800.png: 640x640 1 vase, 8.3ms
# image 212/993 /content/merged_cleaned_dataset/images/3945b6c8-3321-45b9-a500-4933601bdcb1_flux_1756079008.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 213/993 /content/merged_cleaned_dataset/images/39546bc8-7148-414d-8689-ede20573a238_flux_1756081477.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 214/993 /content/merged_cleaned_dataset/images/39ce4cdd-2d5b-4e9a-b4f5-de193027cb14_flux_1756080958.png: 640x640 1 potted plant, 8.2ms
# image 215/993 /content/merged_cleaned_dataset/images/39fca080-1f65-4a42-bbea-2786eb8e815c_flux_1756081448.png: 640x640 1 chair, 1 vase, 9.6ms
# image 216/993 /content/merged_cleaned_dataset/images/3a1d3b11-fff7-4f77-89ae-217a407a048f_flux_1756079134.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 217/993 /content/merged_cleaned_dataset/images/3a7290b1-67df-4ccc-af79-ebca8fee4140_flux_1756081496.png: 640x640 1 cup, 8.2ms
# image 218/993 /content/merged_cleaned_dataset/images/3a903948-3bc9-46df-9313-cf99a3d3de04_flux_1756080498.png: 640x640 (no detections), 8.2ms
# image 219/993 /content/merged_cleaned_dataset/images/3b76ac02-5435-4ecd-a6c3-83cef72c0efb_flux_1756082414.png: 640x640 1 book, 8.2ms
# image 220/993 /content/merged_cleaned_dataset/images/3bb9fd96-92ec-49d7-a64d-3b8753b3f0ec_flux_1756079832.png: 640x640 1 vase, 8.2ms
# image 221/993 /content/merged_cleaned_dataset/images/3bcc59fb-1282-40ba-bc4a-2663eeca2969_flux_1756080681.png: 640x640 1 chair, 8.2ms
# image 222/993 /content/merged_cleaned_dataset/images/3becf56b-cda0-4ff8-bf2d-1bb0fb04bca5_flux_1756079193.png: 640x640 1 chair, 1 potted plant, 1 vase, 8.2ms
# image 223/993 /content/merged_cleaned_dataset/images/3c489e90-9354-4768-b986-190aefb5a69b_flux_1756082116.png: 640x640 1 vase, 8.2ms
# image 224/993 /content/merged_cleaned_dataset/images/3c84639a-ae76-4209-a78d-5eab7955dfeb_flux_1756080906.png: 640x640 1 vase, 8.2ms
# image 225/993 /content/merged_cleaned_dataset/images/3ca78fbd-3149-495a-a611-1439c725ff1d_flux_1756080781.png: 640x640 2 chairs, 4 potted plants, 8.2ms
# image 226/993 /content/merged_cleaned_dataset/images/3cab4296-865b-4338-8b5b-17d500b18d27_flux_1756079423.png: 640x640 1 cup, 1 potted plant, 8.3ms
# image 227/993 /content/merged_cleaned_dataset/images/3cb2edf6-7aa8-43e4-8c2d-f52577fd4412_flux_1756079603.png: 640x640 1 chair, 8.2ms
# image 228/993 /content/merged_cleaned_dataset/images/3d4674c9-1eed-4654-a6af-0cab158f1f73_flux_1756080408.png: 640x640 (no detections), 8.2ms
# image 229/993 /content/merged_cleaned_dataset/images/3d474abf-85ed-4172-8e9b-d009c5e611ee_flux_1756082226.png: 640x640 1 vase, 8.2ms
# image 230/993 /content/merged_cleaned_dataset/images/3d4be69d-7878-4ea1-9a71-46be291d0836_flux_1756081644.png: 640x640 (no detections), 8.2ms
# image 231/993 /content/merged_cleaned_dataset/images/3d5bb8a4-ec0d-4c0d-a1b7-008e868c84fe_flux_1756081437.png: 640x640 (no detections), 8.2ms
# image 232/993 /content/merged_cleaned_dataset/images/3d81eb51-cd23-4d32-8c5d-e99fa64fd132_flux_1756079973.png: 640x640 1 potted plant, 8.2ms
# image 233/993 /content/merged_cleaned_dataset/images/3d82a23c-730e-43fa-979f-70f9b814c2de_flux_1756082083.png: 640x640 1 vase, 8.2ms
# image 234/993 /content/merged_cleaned_dataset/images/3d9ae6bb-4a7f-444d-93ce-189212e536bb_flux_1756080390.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 235/993 /content/merged_cleaned_dataset/images/3de99476-0a18-447c-b7fb-e5e3d975b2ec_flux_1756080884.png: 640x640 (no detections), 8.2ms
# image 236/993 /content/merged_cleaned_dataset/images/3e6fd7e2-2dd6-471b-9089-b1f479f7dd6e_flux_1756081328.png: 640x640 1 cup, 8.2ms
# image 237/993 /content/merged_cleaned_dataset/images/3ec1d650-46f5-4bec-90d8-693a0634bab2_flux_1756080264.png: 640x640 (no detections), 8.2ms
# image 238/993 /content/merged_cleaned_dataset/images/3f27c42d-a586-410b-ab2b-25410749f56f_flux_1756082263.png: 640x640 1 vase, 8.2ms
# image 239/993 /content/merged_cleaned_dataset/images/3f49f8c9-89cb-44a6-b9ce-4c1a41afe9b6_flux_1756080194.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 240/993 /content/merged_cleaned_dataset/images/3f6a51e1-0f12-426f-a432-a8d76830e5c2_flux_1756079185.png: 640x640 1 chair, 1 potted plant, 8.2ms
# image 241/993 /content/merged_cleaned_dataset/images/3f92d9fd-6c39-44c8-8bdd-b06bdfb9c852_flux_1756080172.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 242/993 /content/merged_cleaned_dataset/images/3fbcaccf-a98c-4947-bed8-bb1566b1ac0f_flux_1756079273.png: 640x640 1 cup, 8.2ms
# image 243/993 /content/merged_cleaned_dataset/images/405b0d57-7949-4a8c-adb4-b91a71a5aaa6_flux_1756079776.png: 640x640 1 potted plant, 8.2ms
# image 244/993 /content/merged_cleaned_dataset/images/40619609-7397-4ca1-894c-da380f7a81bb_flux_1756081100.png: 640x640 1 vase, 8.2ms
# image 245/993 /content/merged_cleaned_dataset/images/406d416b-3eb2-4196-ae41-5aba5838e22b_flux_1756081264.png: 640x640 (no detections), 8.2ms
# image 246/993 /content/merged_cleaned_dataset/images/409f191e-c1ac-4c07-b7f8-adf2a0bbe50a_flux_1756080586.png: 640x640 1 cup, 8.2ms
# image 247/993 /content/merged_cleaned_dataset/images/40ede778-93ef-4f51-9442-d02b3c20474a_flux_1756080108.png: 640x640 1 chair, 8.2ms
# image 248/993 /content/merged_cleaned_dataset/images/4157cab7-9819-4d82-a858-817f86d0f00c_flux_1756082407.png: 640x640 1 cup, 8.2ms
# image 249/993 /content/merged_cleaned_dataset/images/419a064b-2540-401b-a531-07494bf72f97_flux_1756079592.png: 640x640 1 cup, 8.2ms
# image 250/993 /content/merged_cleaned_dataset/images/41f96e07-8cb0-4ab4-a687-0962fca56132_flux_1756080707.png: 640x640 1 vase, 14.0ms
# image 251/993 /content/merged_cleaned_dataset/images/41faf946-66e7-4aa9-8bd4-c909c30ba02e_flux_1756080807.png: 640x640 1 cup, 8.2ms
# image 252/993 /content/merged_cleaned_dataset/images/42343668-b19f-467d-b331-6c4acddc1855_flux_1756079178.png: 640x640 1 potted plant, 8.2ms
# image 253/993 /content/merged_cleaned_dataset/images/4235b8e5-9ca4-45be-a9bf-be6f63faf199_flux_1756082322.png: 640x640 (no detections), 8.9ms
# image 254/993 /content/merged_cleaned_dataset/images/423c806f-670c-4f92-ba8f-7cac8cb974a7_flux_1756080932.png: 640x640 2 potted plants, 1 book, 1 vase, 8.2ms
# image 255/993 /content/merged_cleaned_dataset/images/4263b505-ed2a-4d4e-a622-8758d8110b07_flux_1756080183.png: 640x640 2 chairs, 1 potted plant, 8.2ms
# image 256/993 /content/merged_cleaned_dataset/images/428039c4-76f5-4f2e-8763-9da299b35222_flux_1756080224.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 257/993 /content/merged_cleaned_dataset/images/429a8acf-8f0e-4ca2-a2bf-04a1b4eabec1_flux_1756081655.png: 640x640 1 book, 8.2ms
# image 258/993 /content/merged_cleaned_dataset/images/42c5f6fa-ec56-419f-94d2-1d7fb24a2233_flux_1756081481.png: 640x640 1 chair, 10.2ms
# image 259/993 /content/merged_cleaned_dataset/images/42df4fbd-d053-4e95-a614-7921871bef62_flux_1756080331.png: 640x640 (no detections), 8.2ms
# image 260/993 /content/merged_cleaned_dataset/images/4323c5f6-8f29-4f89-a8e6-ac7f9018dcd5_flux_1756078727.png: 640x640 1 chair, 8.2ms
# image 261/993 /content/merged_cleaned_dataset/images/43a4dd78-1bf2-41ee-bfe1-47772ad2fd28_flux_1756082218.png: 640x640 1 chair, 8.2ms
# image 262/993 /content/merged_cleaned_dataset/images/43c66cee-cbce-4b1c-a754-d48bae6eb78b_flux_1756079034.png: 640x640 1 potted plant, 8.2ms
# image 263/993 /content/merged_cleaned_dataset/images/43e6dc87-3486-477a-8e66-ffa77358abb3_flux_1756079584.png: 640x640 1 cup, 8.2ms
# image 264/993 /content/merged_cleaned_dataset/images/43e8a3df-38bf-4b29-93b0-693e22795057_flux_1756079011.png: 640x640 1 chair, 5 potted plants, 8.2ms
# image 265/993 /content/merged_cleaned_dataset/images/44f8399c-6dcf-476c-a066-46a10ff9da8e_flux_1756081625.png: 640x640 (no detections), 8.2ms
# image 266/993 /content/merged_cleaned_dataset/images/457852ee-9781-458b-9af8-d103059229e0_flux_1756081463.png: 640x640 1 cup, 8.2ms
# image 267/993 /content/merged_cleaned_dataset/images/45a9a7cf-1d09-4845-be75-a679df9a3011_flux_1756081669.png: 640x640 2 chairs, 8.2ms
# image 268/993 /content/merged_cleaned_dataset/images/45ba895d-fcbe-49b1-9f1b-428e2d117111_flux_1756081622.png: 640x640 1 cup, 8.2ms
# image 269/993 /content/merged_cleaned_dataset/images/469dbfa2-295f-4e8a-8069-238983cfe3e9_flux_1756078790.png: 640x640 2 books, 8.7ms
# image 270/993 /content/merged_cleaned_dataset/images/46d344d9-4453-4b8c-9cc3-a0dc1b228777_flux_1756080623.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 271/993 /content/merged_cleaned_dataset/images/4749de5a-c0f6-4fb3-bc55-dd9a9283da3f_flux_1756079717.png: 640x640 1 cup, 8.2ms
# image 272/993 /content/merged_cleaned_dataset/images/479bf09d-4946-45a6-a5d8-c783da1d7822_flux_1756080466.png: 640x640 1 chair, 8.2ms
# image 273/993 /content/merged_cleaned_dataset/images/47a3aa28-3501-4aca-9f41-86b21027badb_flux_1756081441.png: 640x640 1 chair, 8.2ms
# image 274/993 /content/merged_cleaned_dataset/images/483827aa-d1d9-4acd-8992-963741dcc4d6_flux_1756081042.png: 640x640 2 cups, 1 chair, 1 potted plant, 8.2ms
# image 275/993 /content/merged_cleaned_dataset/images/487d66e4-6d88-44b8-9140-5e088d2d1f63_flux_1756081774.png: 640x640 1 chair, 8.3ms
# image 276/993 /content/merged_cleaned_dataset/images/488e9f4c-b7a2-42c9-8269-5fcfe1f56c1d_flux_1756080397.png: 640x640 2 cups, 1 potted plant, 8.2ms
# image 277/993 /content/merged_cleaned_dataset/images/491b3e4a-2f61-429b-a3ae-68928022b71c_flux_1756081193.png: 640x640 1 chair, 8.2ms
# image 278/993 /content/merged_cleaned_dataset/images/495c34dc-ecfd-4252-8ad4-f6b68e88824e_flux_1756079079.png: 640x640 1 cup, 8.2ms
# image 279/993 /content/merged_cleaned_dataset/images/4982f0ee-4e34-4432-8d60-81d015261190_flux_1756080419.png: 640x640 (no detections), 8.2ms
# image 280/993 /content/merged_cleaned_dataset/images/4a4a893e-7532-4684-9a5a-1970898d482d_flux_1756081122.png: 640x640 1 chair, 8.2ms
# image 281/993 /content/merged_cleaned_dataset/images/4aa4e312-19be-4e85-9874-7e1e2f5fb98f_flux_1756081034.png: 640x640 (no detections), 8.2ms
# image 282/993 /content/merged_cleaned_dataset/images/4aadfb91-b53e-4537-9458-a0e10e352929_flux_1756079086.png: 640x640 1 vase, 8.2ms
# image 283/993 /content/merged_cleaned_dataset/images/4ac45228-8b02-4b9c-b01f-43cd4b77c8b6_flux_1756079105.png: 640x640 1 chair, 8.2ms
# image 284/993 /content/merged_cleaned_dataset/images/4b403896-2b67-40f3-b22f-23af1e04b7fb_flux_1756081522.png: 640x640 (no detections), 8.2ms
# image 285/993 /content/merged_cleaned_dataset/images/4b53d319-4036-4163-9ef9-8cfcd8957646_flux_1756081256.png: 640x640 1 book, 1 vase, 8.2ms
# image 286/993 /content/merged_cleaned_dataset/images/4b66f6a4-82f9-4225-a226-c4d2f8a109b9_flux_1756080105.png: 640x640 1 potted plant, 8.2ms
# image 287/993 /content/merged_cleaned_dataset/images/4bfd6922-c9be-4750-8aa6-fea7d7e05191_flux_1756078757.png: 640x640 (no detections), 8.2ms
# image 288/993 /content/merged_cleaned_dataset/images/4c477d16-9468-4cc6-ba4f-388c465e2230_flux_1756080168.png: 640x640 2 potted plants, 9.1ms
# image 289/993 /content/merged_cleaned_dataset/images/4c844d1f-403f-4370-8e05-60bee0cf307e_flux_1756078720.png: 640x640 1 book, 13.4ms
# image 290/993 /content/merged_cleaned_dataset/images/4cbc357d-ef42-4047-b3cd-64dd8684d8e2_flux_1756080279.png: 640x640 (no detections), 8.2ms
# image 291/993 /content/merged_cleaned_dataset/images/4cca4683-b4ea-4ddb-85b8-2f20eb7d86c0_flux_1756081793.png: 640x640 4 vases, 8.9ms
# image 292/993 /content/merged_cleaned_dataset/images/4ced3813-4535-4e0a-8bec-fb812779b128_flux_1756079588.png: 640x640 1 potted plant, 2 vases, 8.2ms
# image 293/993 /content/merged_cleaned_dataset/images/4d016870-d932-45ce-8862-44bf4ebf0b41_flux_1756081867.png: 640x640 1 cup, 8.2ms
# image 294/993 /content/merged_cleaned_dataset/images/4d837d05-62cb-4401-a20a-78cbfb773991_flux_1756081556.png: 640x640 1 chair, 1 potted plant, 36.2ms
# image 295/993 /content/merged_cleaned_dataset/images/4ddb7436-9bb3-4927-8baa-11a223155c81_flux_1756081027.png: 640x640 1 chair, 10.8ms
# image 296/993 /content/merged_cleaned_dataset/images/4e0c69d2-bc0f-49b6-8a7d-a4d06c808678_flux_1756081778.png: 640x640 1 potted plant, 34.7ms
# image 297/993 /content/merged_cleaned_dataset/images/4e231b0b-5e7a-4b32-ae66-ae9bcceb9cb1_flux_1756081093.png: 640x640 1 potted plant, 22.9ms
# image 298/993 /content/merged_cleaned_dataset/images/4e2b3b1b-a859-48b6-a417-aab9a7b03ed3_flux_1756082060.png: 640x640 (no detections), 35.2ms
# image 299/993 /content/merged_cleaned_dataset/images/4e41a2cc-e00d-4424-9095-b713547fd2ee_flux_1756079233.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 300/993 /content/merged_cleaned_dataset/images/4e5fdbdf-71cd-4865-bb9f-26bf17e30184_flux_1756078940.png: 640x640 (no detections), 8.2ms
# image 301/993 /content/merged_cleaned_dataset/images/4e7bdfbf-05a5-4b7a-800a-4f2a98945bda_flux_1756079551.png: 640x640 1 chair, 8.2ms
# image 302/993 /content/merged_cleaned_dataset/images/4e9907a8-a3fb-4782-99ba-1d481d1a78e5_flux_1756079954.png: 640x640 3 chairs, 8.2ms
# image 303/993 /content/merged_cleaned_dataset/images/4f63c1b5-c63d-49fb-8b50-320d064ccc05_flux_1756081711.png: 640x640 1 chair, 8.2ms
# image 304/993 /content/merged_cleaned_dataset/images/4f79f90e-4836-4a7c-b8ae-08fce624d320_flux_1756079977.png: 640x640 (no detections), 8.2ms
# image 305/993 /content/merged_cleaned_dataset/images/4fdbe39d-8908-4394-ac66-7503258f662d_flux_1756082241.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 306/993 /content/merged_cleaned_dataset/images/50218e15-3da1-49a0-846f-c327e27150ee_flux_1756079626.png: 640x640 2 books, 8.2ms
# image 307/993 /content/merged_cleaned_dataset/images/503d5f37-e69b-4b55-af6c-e4f30a3d4b19_flux_1756080187.png: 640x640 1 cup, 8.2ms
# image 308/993 /content/merged_cleaned_dataset/images/505c0496-52a1-4e4f-a0b2-8a6d9869ad48_flux_1756079124.png: 640x640 1 chair, 8.2ms
# image 309/993 /content/merged_cleaned_dataset/images/50d90b19-ee0b-4ff0-a807-5a5f5b4850b0_flux_1756080836.png: 640x640 (no detections), 8.2ms
# image 310/993 /content/merged_cleaned_dataset/images/50f7ae87-b79b-442f-be02-1bc087fb5f94_flux_1756081946.png: 640x640 (no detections), 8.2ms
# image 311/993 /content/merged_cleaned_dataset/images/51953155-3557-4d6d-af5d-f6a6af055788_flux_1756079902.png: 640x640 2 cups, 1 chair, 1 vase, 8.2ms
# image 312/993 /content/merged_cleaned_dataset/images/51f245df-ef33-46fc-92bb-a244d9b5bfc2_flux_1756080011.png: 640x640 1 cup, 1 potted plant, 1 book, 8.2ms
# image 313/993 /content/merged_cleaned_dataset/images/52458976-5016-4040-805b-9f648ec5ace7_flux_1756082196.png: 640x640 1 book, 8.2ms
# image 314/993 /content/merged_cleaned_dataset/images/5268081d-281d-4615-89b5-71ada581cc1a_flux_1756079710.png: 640x640 1 chair, 8.2ms
# image 315/993 /content/merged_cleaned_dataset/images/52ad2768-36d4-4c08-9714-a162f55aa993_flux_1756080902.png: 640x640 1 vase, 11.6ms
# image 316/993 /content/merged_cleaned_dataset/images/52b07367-70e1-4b7b-9c66-763020535df4_flux_1756081382.png: 640x640 1 potted plant, 1 vase, 10.2ms
# image 317/993 /content/merged_cleaned_dataset/images/53250b70-5985-4f02-991c-10476571478d_flux_1756079341.png: 640x640 (no detections), 30.0ms
# image 318/993 /content/merged_cleaned_dataset/images/53706bde-8a15-46fa-972b-a14698e2540f_flux_1756080814.png: 640x640 1 cup, 31.6ms
# image 319/993 /content/merged_cleaned_dataset/images/53a48d08-2d69-4419-95b8-2c0e0d841dd6_flux_1756078694.png: 640x640 1 chair, 10.3ms
# image 320/993 /content/merged_cleaned_dataset/images/53c3a9a8-3a77-4f98-b262-f09acf39708a_flux_1756079052.png: 640x640 1 cup, 35.5ms
# image 321/993 /content/merged_cleaned_dataset/images/54515b8f-8e3e-452d-9679-67fce8bf669e_flux_1756081537.png: 640x640 (no detections), 11.7ms
# image 322/993 /content/merged_cleaned_dataset/images/54518000-9593-41b1-8e8d-c68ea90fb3e4_flux_1756079156.png: 640x640 2 vases, 16.5ms
# image 323/993 /content/merged_cleaned_dataset/images/54d104ed-4720-4d96-b2a3-e381d6f1c341_flux_1756081238.png: 640x640 (no detections), 15.5ms
# image 324/993 /content/merged_cleaned_dataset/images/555d424f-c67a-4e09-8699-ffcf17a1646d_flux_1756081503.png: 640x640 1 cup, 1 potted plant, 8.2ms
# image 325/993 /content/merged_cleaned_dataset/images/5609d736-dee2-4239-a8a1-6e64728d0fed_flux_1756080774.png: 640x640 1 cup, 1 vase, 8.5ms
# image 326/993 /content/merged_cleaned_dataset/images/5612e092-d355-4293-a46b-07bec526a633_flux_1756082171.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 327/993 /content/merged_cleaned_dataset/images/56274353-0dd3-47e2-b278-1785c77b5bdb_flux_1756079416.png: 640x640 1 vase, 8.2ms
# image 328/993 /content/merged_cleaned_dataset/images/562780d1-325f-496e-afed-2dfb019a7944_flux_1756081357.png: 640x640 (no detections), 8.2ms
# image 329/993 /content/merged_cleaned_dataset/images/563a0328-cbd4-4856-9332-bf410702b389_flux_1756082001.png: 640x640 1 cup, 1 vase, 8.2ms
# image 330/993 /content/merged_cleaned_dataset/images/56bae961-38d1-47a4-82f5-cc5f536572a2_flux_1756080509.png: 640x640 1 vase, 8.2ms
# image 331/993 /content/merged_cleaned_dataset/images/56e61f9a-2c88-4d52-af37-c4f0bafc6d49_flux_1756082094.png: 640x640 (no detections), 8.2ms
# image 332/993 /content/merged_cleaned_dataset/images/5749a0d6-7c36-4110-b35c-8ee5068c35e0_flux_1756078865.png: 640x640 1 chair, 8.2ms
# image 333/993 /content/merged_cleaned_dataset/images/57621e8f-028c-45d1-beb8-1b6462dd0744_flux_1756080157.png: 640x640 1 chair, 8.2ms
# image 334/993 /content/merged_cleaned_dataset/images/576358ca-8753-41c6-8c3d-7a935ceaaae1_flux_1756080752.png: 640x640 (no detections), 8.2ms
# image 335/993 /content/merged_cleaned_dataset/images/577193a1-f4bb-4f8b-ba7e-08c2c433e9ec_flux_1756080987.png: 640x640 1 chair, 8.4ms
# image 336/993 /content/merged_cleaned_dataset/images/578275c8-e26b-44d1-b883-ee1fccc4959c_flux_1756080480.png: 640x640 2 chairs, 8.2ms
# image 337/993 /content/merged_cleaned_dataset/images/57938a90-2a19-4027-81af-c5b61214c5c8_flux_1756080722.png: 640x640 1 chair, 2 potted plants, 1 vase, 8.7ms
# image 338/993 /content/merged_cleaned_dataset/images/57bfc584-8ff3-41e4-914e-bc1a4ac50e16_flux_1756080648.png: 640x640 1 vase, 8.2ms
# image 339/993 /content/merged_cleaned_dataset/images/57cfc2b7-1d74-40e9-8238-c74f15cc7c7a_flux_1756081823.png: 640x640 1 vase, 8.2ms
# image 340/993 /content/merged_cleaned_dataset/images/584d793f-0be6-49e3-a09a-797dd1986bac_flux_1756081897.png: 640x640 1 cup, 1 book, 10.6ms
# image 341/993 /content/merged_cleaned_dataset/images/5860452b-fec6-4414-8caf-a875a28588b7_flux_1756080873.png: 640x640 1 cup, 9.5ms
# image 342/993 /content/merged_cleaned_dataset/images/58bcc4d6-867e-4a8a-9f09-053b3b7970d0_flux_1756081688.png: 640x640 1 chair, 8.2ms
# image 343/993 /content/merged_cleaned_dataset/images/590274cb-4150-49cb-84ab-45ae5f62672e_flux_1756079659.png: 640x640 (no detections), 30.6ms
# image 344/993 /content/merged_cleaned_dataset/images/5914b8df-458a-4751-8007-42ee5bbec164_flux_1756079814.png: 640x640 2 cups, 31.3ms
# ...
# image 881/993 /content/merged_cleaned_dataset/images/e42c314a-8f44-4a46-afa5-27d8f4b1f203_flux_1756079858.png: 640x640 1 vase, 8.2ms
# image 882/993 /content/merged_cleaned_dataset/images/e499094e-71a2-471f-a510-68b4c9c3018e_flux_1756081589.png: 640x640 1 cup, 8.2ms
# image 883/993 /content/merged_cleaned_dataset/images/e51eba6b-dd89-4962-b910-1089379fab77_flux_1756080994.png: 640x640 2 chairs, 1 potted plant, 1 vase, 8.2ms
# image 884/993 /content/merged_cleaned_dataset/images/e5435074-4c4a-4839-b951-5c28600453ba_flux_1756082105.png: 640x640 2 potted plants, 1 vase, 8.2ms
# image 885/993 /content/merged_cleaned_dataset/images/e5ad13e7-1142-4578-beae-43dbade34552_flux_1756082174.png: 640x640 1 potted plant, 8.2ms
# image 886/993 /content/merged_cleaned_dataset/images/e5f34029-6bd6-4791-9291-1cd6004ce760_flux_1756078742.png: 640x640 3 cups, 1 potted plant, 8.2ms
# image 887/993 /content/merged_cleaned_dataset/images/e60bea87-4964-4f63-84e0-c12636cbfc57_flux_1756082351.png: 640x640 1 vase, 8.2ms
# image 888/993 /content/merged_cleaned_dataset/images/e63c11ef-6b24-4929-9d7d-ed9623efba47_flux_1756081349.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 889/993 /content/merged_cleaned_dataset/images/e6c5de98-299d-4fe8-b2bd-8528fb068471_flux_1756080324.png: 640x640 1 cup, 8.2ms
# image 890/993 /content/merged_cleaned_dataset/images/e6fb6947-38c5-4eb3-9f1f-a2b3d6137423_flux_1756080488.png: 640x640 1 cup, 8.2ms
# image 891/993 /content/merged_cleaned_dataset/images/e7844c1d-573e-4828-b553-90864428f79b_flux_1756079518.png: 640x640 1 chair, 8.2ms
# image 892/993 /content/merged_cleaned_dataset/images/e7b9b64a-9226-4cb0-9f65-46f20f4990d9_flux_1756079026.png: 640x640 1 cup, 10.0ms
# image 893/993 /content/merged_cleaned_dataset/images/e7bbf9bb-3b35-439c-ba9b-54f95be50a1f_flux_1756081647.png: 640x640 1 chair, 1 vase, 8.2ms
# image 894/993 /content/merged_cleaned_dataset/images/e7da0808-f1a0-4671-af85-1169c3012d03_flux_1756078672.png: 640x640 (no detections), 8.2ms
# image 895/993 /content/merged_cleaned_dataset/images/e808c4de-0e5b-480e-a3d8-d4151bee01c7_flux_1756079023.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 896/993 /content/merged_cleaned_dataset/images/e82094a8-435c-4492-ae5a-cfec08d028d6_flux_1756080851.png: 640x640 1 book, 8.2ms
# image 897/993 /content/merged_cleaned_dataset/images/e88ed536-1168-46f5-b532-3b3a91514fb9_flux_1756081038.png: 640x640 1 cup, 31.5ms
# image 898/993 /content/merged_cleaned_dataset/images/e898a2d1-01f5-4175-9683-7c0638167238_flux_1756081379.png: 640x640 1 potted plant, 35.4ms
# image 899/993 /content/merged_cleaned_dataset/images/e8b94026-bcfb-4c33-9fc0-b16c4059bdd6_flux_1756082381.png: 640x640 (no detections), 28.6ms
# image 900/993 /content/merged_cleaned_dataset/images/e9173250-89c8-4fa2-b3f9-4fd7a1ef200c_flux_1756079754.png: 640x640 1 cup, 9.1ms
# image 901/993 /content/merged_cleaned_dataset/images/e948bddd-ea39-4a40-8afa-d6df1a8245d7_flux_1756079109.png: 640x640 1 cup, 8.2ms
# image 902/993 /content/merged_cleaned_dataset/images/e9600052-ad8c-4da7-8fa9-0115e068f961_flux_1756078944.png: 640x640 (no detections), 8.3ms
# image 903/993 /content/merged_cleaned_dataset/images/e9745bd1-d212-43ea-9f85-6712ec4525fa_flux_1756079536.png: 640x640 (no detections), 8.8ms
# image 904/993 /content/merged_cleaned_dataset/images/e9793b64-a7d8-44e4-a7b3-7779cfbead49_flux_1756078842.png: 640x640 1 chair, 1 vase, 8.2ms
# image 905/993 /content/merged_cleaned_dataset/images/e9c3444e-018b-4cd8-977b-0e6dec2e0b28_flux_1756080086.png: 640x640 1 cup, 1 chair, 8.2ms
# image 906/993 /content/merged_cleaned_dataset/images/e9e325e1-4c0b-4586-ac50-efe28f6ec834_flux_1756082167.png: 640x640 1 potted plant, 1 vase, 8.2ms
# image 907/993 /content/merged_cleaned_dataset/images/e9e6759e-1e8e-49fb-a236-07e8f6ddc0e7_flux_1756080161.png: 640x640 1 cup, 14.4ms
# image 908/993 /content/merged_cleaned_dataset/images/ea8dd713-6415-421a-96b7-21e5bac94a92_flux_1756081518.png: 640x640 1 vase, 8.4ms
# image 909/993 /content/merged_cleaned_dataset/images/eaea85ea-876d-4c79-bd0f-99acb0d208e1_flux_1756078887.png: 640x640 1 vase, 8.2ms
# image 910/993 /content/merged_cleaned_dataset/images/eb027c42-1511-49d9-8881-7c2554f62675_flux_1756081167.png: 640x640 1 cup, 8.7ms
# image 911/993 /content/merged_cleaned_dataset/images/eba1beb6-a77d-4241-8020-c422d9a868d5_flux_1756080213.png: 640x640 (no detections), 8.4ms
# image 912/993 /content/merged_cleaned_dataset/images/ebae7f1b-88fa-43ae-84be-ef3ff81b3730_flux_1756079780.png: 640x640 (no detections), 8.2ms
# image 913/993 /content/merged_cleaned_dataset/images/ebea687f-482c-4e8e-a5df-425cee5ccdfa_flux_1756080604.png: 640x640 1 chair, 13.0ms
# image 914/993 /content/merged_cleaned_dataset/images/ebf88bdd-c12a-4d6e-a1b8-1b421d1dc0af_flux_1756078661.png: 640x640 1 chair, 1 potted plant, 13.9ms
# image 915/993 /content/merged_cleaned_dataset/images/ecaf0cc2-74f5-42d1-a423-f06b56171ee8_flux_1756080231.png: 640x640 1 cup, 14.6ms
# image 916/993 /content/merged_cleaned_dataset/images/ecf263d6-d3b7-45f7-b846-f1f2576b53bd_flux_1756081673.png: 640x640 1 potted plant, 1 vase, 15.6ms
# image 917/993 /content/merged_cleaned_dataset/images/ed53d07f-d5fa-4d54-9ad9-4c27d86d9296_flux_1756079947.png: 640x640 1 cup, 1 vase, 55.3ms
# image 918/993 /content/merged_cleaned_dataset/images/edb73a6c-12d8-4e33-b171-3887184aa59c_flux_1756080770.png: 640x640 2 potted plants, 1 vase, 79.3ms
# image 919/993 /content/merged_cleaned_dataset/images/edbacb8b-7921-4c76-92ce-5a9db892d5a3_flux_1756079300.png: 640x640 (no detections), 29.7ms
# image 920/993 /content/merged_cleaned_dataset/images/ee1917cb-30ad-48b1-8dd2-c60ff37f81b9_flux_1756079270.png: 640x640 1 cup, 1 potted plant, 9.8ms
# image 921/993 /content/merged_cleaned_dataset/images/ee4b7ebe-23ff-4026-955c-e39ecb9cdff6_flux_1756079791.png: 640x640 1 chair, 1 vase, 10.2ms
# image 922/993 /content/merged_cleaned_dataset/images/ee5f309e-124c-4642-8fe3-ee653cc8e8ad_flux_1756080936.png: 640x640 1 vase, 21.4ms
# image 923/993 /content/merged_cleaned_dataset/images/ee837846-b1dc-40cd-874f-3379d9670240_flux_1756081488.png: 640x640 (no detections), 18.8ms
# image 924/993 /content/merged_cleaned_dataset/images/eeb0b36d-a161-4755-8c31-7cda551cbc2e_flux_1756081961.png: 640x640 2 cups, 11.5ms
# image 925/993 /content/merged_cleaned_dataset/images/ef68a476-2189-4214-a798-96a076cf695f_flux_1756081393.png: 640x640 (no detections), 10.4ms
# image 926/993 /content/merged_cleaned_dataset/images/efac38e6-16a3-4777-89f2-f8142a87c041_flux_1756081699.png: 640x640 1 cup, 10.3ms
# image 927/993 /content/merged_cleaned_dataset/images/efeb8d86-fbc2-4c64-bf68-ecb1a8e48da4_flux_1756082207.png: 640x640 1 potted plant, 11.6ms
# image 928/993 /content/merged_cleaned_dataset/images/f00275c6-fd61-4eb3-8a4d-c1d0ef31e555_flux_1756081920.png: 640x640 1 cup, 14.3ms
# image 929/993 /content/merged_cleaned_dataset/images/f03e6324-3fba-4441-9a3b-ce568790d27c_flux_1756079670.png: 640x640 1 potted plant, 2 vases, 10.7ms
# image 930/993 /content/merged_cleaned_dataset/images/f09b3eaa-f07c-4485-8def-caf9590210e7_flux_1756080346.png: 640x640 1 chair, 2 potted plants, 1 vase, 10.8ms
# image 931/993 /content/merged_cleaned_dataset/images/f0b81379-cade-4591-add9-8c9f7767305d_flux_1756079251.png: 640x640 (no detections), 10.1ms
# image 932/993 /content/merged_cleaned_dataset/images/f0c28297-70d3-4a8f-985b-5379b73598eb_flux_1756082403.png: 640x640 1 cup, 10.4ms
# image 933/993 /content/merged_cleaned_dataset/images/f0fd77e9-100b-4b93-9019-91e8e7892ad5_flux_1756079969.png: 640x640 1 cup, 10.7ms
# image 934/993 /content/merged_cleaned_dataset/images/f114f357-0c6e-47e2-8660-4b1b16b974b4_flux_1756079674.png: 640x640 (no detections), 35.6ms
# image 935/993 /content/merged_cleaned_dataset/images/f1b9be00-79e1-46bb-98c1-224774cf71a4_flux_1756080368.png: 640x640 (no detections), 37.5ms
# image 936/993 /content/merged_cleaned_dataset/images/f1cb4d08-88b5-4606-8871-8c5d7aecf50f_flux_1756082275.png: 640x640 (no detections), 43.5ms
# image 937/993 /content/merged_cleaned_dataset/images/f1dfc87b-fbb8-4866-a669-9f99aedfaa7f_flux_1756081819.png: 640x640 1 chair, 9.8ms
# image 938/993 /content/merged_cleaned_dataset/images/f20c965d-b7ce-4784-985a-4b9e79634c22_flux_1756079360.png: 640x640 1 vase, 9.7ms
# image 939/993 /content/merged_cleaned_dataset/images/f2271b59-09bd-4717-9b03-f6572351c9eb_flux_1756082030.png: 640x640 1 chair, 9.4ms
# image 940/993 /content/merged_cleaned_dataset/images/f327ce2f-f476-49aa-8c1a-95f008868f69_flux_1756080082.png: 640x640 1 vase, 9.6ms
# image 941/993 /content/merged_cleaned_dataset/images/f39a2f29-eb75-4c4d-94f7-21e1832b3855_flux_1756080840.png: 640x640 2 chairs, 1 vase, 10.9ms
# image 942/993 /content/merged_cleaned_dataset/images/f3ac8a7a-e17b-4ba3-b091-0a745a5c8191_flux_1756081570.png: 640x640 1 book, 10.3ms
# image 943/993 /content/merged_cleaned_dataset/images/f3d17fd8-24fb-47a9-a423-59873205948e_flux_1756078869.png: 640x640 1 book, 11.8ms
# image 944/993 /content/merged_cleaned_dataset/images/f3da8801-0d6b-4862-b0e2-f0f3ca4b4db2_flux_1756080328.png: 640x640 1 cup, 1 vase, 10.0ms
# image 945/993 /content/merged_cleaned_dataset/images/f442f479-5bfc-47de-aaea-66e9954d7867_flux_1756079843.png: 640x640 4 books, 12.9ms
# image 946/993 /content/merged_cleaned_dataset/images/f491d54f-37eb-42fe-bb08-0317f9e29712_flux_1756081302.png: 640x640 1 chair, 13.0ms
# image 947/993 /content/merged_cleaned_dataset/images/f4d323ce-a9b9-4d81-8a04-3608ed737dd7_flux_1756081375.png: 640x640 1 book, 22.3ms
# image 948/993 /content/merged_cleaned_dataset/images/f4db1868-0236-4ceb-9acb-41780f6520bd_flux_1756081882.png: 640x640 (no detections), 10.1ms
# image 949/993 /content/merged_cleaned_dataset/images/f4ebe5c1-1c65-4084-88f8-168ebffbe301_flux_1756079098.png: 640x640 1 cup, 11.2ms
# image 950/993 /content/merged_cleaned_dataset/images/f500ba27-0b01-4924-82c5-1bfb4ea03ef8_flux_1756080674.png: 640x640 1 book, 10.1ms
# image 951/993 /content/merged_cleaned_dataset/images/f519141b-d3c9-4d76-a66c-0219ca39a324_flux_1756079090.png: 640x640 1 cup, 11.3ms
# image 952/993 /content/merged_cleaned_dataset/images/f5608264-afb3-4349-8c75-702c79e5f5a7_flux_1756081733.png: 640x640 1 chair, 10.4ms
# image 953/993 /content/merged_cleaned_dataset/images/f65468f1-7ce2-46e8-916c-11f9ba463cd8_flux_1756081763.png: 640x640 2 chairs, 17.0ms
# image 954/993 /content/merged_cleaned_dataset/images/f672ac39-87af-436e-9c37-319dc0ba0648_flux_1756081346.png: 640x640 2 books, 1 vase, 13.3ms
# image 955/993 /content/merged_cleaned_dataset/images/f67aefc6-6310-47c3-8b2b-1a94bfa2e219_flux_1756079795.png: 640x640 2 chairs, 10.4ms
# image 956/993 /content/merged_cleaned_dataset/images/f6bf2c0d-d2e5-4f98-bf60-00f91fac62be_flux_1756078884.png: 640x640 1 cup, 1 book, 13.5ms
# image 957/993 /content/merged_cleaned_dataset/images/f73bad3d-7d14-4cde-b994-436be64f7b05_flux_1756080590.png: 640x640 1 vase, 15.2ms
# image 958/993 /content/merged_cleaned_dataset/images/f8a8d32a-b395-4f57-9bbd-b9684d3e4622_flux_1756079229.png: 640x640 1 cup, 13.4ms
# image 959/993 /content/merged_cleaned_dataset/images/f8ad4cd9-51ed-49a5-9095-2fe769f5b1b6_flux_1756080869.png: 640x640 1 cup, 13.2ms
# image 960/993 /content/merged_cleaned_dataset/images/f8aeb2b6-0387-4dc2-bdb3-ef5174093f67_flux_1756079000.png: 640x640 1 vase, 13.8ms
# image 961/993 /content/merged_cleaned_dataset/images/f8c68903-3292-4ce6-9b52-1b805cce7b43_flux_1756079196.png: 640x640 1 chair, 13.3ms
# image 962/993 /content/merged_cleaned_dataset/images/f910e424-885a-46f2-a6ca-19b4b38e9a44_flux_1756082333.png: 640x640 1 chair, 1 potted plant, 15.4ms
# image 963/993 /content/merged_cleaned_dataset/images/f9297bd5-5b1f-4606-b3a4-25f3e990ca1d_flux_1756080101.png: 640x640 1 vase, 10.4ms
# image 964/993 /content/merged_cleaned_dataset/images/f95d5d60-31e4-4211-ba48-f5f2a3a5297f_flux_1756078929.png: 640x640 (no detections), 8.2ms
# image 965/993 /content/merged_cleaned_dataset/images/f97a400e-c863-4c29-a19f-a38fec5ba0aa_flux_1756081411.png: 640x640 1 cup, 8.2ms
# image 966/993 /content/merged_cleaned_dataset/images/f998c8d8-176c-41c3-8419-8b5ad5aadabc_flux_1756079761.png: 640x640 (no detections), 9.8ms
# image 967/993 /content/merged_cleaned_dataset/images/f9aa79f0-4365-4fce-a198-d8b28a0acde3_flux_1756079041.png: 640x640 1 cup, 8.2ms
# image 968/993 /content/merged_cleaned_dataset/images/f9e2ce33-c9bb-40b3-adc6-9f73e099f64b_flux_1756079502.png: 640x640 3 cups, 1 chair, 1 potted plant, 8.4ms
# image 969/993 /content/merged_cleaned_dataset/images/fa5eebae-c854-4383-baa7-8420ec1f554d_flux_1756080630.png: 640x640 1 potted plant, 1 vase, 11.8ms
# image 970/993 /content/merged_cleaned_dataset/images/fa8ea711-948d-4db0-8324-a2f56ce9f3ab_flux_1756082388.png: 640x640 1 chair, 8.2ms
# image 971/993 /content/merged_cleaned_dataset/images/faba1ee7-36b7-4b1f-9711-547884c049f4_flux_1756081353.png: 640x640 (no detections), 8.2ms
# image 972/993 /content/merged_cleaned_dataset/images/fbb01c0a-45c4-4f95-844f-3f2cbb09015a_flux_1756081864.png: 640x640 1 cup, 8.2ms
# image 973/993 /content/merged_cleaned_dataset/images/fbb708e1-055c-44d4-a143-df9c2ae996f6_flux_1756081567.png: 640x640 1 book, 8.2ms
# image 974/993 /content/merged_cleaned_dataset/images/fbd05460-7440-4880-aa40-347cec3015aa_flux_1756082049.png: 640x640 1 cup, 8.2ms
# image 975/993 /content/merged_cleaned_dataset/images/fbd8ecaf-acd6-459b-bfb1-47fd24a9b175_flux_1756079045.png: 640x640 1 potted plant, 2 vases, 8.2ms
# image 976/993 /content/merged_cleaned_dataset/images/fc7fe2bb-dd08-4180-b5ca-018c058315d3_flux_1756078831.png: 640x640 1 chair, 12.9ms
# image 977/993 /content/merged_cleaned_dataset/images/fc919877-b6b5-47aa-b3fb-24f38e86359c_flux_1756079207.png: 640x640 1 chair, 8.2ms
# image 978/993 /content/merged_cleaned_dataset/images/fd204698-f37b-4fab-9613-844ab28420d8_flux_1756079435.png: 640x640 1 potted plant, 8.2ms
# image 979/993 /content/merged_cleaned_dataset/images/fd4b958f-1ea1-4c5e-9411-df7a76e99f6f_flux_1756079618.png: 640x640 1 cup, 8.2ms
# image 980/993 /content/merged_cleaned_dataset/images/fd7faaf4-dbcf-4b8e-b1b5-55283f1faaf0_flux_1756080748.png: 640x640 1 vase, 8.2ms
# image 981/993 /content/merged_cleaned_dataset/images/fd83b426-677a-496a-a880-c666fc0afe4e_flux_1756080253.png: 640x640 1 chair, 8.5ms
# image 982/993 /content/merged_cleaned_dataset/images/fe081c1b-a186-406c-92b1-bbfb045737a8_flux_1756080451.png: 640x640 1 cup, 8.2ms
# image 983/993 /content/merged_cleaned_dataset/images/fe2ab369-25a5-4b2c-971c-cd31c3a6ec22_flux_1756078849.png: 640x640 1 potted plant, 10.4ms
# image 984/993 /content/merged_cleaned_dataset/images/fe497f86-221a-4f37-b62a-2a116dca1a67_flux_1756082108.png: 640x640 1 cup, 8.2ms
# image 985/993 /content/merged_cleaned_dataset/images/fe498f37-6989-4649-a4dd-5125a81682b1_flux_1756081426.png: 640x640 2 chairs, 3 potted plants, 8.2ms
# image 986/993 /content/merged_cleaned_dataset/images/fe71821f-2fb7-4d6b-9d7f-97dae8fb574f_flux_1756080991.png: 640x640 (no detections), 8.2ms
# image 987/993 /content/merged_cleaned_dataset/images/febc3f83-08b5-407e-b98f-58f723679dd5_flux_1756078989.png: 640x640 1 cup, 8.2ms
# image 988/993 /content/merged_cleaned_dataset/images/fed56918-760d-4043-8fb0-5d0e4be6414b_flux_1756080887.png: 640x640 1 book, 8.2ms
# image 989/993 /content/merged_cleaned_dataset/images/ff59b836-1cde-416b-85a0-2c30c3ded392_flux_1756078676.png: 640x640 (no detections), 8.2ms
# image 990/993 /content/merged_cleaned_dataset/images/ff9376c9-b821-4f82-a0d9-d26070ea7e86_flux_1756079454.png: 640x640 2 potted plants, 8.2ms
# image 991/993 /content/merged_cleaned_dataset/images/ff9a0c40-fd15-427e-ad36-8e89c2ac6c79_flux_1756079318.png: 640x640 (no detections), 8.2ms
# image 992/993 /content/merged_cleaned_dataset/images/ffc4d71d-0d83-4d25-9229-15942ff76003_flux_1756080895.png: 640x640 1 chair, 8.7ms
# image 993/993 /content/merged_cleaned_dataset/images/ffe8acd0-e74b-49af-b156-1fb72aebfa16_flux_1756079304.png: 640x640 1 cup, 2 chairs, 3 potted plants, 1 vase, 8.2ms
# Speed: 3.1ms preprocess, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/runs/detect/predict2
# ✅ 82 misclassified images found.
# 📁 All outputs saved inside 'new_misclassified_dataset/'

# %%
import csv

wrong_class = 0
missing_annotation = 0

with open("new_misclassified_dataset/misclassified_report.csv", newline="") as f:
    reader = csv.reader(f)
    next(reader)  # skip header
    for row in reader:
        reason = row[1]
        if reason == "Wrong Class":
            wrong_class += 1
        elif reason == "Missing Annotation":
            missing_annotation += 1

total = wrong_class + missing_annotation

print("Wrong Class:", wrong_class)
print("Missing Annotation:", missing_annotation)
print("Total Flagged:", total)
# Out:
# Wrong Class: 32
# Missing Annotation: 59
# Total Flagged: 91

# %%
# this is done because when we run yolo model it creates a seperate
# predict/ folder in runs/detect/ folder every single time and can cause confusion

# The below code deletes the detect folder if we are running the yolo model for second time and so on.

# !rm -rf runs/detect

# %%
# add image width and height in json file
from pathlib import Path
from PIL import Image
from tqdm import tqdm

coco_path = 'cleaned_merged_coco.json'
images_dir = 'merged_cleaned_dataset/images'

# Load COCO JSON
with open(coco_path, 'r') as f:
    coco_data = json.load(f)

print("Adding image dimensions...")
added_count = 0  # counter for images updated

for img in tqdm(coco_data['images']):
    if 'height' not in img or 'width' not in img:
        img_path = Path(images_dir) / img['file_name']
        try:
            with Image.open(img_path) as im:
                img['width'], img['height'] = im.size
                added_count += 1
        except Exception as e:
            print(f"Error with {img['file_name']}: {e}")

# Save updated JSON
with open(coco_path, 'w') as f:
    json.dump(coco_data, f, indent=4)

print(f"✅ Done! Added width and height for {added_count} images.")
# Out:
# Adding image dimensions...
# 100%|██████████| 993/993 [00:00<00:00, 16438.38it/s]
# ✅ Done! Added width and height for 993 images.

# %%
# reindex json file
import json

coco_path = "cleaned_merged_coco.json"

with open(coco_path, "r") as f:
    coco = json.load(f)

# Sort and reindex categories from 0
sorted_cats = sorted(coco["categories"], key=lambda x: x["id"])
id_map = {cat["id"]: i for i, cat in enumerate(sorted_cats)}
print("ID mapping:", id_map)

# Update category IDs in annotations
for ann in coco["annotations"]:
    ann["category_id"] = id_map[ann["category_id"]]

# Update categories list
for cat in coco["categories"]:
    cat["id"] = id_map[cat["id"]]

# Save updated file
reindexed_path = "merged_cleaned_dataset/merged_coco_reindexed.json"
with open(reindexed_path, "w") as f:
    json.dump(coco, f, indent=4)

print(f" Reindexed COCO file saved to {reindexed_path}")
# Out:
# ID mapping: {1: 0, 2: 1, 3: 2, 4: 3, 5: 4}
#  Reindexed COCO file saved to merged_cleaned_dataset/merged_coco_reindexed.json

# %%
import json

coco_path = "merged_cleaned_dataset/merged_coco_reindexed.json"

with open(coco_path, "r") as f:
    coco = json.load(f)

valid_cat_ids = set(range(5))  # your reindexed categories: 0-4
invalid_annotations = []

for ann in coco["annotations"]:
    bbox = ann.get("bbox")
    cat_id = ann.get("category_id")

    # Check category_id
    cat_ok = cat_id in valid_cat_ids

    # Check bbox: 4 numbers, no None, all >=0, width/height > 0
    bbox_ok = (
        isinstance(bbox, list) and
        len(bbox) == 4 and
        all(isinstance(v, (int, float)) for v in bbox) and
        all(v >= 0 for v in bbox) and
        bbox[2] > 0 and bbox[3] > 0
    )

    if not (cat_ok and bbox_ok):
        invalid_annotations.append({
            "image_id": ann.get("image_id"),
            "category_id": cat_id,
            "bbox": bbox
        })

if invalid_annotations:
    print(f"⚠️ Found {len(invalid_annotations)} invalid annotations:")
    for i, ann in enumerate(invalid_annotations[:10]):
        print(f"{i+1}: {ann}")
else:
    print("✅ All annotations look good!")
# Out:
# ✅ All annotations look good!

# %%
def coco_to_yolo_custom(coco_json_path, output_dir, image_dir):
    """
    Convert COCO format to YOLO format
    """
    # Load COCO annotations
    with open(coco_json_path, 'r') as f:
        coco = json.load(f)

    # Create output directory
    labels_dir = Path(output_dir) / 'labels'
    labels_dir.mkdir(parents=True, exist_ok=True)

    # Create image_id to filename mapping
    image_info = {img['id']: img for img in coco['images']}

    # Group annotations by image_id
    annotations_by_image = {}
    for ann in coco['annotations']:
        img_id = ann['image_id']
        if img_id not in annotations_by_image:
            annotations_by_image[img_id] = []
        annotations_by_image[img_id].append(ann)

    print(f"Converting {len(image_info)} images...")

    # Convert each image's annotations
    converted = 0
    for img_id, img_data in tqdm(image_info.items()):
        img_width = img_data['width']
        img_height = img_data['height']
        filename = img_data['file_name']

        # Get label filename (same as image but .txt)
        label_filename = Path(filename).stem + '.txt'
        label_path = labels_dir / label_filename

        # Get annotations for this image
        anns = annotations_by_image.get(img_id, [])

        # Write YOLO format annotations
        with open(label_path, 'w') as f:
            for ann in anns:
                category_id = ann['category_id']
                bbox = ann['bbox']  # [x, y, width, height] in pixels

                # Convert to YOLO format (normalized center x, center y, width, height)
                x, y, w, h = bbox
                x_center = (x + w / 2) / img_width
                y_center = (y + h / 2) / img_height
                norm_width = w / img_width
                norm_height = h / img_height

                # Write: class x_center y_center width height
                f.write(f"{category_id} {x_center:.6f} {y_center:.6f} {norm_width:.6f} {norm_height:.6f}\n")

        converted += 1

    print(f"Converted {converted} images to YOLO format")
    print(f"Labels saved to: {labels_dir}")

    return labels_dir

# Run the conversion
coco_to_yolo_custom(
    coco_json_path='merged_cleaned_dataset/merged_coco_reindexed.json',
    output_dir='YOLO_dataset_final',
    image_dir='merged_cleaned_dataset/images'
)
# Out:
# Converting 993 images...
# 100%|██████████| 993/993 [00:00<00:00, 3574.76it/s]
# Converted 993 images to YOLO format
# Labels saved to: YOLO_dataset_final/labels
# PosixPath('YOLO_dataset_final/labels')

# %%
# copy images to yolo_dataset folder
# Source and destination
source_images = Path('merged_cleaned_dataset/images')
dest_images = Path('YOLO_dataset_final/images')

# Create destination if it doesn't exist
dest_images.mkdir(parents=True, exist_ok=True)

# Copy all images
print("Copying images...")
image_files = list(source_images.glob('*'))

for img in tqdm(image_files):
    if img.is_file():
        shutil.copy2(img, dest_images / img.name)

print(f"Done! Copied {len(image_files)} images to {dest_images}")
# Out:
# Copying images...
# 100%|██████████| 993/993 [00:00<00:00, 1403.00it/s]
# Done! Copied 993 images to YOLO_dataset_final/images

# %%
from sklearn.model_selection import train_test_split

# %%
# split the data into train test
from pathlib import Path
import shutil
from sklearn.model_selection import train_test_split
from tqdm import tqdm

dataset_dir = Path('YOLO_dataset_final')
images_dir = dataset_dir / 'images'
labels_dir = dataset_dir / 'labels'

# create train/val directories
(dataset_dir / 'images' / 'train').mkdir(parents=True, exist_ok=True)
(dataset_dir / 'images' / 'val').mkdir(parents=True, exist_ok=True)
(dataset_dir / 'labels' / 'train').mkdir(parents=True, exist_ok=True)
(dataset_dir / 'labels' / 'val').mkdir(parents=True, exist_ok=True)

# get image files to a list
print("Finding images...")
image_files = [f for f in images_dir.glob('*') if f.is_file() and f.suffix.lower() in ['.jpg', '.jpeg', '.png']]
print(f"Found {len(image_files)} images")

# split to train/val
train_imgs, val_imgs = train_test_split(
    image_files,
    train_size=0.8,
    random_state=101
)

print(f"\nSplit:")
print(f"  Train: {len(train_imgs)} images")
print(f"  Val:   {len(val_imgs)} images")

#move train files
print("\nMoving train files...")
for img in tqdm(train_imgs):
    # Move image
    shutil.move(str(img), str(dataset_dir / 'images' / 'train' / img.name))

    # Move corresponding label
    label = labels_dir / f'{img.stem}.txt'
    if label.exists():
        shutil.move(str(label), str(dataset_dir / 'labels' / 'train' / label.name))

#move val files
print("Moving val files...")
for img in tqdm(val_imgs):
    # Move image
    shutil.move(str(img), str(dataset_dir / 'images' / 'val' / img.name))

    # Move corresponding label
    label = labels_dir / f'{img.stem}.txt'
    if label.exists():
        shutil.move(str(label), str(dataset_dir / 'labels' / 'val' / label.name))

# clean directory
if images_dir.exists() and not any(images_dir.iterdir()):
    images_dir.rmdir()
if labels_dir.exists() and not any(labels_dir.iterdir()):
    labels_dir.rmdir()

print("\n Dataset split complete!")
# Out:
# Finding images...
# Found 993 images
#
# Split:
#   Train: 794 images
#   Val:   199 images
#
# Moving train files...
# 100%|██████████| 794/794 [00:00<00:00, 12876.11it/s]
# Moving val files...
# 100%|██████████| 199/199 [00:00<00:00, 11983.73it/s]
#  Dataset split complete!

# %%
import json
import yaml
from pathlib import Path

def create_yolo_yaml(coco_json_path, yolo_dataset_dir, yaml_filename='data.yaml'):
    """
    Create YAML config file for YOLO training with train/val split
    """
    # Load COCO annotations to get categories
    with open(coco_json_path, 'r') as f:
        coco = json.load(f)

    # Extract and sort categories by id
    categories = sorted(coco['categories'], key=lambda x: x['id'])

    print("📋 Category Information:")
    print("-" * 50)
    for cat in categories:
        print(f"ID {cat['id']}: {cat['name']}")
    print("-" * 50)
    print(f"Total categories: {len(categories)}\n")

    # Create names dictionary (id: name)
    names = {cat['id']: cat['name'] for cat in categories}

    # Get absolute path to dataset
    dataset_path = Path(yolo_dataset_dir).resolve()

    # Create YAML structure with val instead of test
    yaml_data = {
        'path': str(dataset_path),  # dataset root dir
        'train': 'images/train',     # train images (relative to 'path')
        'val': 'images/val',         # val images (relative to 'path')

        'nc': len(categories),       # number of classes
        'names': names               # class names
    }

    # Save YAML file
    yaml_path = Path(yolo_dataset_dir) / yaml_filename
    with open(yaml_path, 'w') as f:
        yaml.dump(yaml_data, f, default_flow_style=False, sort_keys=False)

    print(f"✅ YAML file created: {yaml_path}")
    print("\n📄 YAML Contents:")
    print("-" * 50)
    with open(yaml_path, 'r') as f:
        print(f.read())
    print("-" * 50)

    return yaml_path

# Recreate YAML with correct val path
create_yolo_yaml(
    coco_json_path='merged_cleaned_dataset/merged_coco_reindexed.json',
    yolo_dataset_dir='YOLO_dataset_final',
    yaml_filename='data.yaml'
)
# Out:
# 📋 Category Information:
# --------------------------------------------------
# ID 0: potted plant
# ID 1: chair
# ID 2: cup
# ID 3: vase
# ID 4: book
# --------------------------------------------------
# Total categories: 5
#
# ✅ YAML file created: YOLO_dataset_final/data.yaml
#
# 📄 YAML Contents:
# --------------------------------------------------
# path: /content/YOLO_dataset_final
# train: images/train
# val: images/val
# nc: 5
# names:
#   0: potted plant
#   1: chair
#   2: cup
#   3: vase
#   4: book
#
# --------------------------------------------------
# PosixPath('YOLO_dataset_final/data.yaml')

# %%
results = model.train(
    data='YOLO_dataset_final/data.yaml',
    epochs=50
)
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=YOLO_dataset_final/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/detect/train, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 32.9MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431647  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,815 parameters, 2,590,799 gradients, 6.4 GFLOPs
#
# Transferred 79/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2687.8±572.9 MB/s, size: 230.0 KB)
# train: Scanning /content/YOLO_dataset_final/labels/train... 794 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 794/794 1.4Kit/s 0.6s
# train: New cache created: /content/YOLO_dataset_final/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1789.6±1370.8 MB/s, size: 231.9 KB)
# val: Scanning /content/YOLO_dataset_final/labels/val... 199 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 199/199 618.8it/s 0.3s
# val: New cache created: /content/YOLO_dataset_final/labels/val.cache
# Plotting labels to /content/runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.95G      2.782      3.848      2.572         98        640: 100% ━━━━━━━━━━━━ 50/50 1.3it/s 38.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.3s/it 9.2s
#                    all        199        714     0.0176      0.329     0.0554     0.0315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.96G      2.005      3.151      2.009         64        640: 100% ━━━━━━━━━━━━ 50/50 2.6it/s 19.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.294      0.247      0.192      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      3.16G      1.703      2.629       1.78         57        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.2s
#                    all        199        714       0.33      0.355      0.265      0.182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      3.36G      1.494      2.301      1.644         86        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.538      0.393      0.451      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.38G      1.403      2.084      1.545         54        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.618      0.438      0.496      0.368
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      3.58G       1.37      1.973      1.501        103        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.9s
#                    all        199        714      0.607      0.466      0.512      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50       3.6G      1.297       1.89      1.473         40        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.3s
#                    all        199        714      0.587      0.479      0.542      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      3.61G      1.264      1.816      1.433         68        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.665      0.497      0.566      0.442
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.83G      1.207      1.724      1.387         72        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.655      0.492       0.57      0.462
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.84G      1.183      1.692       1.38         58        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9it/s 3.8s
#                    all        199        714       0.64      0.516      0.589      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.85G      1.179      1.619      1.353         57        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714        0.7       0.47      0.582      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.87G      1.132      1.561      1.332        111        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.689       0.51      0.583      0.483
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.88G      1.127      1.534       1.33         90        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.9s
#                    all        199        714      0.616       0.54      0.605      0.486
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      4.11G      1.147      1.528      1.338         83        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.687       0.54      0.629      0.508
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      4.13G       1.08      1.464       1.29         99        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.764      0.513      0.628      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      4.14G      1.073      1.447       1.29        113        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.9s
#                    all        199        714      0.701      0.524      0.626      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      4.16G      1.066      1.446      1.298        101        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.694      0.543      0.637      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50      4.41G      1.027        1.4      1.263         75        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        199        714      0.749      0.536      0.639      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      4.43G      1.028      1.363      1.264         67        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9it/s 3.7s
#                    all        199        714      0.668      0.545      0.618      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      4.44G      1.011      1.343      1.264         72        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.9s
#                    all        199        714      0.681       0.55      0.625       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      4.46G      1.033       1.33      1.237         50        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        199        714      0.682      0.546      0.628      0.524
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      4.47G     0.9738      1.301       1.23         94        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.9s
#                    all        199        714      0.662      0.562      0.641      0.536
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      4.49G      0.983      1.278      1.218         70        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.9s
#                    all        199        714       0.67       0.56       0.63      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       4.5G      0.956      1.248      1.209         99        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.712       0.56       0.66      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      4.52G     0.9469       1.23      1.208         81        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.3s
#                    all        199        714      0.704      0.574      0.651      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      4.53G      0.933      1.231      1.206         74        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        199        714      0.653      0.594      0.642      0.539
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      4.55G     0.9306      1.214      1.199         73        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 18.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.7it/s 2.6s
#                    all        199        714      0.677      0.568      0.645      0.543
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50       4.8G     0.9562      1.205      1.196         78        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2it/s 3.2s
#                    all        199        714        0.7      0.545      0.644      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50      4.82G     0.9263      1.173      1.195         70        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.3s
#                    all        199        714       0.66      0.589      0.652      0.545
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      4.83G     0.8848      1.149      1.169         84        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.672       0.61      0.673      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      4.85G     0.8725      1.125      1.174         63        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.664      0.604      0.653      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      4.86G     0.9134      1.146      1.169         58        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.8it/s 3.8s
#                    all        199        714      0.795      0.523      0.675      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      4.88G     0.9155      1.163      1.191         74        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.0s
#                    all        199        714       0.68      0.594      0.669      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      4.89G     0.9085      1.129      1.182        131        640: 100% ━━━━━━━━━━━━ 50/50 2.6it/s 18.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        199        714       0.72      0.578      0.682      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      4.91G     0.8931      1.114       1.17         92        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.1it/s 3.4s
#                    all        199        714      0.713      0.585      0.674       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      4.92G     0.8833      1.112      1.161         67        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        199        714      0.715      0.586      0.676      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      4.94G     0.8772      1.069      1.152         79        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.5it/s 2.8s
#                    all        199        714       0.71      0.595      0.675      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      4.95G     0.8807       1.06      1.155         55        640: 100% ━━━━━━━━━━━━ 50/50 2.7it/s 18.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2it/s 3.2s
#                    all        199        714      0.676      0.621      0.678      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50      4.97G      0.884      1.081      1.163         81        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.7it/s 4.1s
#                    all        199        714      0.691      0.622      0.689      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      4.98G     0.8525      1.034      1.144         72        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714       0.75      0.583      0.693      0.587
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         5G     0.7962      1.002      1.103         33        640: 100% ━━━━━━━━━━━━ 50/50 2.4it/s 21.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.3it/s 3.1s
#                    all        199        714      0.738      0.559      0.672      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      5.01G     0.7785     0.9302      1.089        120        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 3.0s
#                    all        199        714      0.693      0.584      0.678      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      5.03G     0.7539     0.9006      1.085         76        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2it/s 3.2s
#                    all        199        714      0.754      0.566      0.689      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      5.04G     0.7444     0.8783      1.065         40        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.715      0.606      0.693      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      5.06G     0.7424     0.8632      1.075         55        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        199        714      0.725      0.607      0.688      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      5.07G     0.7321     0.8694      1.066         25        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.2it/s 3.2s
#                    all        199        714      0.749      0.583      0.686      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      5.09G     0.7482     0.8525      1.079         28        640: 100% ━━━━━━━━━━━━ 50/50 3.0it/s 16.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.661      0.636      0.684      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       5.1G     0.7326     0.8378      1.067         29        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.9it/s 3.6s
#                    all        199        714      0.676      0.636      0.684      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50      5.12G     0.7309     0.8295       1.05         82        640: 100% ━━━━━━━━━━━━ 50/50 2.9it/s 17.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.6it/s 2.7s
#                    all        199        714       0.69      0.598      0.682      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      5.13G     0.7212     0.8322      1.065         66        640: 100% ━━━━━━━━━━━━ 50/50 2.8it/s 17.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        199        714      0.759      0.553      0.684      0.584
#
# 50 epochs completed in 0.314 hours.
# Optimizer stripped from /content/runs/detect/train/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs/detect/train/weights/best.pt, 5.5MB
#
# Validating /content/runs/detect/train/weights/best.pt...
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 1.4it/s 5.1s
#                    all        199        714      0.749      0.584      0.693      0.587
#           potted plant         92        222      0.768      0.617      0.729        0.6
#                  chair         77        147       0.72      0.483      0.596      0.464
#                    cup         46         57      0.935      0.756      0.881       0.84
#                   vase         74        130      0.797      0.569      0.743      0.624
#                   book         56        158      0.527      0.493      0.516      0.405
# Speed: 0.4ms preprocess, 3.8ms inference, 0.0ms loss, 7.1ms postprocess per image
# Results saved to /content/runs/detect/train

# %%
import os

root = "YOLO_dataset_final"

folders = [
    os.path.join(root, "images/test"),
    os.path.join(root, "labels/test"),
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f"Created: {folder}")

print("\nTest folder structure is ready. You can upload your test images and labels manually!")
# Out:
# Created: YOLO_dataset_final/images/test
# Created: YOLO_dataset_final/labels/test
#
# Test folder structure is ready. You can upload your test images and labels manually!

# %%
import yaml

yaml_path = "YOLO_dataset_final/data.yaml"   # path to your existing yaml
test_path = "images/test"                    # <-- correct relative path

# Load existing YAML
with open(yaml_path, "r") as f:
    data = yaml.safe_load(f)

# Add/update the test field
data["test"] = test_path

# Save updated YAML
with open(yaml_path, "w") as f:
    yaml.dump(data, f, sort_keys=False)

print("Updated data.yaml successfully!")
# Out:
# Updated data.yaml successfully!

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt")  # your fine-tuned model
results = model.val(data="YOLO_dataset_final/data.yaml", split="test")
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1686.7±561.0 MB/s, size: 145.7 KB)
# val: Scanning /content/YOLO_dataset_final/labels/test... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 244.3it/s 0.8s
# val: New cache created: /content/YOLO_dataset_final/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.0it/s 12.8s
#                    all        200       1061      0.466      0.369      0.349      0.197
#           potted plant        111        221      0.555      0.697      0.658      0.377
#                  chair         68        101      0.324      0.347      0.246      0.122
#                    cup         77        107      0.521       0.29      0.291      0.186
#                   vase        122        231      0.604      0.342      0.392       0.22
#                   book         75        401      0.324       0.17      0.159     0.0819
# Speed: 3.6ms preprocess, 11.3ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to /content/runs/detect/val2

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")  # baseline pretrained model
results = model.val(data="YOLO_dataset_final/data.yaml", split="test")
# Out:
# Ultralytics 8.3.230 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1823.4±615.3 MB/s, size: 1886.7 KB)
# val: Scanning /content/YOLO_dataset_final/labels/test.cache... 200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 200/200 116.8Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 13/13 1.3it/s 10.3s
#                    all        200       1061      0.061      0.119     0.0401     0.0233
#                 person        111        221     0.0338       0.24     0.0231      0.013
#                bicycle         68        101      0.107      0.188     0.0876     0.0438
#                    car         77        107     0.0269      0.112     0.0158    0.00899
#             motorcycle        122        231     0.0519     0.0346     0.0279     0.0178
#               airplane         75        401     0.0857     0.0224     0.0461     0.0329
# Speed: 2.3ms preprocess, 3.9ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to /content/runs/detect/val4
